# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

import os

# %%
houses = pd.read_csv('./informations_households.csv')

# %%
houses['LCLid'].nunique()
# Out:
# 5566

# %%
houses
# Out:
#           LCLid stdorToU    Acorn Acorn_grouped       file
# 0     MAC005492      ToU   ACORN-        ACORN-    block_0
# 1     MAC001074      ToU   ACORN-        ACORN-    block_0
# 2     MAC000002      Std  ACORN-A      Affluent    block_0
# 3     MAC003613      Std  ACORN-A      Affluent    block_0
# 4     MAC003597      Std  ACORN-A      Affluent    block_0
# ...         ...      ...      ...           ...        ...
# 5561  MAC002056      Std  ACORN-U       ACORN-U  block_111
# 5562  MAC004587      Std  ACORN-U       ACORN-U  block_111
# 5563  MAC004828      Std  ACORN-U       ACORN-U  block_111
# 5564  MAC001704      ToU  ACORN-U       ACORN-U  block_111
# 5565  MAC002774      ToU  ACORN-U       ACORN-U  block_111
#
# [5566 rows x 5 columns]

# %%
houses.Acorn.unique()
# Out:
# array(['ACORN-', 'ACORN-A', 'ACORN-B', 'ACORN-C', 'ACORN-D', 'ACORN-E',
#        'ACORN-F', 'ACORN-G', 'ACORN-H', 'ACORN-I', 'ACORN-J', 'ACORN-K',
#        'ACORN-L', 'ACORN-M', 'ACORN-N', 'ACORN-O', 'ACORN-P', 'ACORN-Q',
#        'ACORN-U'], dtype=object)

# %%
halfhourly = pd.read_csv('./halfhourly_dataset/halfhourly_dataset/block_0.csv')
halfhourly
# Out:
#              LCLid                         tstp energy(kWh/hh)
# 0        MAC000002  2012-10-12 00:30:00.0000000             0
# 1        MAC000002  2012-10-12 01:00:00.0000000             0
# 2        MAC000002  2012-10-12 01:30:00.0000000             0
# 3        MAC000002  2012-10-12 02:00:00.0000000             0
# 4        MAC000002  2012-10-12 02:30:00.0000000             0
# ...            ...                          ...            ...
# 1222665  MAC005492  2014-02-27 22:00:00.0000000         0.182
# 1222666  MAC005492  2014-02-27 22:30:00.0000000         0.122
# 1222667  MAC005492  2014-02-27 23:00:00.0000000          0.14
# 1222668  MAC005492  2014-02-27 23:30:00.0000000         0.192
# 1222669  MAC005492  2014-02-28 00:00:00.0000000         0.088
#
# [1222670 rows x 3 columns]

# %%
directory = './halfhourly_dataset/halfhourly_dataset/'
for filename in os.listdir(directory):
    if filename.endswith('.csv'):
        print(os.path.join(directory, filename))
        #halfhourly = pd.read_csv(filename)
        #halfhourly.LCLid.unique()
    else:
        continue
# Out:
# ./halfhourly_dataset/halfhourly_dataset/block_71.csv
# ./halfhourly_dataset/halfhourly_dataset/block_65.csv
# ./halfhourly_dataset/halfhourly_dataset/block_59.csv
# ./halfhourly_dataset/halfhourly_dataset/block_58.csv
# ./halfhourly_dataset/halfhourly_dataset/block_64.csv
# ./halfhourly_dataset/halfhourly_dataset/block_70.csv
# ./halfhourly_dataset/halfhourly_dataset/block_99.csv
# ./halfhourly_dataset/halfhourly_dataset/block_66.csv
# ./halfhourly_dataset/halfhourly_dataset/block_72.csv
# ./halfhourly_dataset/halfhourly_dataset/block_73.csv
# ./halfhourly_dataset/halfhourly_dataset/block_67.csv
# ./halfhourly_dataset/halfhourly_dataset/block_98.csv
# ./halfhourly_dataset/halfhourly_dataset/block_88.csv
# ./halfhourly_dataset/halfhourly_dataset/block_63.csv
# ./halfhourly_dataset/halfhourly_dataset/block_77.csv
# ./halfhourly_dataset/halfhourly_dataset/block_76.csv
# ./halfhourly_dataset/halfhourly_dataset/block_62.csv
# ./halfhourly_dataset/halfhourly_dataset/block_89.csv
# ...
