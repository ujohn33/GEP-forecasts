# %%
import datetime
import sys
import os

import IPython
import IPython.display
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from tensorflow.keras import Input, Model
from cond_rnn import ConditionalRNN
from sklearn.preprocessing import MinMaxScaler
from pmdarima.arima import auto_arima

import src.preprocessing
from src.functions import load_data, mape, TimeSeriesTensor, create_evaluation_df, series_to_supervised, plot_train_history, validation

np.set_printoptions(threshold=sys.maxsize)

# %%
GEP1 = pd.read_csv('../data/GEP/Consumption_15min.csv', index_col=0, header=0, names=['value'])
GEP2 = pd.read_csv('../data/GEP/B2_Consumption_15min.csv', index_col=0, header=0, names=['value'])
GEP4 = pd.read_csv('../data/GEP/B4_Consumption_15min.csv', index_col=0, header=0, names=['value'])
datasets = [GEP1, GEP2, GEP4]
names = ['GEP1', 'GEP2', 'GEP4']

# %%
class Baseline(tf.keras.Model):
    def __init__(self, label_index=None):
        super().__init__()
        self.label_index = label_index

    def call(self, inputs):
        if self.label_index is None:
            return inputs
        result = inputs[:, :, self.label_index]
        return result[:, :, tf.newaxis]

# %%
metrics = pd.DataFrame(columns=['mape','rmse', 'B'], index=range(len(datasets)))
from progressbar import ProgressBar
pbar = ProgressBar()
for i,df in enumerate(datasets):
    train_inputs, test_inputs, y_scaler = MIMO_fulldata_preparation(df)
    baseline = Baseline(label_index = 0)
    baseline.compile(loss=tf.losses.MeanSquaredError(), metrics=[tf.metrics.MeanSquaredError()])
    predictions_B = baseline.predict(test_inputs['X'])
    eval_df_B = create_evaluation_df(predictions_B.reshape(-1,24), test_inputs, 24, y_scaler)
    mape = validation(eval_df_B['prediction'], eval_df_B['actual'], 'MAE')
    #print('mape {}'.format(mape))
    rmse = validation(eval_df_B['prediction'], eval_df_B['actual'], 'RMSE')
    #print('rmse {}'.format(rmse))
    metrics.loc[i] = pd.Series({'mape':mape, 'rmse':rmse, 'B':names[i]})
metrics.to_csv('./results/GEP/baseline.csv')

# %%
MAX_EPOCHS = 100
BATCHSIZE = 32
patience = 10
HORIZON = 24

FULL_LSTMIMO = tf.keras.models.Sequential([
    # Shape [batch, time, features] => [batch, time, lstm_units]
    tf.keras.layers.LSTM(32, input_shape=(24, 15)),
    # Shape => [batch, time, features]
    tf.keras.layers.Dense(HORIZON)
])

metrics = pd.DataFrame(columns=['mape','rmse', 'B'], index=range(len(datasets)))
from progressbar import ProgressBar
pbar = ProgressBar()
for i,df in enumerate(datasets):
    train_longer_inputs, test_longer_inputs, y_scaler = MIMO_fulldata_preparation(df)
    # full data LSTM MIMO compilation and fit
    FULL_LSTMIMO.compile(optimizer=tf.optimizers.Adam(), loss='mse', metrics=[tf.metrics.MeanSquaredError()])

    early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=patience, mode='min')
    for j in pbar(range(1,11)):
        print('RUN:{}'.format(j))
        history = FULL_LSTMIMO.fit(train_longer_inputs['X'], train_longer_inputs['target'], batch_size=32, epochs=MAX_EPOCHS,
                      validation_split=0.15,
                      callbacks=[early_stopping], verbose=1)

        FD_predictions = FULL_LSTMIMO.predict(test_longer_inputs['X'])
        FD_eval_df = create_evaluation_df(FD_predictions, test_longer_inputs, HORIZON, y_scaler)
        mae = validation(FD_eval_df['prediction'], FD_eval_df['actual'], 'MAE')
        rmse = validation(FD_eval_df['prediction'], FD_eval_df['actual'], 'RMSE')
        #print('rmse {}'.format(rmse))
        metrics.loc[10*i + j] = pd.Series({'mae':mae, 'rmse':rmse, 'B': names[i]})
metrics.to_csv('./results/GEP/fulldata10_LSTM.csv')
# Out:
#   0% |                                                                        |
# RUN:1
# Epoch 1/100
# 112/112 [==============================] - 2s 21ms/step - loss: 0.0508 - mean_squared_error: 0.0508 - val_loss: 0.0505 - val_mean_squared_error: 0.0505
# Epoch 2/100
# 112/112 [==============================] - 2s 17ms/step - loss: 0.0278 - mean_squared_error: 0.0278 - val_loss: 0.0271 - val_mean_squared_error: 0.0271
# Epoch 3/100
# 112/112 [==============================] - 2s 17ms/step - loss: 0.0184 - mean_squared_error: 0.0184 - val_loss: 0.0280 - val_mean_squared_error: 0.0280
# Epoch 4/100
# 112/112 [==============================] - 2s 16ms/step - loss: 0.0140 - mean_squared_error: 0.0140 - val_loss: 0.0315 - val_mean_squared_error: 0.0315
# Epoch 5/100
# 112/112 [==============================] - 2s 16ms/step - loss: 0.0119 - mean_squared_error: 0.0119 - val_loss: 0.0329 - val_mean_squared_error: 0.0329
# Epoch 6/100
# 112/112 [==============================] - 2s 16ms/step - loss: 0.0106 - mean_squared_error: 0.0106 - val_loss: 0.0387 - val_mean_squared_error: 0.0387
# Epoch 7/100
# 112/112 [==============================] - 2s 16ms/step - loss: 0.0099 - mean_squared_error: 0.0099 - val_loss: 0.0371 - val_mean_squared_error: 0.0371
# Epoch 8/100
# 112/112 [==============================] - 2s 16ms/step - loss: 0.0093 - mean_squared_error: 0.0093 - val_loss: 0.0359 - val_mean_squared_error: 0.0359
# Epoch 9/100
# 112/112 [==============================] - 2s 16ms/step - loss: 0.0088 - mean_squared_error: 0.0088 - val_loss: 0.0372 - val_mean_squared_error: 0.0372
# Epoch 10/100
# 112/112 [==============================] - 2s 15ms/step - loss: 0.0083 - mean_squared_error: 0.0083 - val_loss: 0.0395 - val_mean_squared_error: 0.0395
# Epoch 11/100
# 112/112 [==============================] - 2s 17ms/step - loss: 0.0081 - mean_squared_error: 0.0081 - val_loss: 0.0382 - val_mean_squared_error: 0.0382
# Epoch 12/100
# 112/112 [==============================] - 2s 16ms/step - loss: 0.0076 - mean_squared_error: 0.0076 - val_loss: 0.0394 - val_mean_squared_error: 0.0394
#  10% |#######                                                                 |
# RUN:2
# Epoch 1/100
# 112/112 [==============================] - 2s 16ms/step - loss: 0.0075 - mean_squared_error: 0.0075 - val_loss: 0.0373 - val_mean_squared_error: 0.0373
# Epoch 2/100
# 112/112 [==============================] - 2s 15ms/step - loss: 0.0068 - mean_squared_error: 0.0068 - val_loss: 0.0386 - val_mean_squared_error: 0.0386
# Epoch 3/100
# 112/112 [==============================] - 2s 15ms/step - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 0.0378 - val_mean_squared_error: 0.0378
# Epoch 4/100
# 112/112 [==============================] - 2s 15ms/step - loss: 0.0059 - mean_squared_error: 0.0059 - val_loss: 0.0384 - val_mean_squared_error: 0.0384
# Epoch 5/100
# 112/112 [==============================] - 2s 15ms/step - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0392 - val_mean_squared_error: 0.0392
# Epoch 6/100
# 112/112 [==============================] - 2s 15ms/step - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 0.0346 - val_mean_squared_error: 0.0346
# Epoch 7/100
# 112/112 [==============================] - 2s 15ms/step - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 0.0363 - val_mean_squared_error: 0.0363
# Epoch 8/100
# 112/112 [==============================] - 2s 15ms/step - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 0.0353 - val_mean_squared_error: 0.0353
# Epoch 9/100
# 112/112 [==============================] - 2s 16ms/step - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0354 - val_mean_squared_error: 0.0354
# Epoch 10/100
# 112/112 [==============================] - 2s 15ms/step - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0348 - val_mean_squared_error: 0.0348
# Epoch 11/100
# 112/112 [==============================] - 2s 14ms/step - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 0.0355 - val_mean_squared_error: 0.0355
# Epoch 12/100
# 112/112 [==============================] - 2s 14ms/step - loss: 0.0041 - mean_squared_error: 0.0041 - val_loss: 0.0345 - val_mean_squared_error: 0.0345
# Epoch 13/100
# 112/112 [==============================] - 2s 14ms/step - loss: 0.0041 - mean_squared_error: 0.0041 - val_loss: 0.0334 - val_mean_squared_error: 0.0334
# Epoch 14/100
# 112/112 [==============================] - 2s 15ms/step - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0335 - val_mean_squared_error: 0.0335
# Epoch 15/100
# 112/112 [==============================] - 2s 15ms/step - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0335 - val_mean_squared_error: 0.0335
# Epoch 16/100
# 112/112 [==============================] - 2s 15ms/step - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0325 - val_mean_squared_error: 0.0325
# Epoch 17/100
# 112/112 [==============================] - 2s 16ms/step - loss: 0.0037 - mean_squared_error: 0.0037 - val_loss: 0.0335 - val_mean_squared_error: 0.0335
# Epoch 18/100
# 112/112 [==============================] - 2s 15ms/step - loss: 0.0035 - mean_squared_error: 0.0035 - val_loss: 0.0323 - val_mean_squared_error: 0.0323
# Epoch 19/100
# 112/112 [==============================] - 2s 15ms/step - loss: 0.0035 - mean_squared_error: 0.0035 - val_loss: 0.0337 - val_mean_squared_error: 0.0337
# Epoch 20/100
# 112/112 [==============================] - 2s 15ms/step - loss: 0.0035 - mean_squared_error: 0.0035 - val_loss: 0.0325 - val_mean_squared_error: 0.0325
# Epoch 21/100
# 112/112 [==============================] - 2s 16ms/step - loss: 0.0033 - mean_squared_error: 0.0033 - val_loss: 0.0318 - val_mean_squared_error: 0.0318
# Epoch 22/100
# 112/112 [==============================] - 2s 16ms/step - loss: 0.0033 - mean_squared_error: 0.0033 - val_loss: 0.0338 - val_mean_squared_error: 0.0338
# Epoch 23/100
# 112/112 [==============================] - 2s 15ms/step - loss: 0.0035 - mean_squared_error: 0.0035 - val_loss: 0.0323 - val_mean_squared_error: 0.0323
# Epoch 24/100
# 112/112 [==============================] - 2s 17ms/step - loss: 0.0033 - mean_squared_error: 0.0033 - val_loss: 0.0320 - val_mean_squared_error: 0.0320
# Epoch 25/100
# 112/112 [==============================] - 2s 16ms/step - loss: 0.0035 - mean_squared_error: 0.0035 - val_loss: 0.0320 - val_mean_squared_error: 0.0320
# Epoch 26/100
# 112/112 [==============================] - 2s 15ms/step - loss: 0.0030 - mean_squared_error: 0.0030 - val_loss: 0.0316 - val_mean_squared_error: 0.0316
# Epoch 27/100
# 112/112 [==============================] - 2s 16ms/step - loss: 0.0031 - mean_squared_error: 0.0031 - val_loss: 0.0316 - val_mean_squared_error: 0.0316
# Epoch 28/100
# 112/112 [==============================] - 2s 15ms/step - loss: 0.0029 - mean_squared_error: 0.0029 - val_loss: 0.0319 - val_mean_squared_error: 0.0319
# Epoch 29/100
# 112/112 [==============================] - 2s 14ms/step - loss: 0.0029 - mean_squared_error: 0.0029 - val_loss: 0.0311 - val_mean_squared_error: 0.0311
# Epoch 30/100
# 112/112 [==============================] - 2s 14ms/step - loss: 0.0029 - mean_squared_error: 0.0029 - val_loss: 0.0321 - val_mean_squared_error: 0.0321
# Epoch 31/100
# 112/112 [==============================] - 2s 16ms/step - loss: 0.0026 - mean_squared_error: 0.0026 - val_loss: 0.0319 - val_mean_squared_error: 0.0319
# Epoch 32/100
# 112/112 [==============================] - 2s 15ms/step - loss: 0.0026 - mean_squared_error: 0.0026 - val_loss: 0.0319 - val_mean_squared_error: 0.0319
# Epoch 33/100
# 112/112 [==============================] - 2s 15ms/step - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 0.0318 - val_mean_squared_error: 0.0318
# Epoch 34/100
# 112/112 [==============================] - 2s 15ms/step - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 0.0318 - val_mean_squared_error: 0.0318
# Epoch 35/100
# 112/112 [==============================] - 2s 15ms/step - loss: 0.0024 - mean_squared_error: 0.0024 - val_loss: 0.0319 - val_mean_squared_error: 0.0319
# Epoch 36/100
# 112/112 [==============================] - 2s 14ms/step - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 0.0323 - val_mean_squared_error: 0.0323
# Epoch 37/100
# 112/112 [==============================] - 2s 16ms/step - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 0.0323 - val_mean_squared_error: 0.0323
# Epoch 38/100
# 112/112 [==============================] - 2s 15ms/step - loss: 0.0024 - mean_squared_error: 0.0024 - val_loss: 0.0322 - val_mean_squared_error: 0.0322
# Epoch 39/100
# 112/112 [==============================] - 2s 14ms/step - loss: 0.0023 - mean_squared_error: 0.0023 - val_loss: 0.0324 - val_mean_squared_error: 0.0324
#  20% |##############                                                          |
# RUN:3
# Epoch 1/100
# 112/112 [==============================] - 2s 15ms/step - loss: 0.0023 - mean_squared_error: 0.0023 - val_loss: 0.0327 - val_mean_squared_error: 0.0327
# Epoch 2/100
# 112/112 [==============================] - 2s 15ms/step - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0323 - val_mean_squared_error: 0.0323
# Epoch 3/100
# 112/112 [==============================] - 2s 15ms/step - loss: 0.0024 - mean_squared_error: 0.0024 - val_loss: 0.0328 - val_mean_squared_error: 0.0328
# Epoch 4/100
# 112/112 [==============================] - 2s 15ms/step - loss: 0.0022 - mean_squared_error: 0.0022 - val_loss: 0.0324 - val_mean_squared_error: 0.0324
# Epoch 5/100
# 112/112 [==============================] - 2s 15ms/step - loss: 0.0022 - mean_squared_error: 0.0022 - val_loss: 0.0334 - val_mean_squared_error: 0.0334
# Epoch 6/100
# 112/112 [==============================] - 2s 15ms/step - loss: 0.0023 - mean_squared_error: 0.0023 - val_loss: 0.0330 - val_mean_squared_error: 0.0330
# Epoch 7/100
# 112/112 [==============================] - 2s 15ms/step - loss: 0.0028 - mean_squared_error: 0.0028 - val_loss: 0.0326 - val_mean_squared_error: 0.0326
# Epoch 8/100
# 112/112 [==============================] - 2s 14ms/step - loss: 0.0022 - mean_squared_error: 0.0022 - val_loss: 0.0329 - val_mean_squared_error: 0.0329
# Epoch 9/100
# 112/112 [==============================] - 2s 14ms/step - loss: 0.0021 - mean_squared_error: 0.0021 - val_loss: 0.0326 - val_mean_squared_error: 0.0326
# Epoch 10/100
# 112/112 [==============================] - 2s 14ms/step - loss: 0.0021 - mean_squared_error: 0.0021 - val_loss: 0.0329 - val_mean_squared_error: 0.0329
# Epoch 11/100
# 112/112 [==============================] - 2s 14ms/step - loss: 0.0021 - mean_squared_error: 0.0021 - val_loss: 0.0328 - val_mean_squared_error: 0.0328
# Epoch 12/100
# 112/112 [==============================] - 2s 15ms/step - loss: 0.0021 - mean_squared_error: 0.0021 - val_loss: 0.0328 - val_mean_squared_error: 0.0328
#  30% |#####################                                                   |
# RUN:4
# Epoch 1/100
# 112/112 [==============================] - 2s 17ms/step - loss: 0.0021 - mean_squared_error: 0.0021 - val_loss: 0.0322 - val_mean_squared_error: 0.0322
# Epoch 2/100
# 112/112 [==============================] - 2s 15ms/step - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0327 - val_mean_squared_error: 0.0327
# Epoch 3/100
# 112/112 [==============================] - 2s 15ms/step - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0318 - val_mean_squared_error: 0.0318
# Epoch 4/100
# 112/112 [==============================] - 2s 14ms/step - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0324 - val_mean_squared_error: 0.0324
# Epoch 5/100
# 112/112 [==============================] - 2s 15ms/step - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0327 - val_mean_squared_error: 0.0327
# Epoch 6/100
# 112/112 [==============================] - 2s 15ms/step - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0327 - val_mean_squared_error: 0.0327
# Epoch 7/100
# 112/112 [==============================] - 2s 15ms/step - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0327 - val_mean_squared_error: 0.0327
# Epoch 8/100
# 112/112 [==============================] - 2s 15ms/step - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0323 - val_mean_squared_error: 0.0323
# Epoch 9/100
# 112/112 [==============================] - 2s 15ms/step - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0332 - val_mean_squared_error: 0.0332
# Epoch 10/100
# 112/112 [==============================] - 2s 14ms/step - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 0.0333 - val_mean_squared_error: 0.0333
# Epoch 11/100
# 112/112 [==============================] - 2s 15ms/step - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 0.0328 - val_mean_squared_error: 0.0328
# Epoch 12/100
# 112/112 [==============================] - 2s 15ms/step - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 0.0328 - val_mean_squared_error: 0.0328
# Epoch 13/100
# 112/112 [==============================] - 2s 15ms/step - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 0.0323 - val_mean_squared_error: 0.0323
#  40% |############################                                            |
# RUN:5
# Epoch 1/100
# 112/112 [==============================] - 2s 15ms/step - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 0.0328 - val_mean_squared_error: 0.0328
# Epoch 2/100
# 112/112 [==============================] - 2s 16ms/step - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 0.0329 - val_mean_squared_error: 0.0329
# Epoch 3/100
# 112/112 [==============================] - 2s 15ms/step - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 0.0337 - val_mean_squared_error: 0.0337
# Epoch 4/100
# 112/112 [==============================] - 2s 15ms/step - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 0.0328 - val_mean_squared_error: 0.0328
# Epoch 5/100
# 112/112 [==============================] - 2s 15ms/step - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 0.0326 - val_mean_squared_error: 0.0326
# Epoch 6/100
# 112/112 [==============================] - 2s 14ms/step - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0330 - val_mean_squared_error: 0.0330
# Epoch 7/100
# 112/112 [==============================] - 2s 14ms/step - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0328 - val_mean_squared_error: 0.0328
# Epoch 8/100
# 112/112 [==============================] - 2s 15ms/step - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0333 - val_mean_squared_error: 0.0333
# Epoch 9/100
# 112/112 [==============================] - 2s 16ms/step - loss: 0.0034 - mean_squared_error: 0.0034 - val_loss: 0.0317 - val_mean_squared_error: 0.0317
# Epoch 10/100
# 112/112 [==============================] - 2s 15ms/step - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0327 - val_mean_squared_error: 0.0327
# Epoch 11/100
# 112/112 [==============================] - 2s 15ms/step - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0321 - val_mean_squared_error: 0.0321
# Epoch 12/100
# 112/112 [==============================] - 2s 15ms/step - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0327 - val_mean_squared_error: 0.0327
# Epoch 13/100
# 112/112 [==============================] - 2s 15ms/step - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0320 - val_mean_squared_error: 0.0320
# Epoch 14/100
# 112/112 [==============================] - 2s 15ms/step - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0323 - val_mean_squared_error: 0.0323
# Epoch 15/100
# 112/112 [==============================] - 2s 15ms/step - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0329 - val_mean_squared_error: 0.0329
# Epoch 16/100
# 112/112 [==============================] - 2s 15ms/step - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0327 - val_mean_squared_error: 0.0327
# Epoch 17/100
# 112/112 [==============================] - 2s 15ms/step - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0333 - val_mean_squared_error: 0.0333
# Epoch 18/100
# 112/112 [==============================] - 2s 15ms/step - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0326 - val_mean_squared_error: 0.0326
# Epoch 19/100
# 112/112 [==============================] - 2s 15ms/step - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0325 - val_mean_squared_error: 0.0325
#  50% |####################################                                    |
# RUN:6
# Epoch 1/100
# 112/112 [==============================] - 2s 15ms/step - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0330 - val_mean_squared_error: 0.0330
# Epoch 2/100
# 112/112 [==============================] - 2s 15ms/step - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0328 - val_mean_squared_error: 0.0328
# Epoch 3/100
# 112/112 [==============================] - 2s 14ms/step - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0333 - val_mean_squared_error: 0.0333
# Epoch 4/100
# 112/112 [==============================] - 2s 15ms/step - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0324 - val_mean_squared_error: 0.0324
# Epoch 5/100
# 112/112 [==============================] - 2s 15ms/step - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0327 - val_mean_squared_error: 0.0327
# Epoch 6/100
# 112/112 [==============================] - 2s 16ms/step - loss: 0.0028 - mean_squared_error: 0.0028 - val_loss: 0.0342 - val_mean_squared_error: 0.0342
# Epoch 7/100
# 112/112 [==============================] - 2s 15ms/step - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 0.0354 - val_mean_squared_error: 0.0354
# Epoch 8/100
# 112/112 [==============================] - 2s 14ms/step - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0332 - val_mean_squared_error: 0.0332
# Epoch 9/100
# 112/112 [==============================] - 2s 15ms/step - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0332 - val_mean_squared_error: 0.0332
# Epoch 10/100
# 112/112 [==============================] - 2s 15ms/step - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0330 - val_mean_squared_error: 0.0330
# Epoch 11/100
# 112/112 [==============================] - 2s 15ms/step - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0321 - val_mean_squared_error: 0.0321
# Epoch 12/100
# 112/112 [==============================] - 2s 15ms/step - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0326 - val_mean_squared_error: 0.0326
# Epoch 13/100
# 112/112 [==============================] - 2s 15ms/step - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0325 - val_mean_squared_error: 0.0325
# Epoch 14/100
# 112/112 [==============================] - 2s 15ms/step - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0327 - val_mean_squared_error: 0.0327
# Epoch 15/100
# 112/112 [==============================] - 2s 14ms/step - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0328 - val_mean_squared_error: 0.0328
# Epoch 16/100
# 112/112 [==============================] - 2s 14ms/step - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0328 - val_mean_squared_error: 0.0328
# Epoch 17/100
# 112/112 [==============================] - 2s 15ms/step - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0335 - val_mean_squared_error: 0.0335
# Epoch 18/100
# 112/112 [==============================] - 2s 16ms/step - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0328 - val_mean_squared_error: 0.0328
# Epoch 19/100
# 112/112 [==============================] - 2s 15ms/step - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0329 - val_mean_squared_error: 0.0329
# Epoch 20/100
# 112/112 [==============================] - 2s 14ms/step - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0327 - val_mean_squared_error: 0.0327
# Epoch 21/100
# 112/112 [==============================] - 2s 14ms/step - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0330 - val_mean_squared_error: 0.0330
#  60% |###########################################                             |
# RUN:7
# Epoch 1/100
# 112/112 [==============================] - 2s 15ms/step - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0327 - val_mean_squared_error: 0.0327
# Epoch 2/100
# 112/112 [==============================] - 2s 16ms/step - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0334 - val_mean_squared_error: 0.0334
# Epoch 3/100
# 112/112 [==============================] - 2s 16ms/step - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0326 - val_mean_squared_error: 0.0326
# Epoch 4/100
# 112/112 [==============================] - 2s 15ms/step - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0335 - val_mean_squared_error: 0.0335
# Epoch 5/100
# 112/112 [==============================] - 2s 16ms/step - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0331 - val_mean_squared_error: 0.0331
# Epoch 6/100
# 112/112 [==============================] - 2s 16ms/step - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0333 - val_mean_squared_error: 0.0333
# Epoch 7/100
# 112/112 [==============================] - 2s 16ms/step - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0331 - val_mean_squared_error: 0.0331
# Epoch 8/100
# 112/112 [==============================] - 2s 16ms/step - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0330 - val_mean_squared_error: 0.0330
# Epoch 9/100
# 112/112 [==============================] - 2s 15ms/step - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0332 - val_mean_squared_error: 0.0332
# Epoch 10/100
# 112/112 [==============================] - 2s 14ms/step - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0332 - val_mean_squared_error: 0.0332
# Epoch 11/100
# 112/112 [==============================] - 2s 15ms/step - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0333 - val_mean_squared_error: 0.0333
# Epoch 12/100
# 112/112 [==============================] - 2s 15ms/step - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0334 - val_mean_squared_error: 0.0334
# Epoch 13/100
# 112/112 [==============================] - 2s 15ms/step - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0327 - val_mean_squared_error: 0.0327
#  70% |##################################################                      |
# RUN:8
# Epoch 1/100
# 112/112 [==============================] - 2s 14ms/step - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0336 - val_mean_squared_error: 0.0336
# Epoch 2/100
# 112/112 [==============================] - 2s 14ms/step - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0331 - val_mean_squared_error: 0.0331
# Epoch 3/100
# 112/112 [==============================] - 2s 15ms/step - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0334 - val_mean_squared_error: 0.0334
# Epoch 4/100
# 112/112 [==============================] - 2s 15ms/step - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 0.0327 - val_mean_squared_error: 0.0327
# Epoch 5/100
# 112/112 [==============================] - 2s 14ms/step - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 0.0329 - val_mean_squared_error: 0.0329
# Epoch 6/100
# 112/112 [==============================] - 2s 15ms/step - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0337 - val_mean_squared_error: 0.0337
# Epoch 7/100
# 112/112 [==============================] - 2s 15ms/step - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 0.0324 - val_mean_squared_error: 0.0324
# Epoch 8/100
# 112/112 [==============================] - 2s 15ms/step - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 0.0328 - val_mean_squared_error: 0.0328
# Epoch 9/100
# 112/112 [==============================] - 2s 15ms/step - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 0.0331 - val_mean_squared_error: 0.0331
# Epoch 10/100
# 112/112 [==============================] - 2s 15ms/step - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0331 - val_mean_squared_error: 0.0331
# Epoch 11/100
# 112/112 [==============================] - 2s 16ms/step - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0340 - val_mean_squared_error: 0.0340
# Epoch 12/100
# 112/112 [==============================] - 2s 15ms/step - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0342 - val_mean_squared_error: 0.0342
# Epoch 13/100
# 112/112 [==============================] - 2s 14ms/step - loss: 0.0023 - mean_squared_error: 0.0023 - val_loss: 0.0341 - val_mean_squared_error: 0.0341
# Epoch 14/100
# 112/112 [==============================] - 2s 14ms/step - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0332 - val_mean_squared_error: 0.0332
# Epoch 15/100
# 112/112 [==============================] - 2s 15ms/step - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0332 - val_mean_squared_error: 0.0332
# Epoch 16/100
# 112/112 [==============================] - 2s 15ms/step - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 0.0335 - val_mean_squared_error: 0.0335
# Epoch 17/100
# 112/112 [==============================] - 2s 15ms/step - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 0.0341 - val_mean_squared_error: 0.0341
#  80% |#########################################################               |
# RUN:9
# Epoch 1/100
# 112/112 [==============================] - 2s 15ms/step - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 0.0332 - val_mean_squared_error: 0.0332
# Epoch 2/100
# 112/112 [==============================] - 2s 15ms/step - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 0.0338 - val_mean_squared_error: 0.0338
# Epoch 3/100
#  25/112 [=====>........................] - ETA: 1s - loss: 0.0015 - mean_squared_error: 0.0015

# %%
NUM_CELLS = 32
MAX_EPOCHS = 100
BATCHSIZE = 32
patience = 10
HORIZON = 24
# ConditionalRNN with the functional API.
#i = Input(shape=[HORIZON, 5], name='time-series')
#c1 = Input(shape=[8], name='one-hot')
#c2 = Input(shape=[2], name='lags-as-features')
# add the condition tensor here.
#x = ConditionalRNN(NUM_CELLS, cell='LSTM', name='cond_rnn_0')([i, c1, c2])
# Dense layer to output
#x = Dense(HORIZON)(x)
#ConditionalRNN = Model(inputs=[i, c1, c2], outputs=[x])

ConditionalRNN = Sequential(layers=[ConditionalRNN(32, cell='LSTM'),
                                    Dense(HORIZON)])

metrics = pd.DataFrame(columns=['mae','rmse', 'B'], index=range(len(datasets)))
from progressbar import ProgressBar
pbar = ProgressBar()
for i,df in enumerate(datasets):
    train_inputs, test_inputs, train_c1, test_c1, train_c2, test_c2, y_scaler = ConditionalRNN_data_preparation(df)
    # full data LSTM MIMO compilation and fit
    ConditionalRNN.compile(optimizer=tf.optimizers.Adam(), loss='mse', metrics=[tf.metrics.MeanSquaredError()])
    early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=patience, mode='min')
    for j in pbar(range(1,11)):
        history = ConditionalRNN.fit([train_inputs['X'],train_c1,train_c2], train_inputs['target'], batch_size=32, epochs=MAX_EPOCHS,
                      validation_split=0.15,
                      callbacks=[early_stopping], verbose=1)

        #save_model(ConditionalRNN, i)
        predictions = ConditionalRNN.predict([test_inputs['X'],test_c1,test_c2])
        eval_df = create_evaluation_df(predictions, test_inputs, HORIZON, y_scaler)
        mae = validation(eval_df['prediction'], eval_df['actual'], 'MAE')
        rmse = validation(eval_df['prediction'], eval_df['actual'], 'RMSE')
    #print('rmse {}'.format(rmse))
        metrics.loc[10*i + j] = pd.Series({'mae':mae, 'rmse':rmse, 'B': names[i]})
metrics.to_csv('./results/GEP/ConditionalRNN10_sequential.csv')

# %%
MAX_EPOCHS = 100
BATCHSIZE = 32
patience = 10
HORIZON = 24

LSTMIMO = tf.keras.models.Sequential([
    # Shape [batch, time, features] => [batch, time, lstm_units]
    tf.keras.layers.LSTM(32, input_shape=(24, 5)),
    # Shape => [batch, time, features]
    tf.keras.layers.Dense(HORIZON)
])

metrics = pd.DataFrame(columns=['mae','rmse', 'B'], index=range(len(datasets)))
from progressbar import ProgressBar
pbar = ProgressBar()
for i,df in enumerate(datasets):
    train_inputs, test_inputs, _, _, _, _, y_scaler = ConditionalRNN_data_preparation(df)
    # full data LSTM MIMO compilation and fit
    LSTMIMO.compile(optimizer=tf.optimizers.Adam(), loss='mse', metrics=[tf.metrics.MeanSquaredError()])

    early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=patience, mode='min')
    
    for j in range(1,11):
        history = LSTMIMO.fit(train_inputs['X'], train_inputs['target'], batch_size=32, epochs=MAX_EPOCHS,
                      validation_split=0.15,
                      callbacks=[early_stopping], verbose=1)

        FD_predictions = LSTMIMO.predict(test_inputs['X'])
        FD_eval_df = create_evaluation_df(FD_predictions, test_inputs, HORIZON, y_scaler)
        mae = validation(FD_eval_df['prediction'], FD_eval_df['actual'], 'MAE')
        rmse = validation(FD_eval_df['prediction'], FD_eval_df['actual'], 'RMSE')
        #print('rmse {}'.format(rmse))
        metrics.loc[10*i + j] = pd.Series({'mae':mae, 'rmse':rmse, 'B': names[i]})
metrics.to_csv('./results/GEP/LSTM_MIMO10.csv')

# %%
def train_test_split(df, n_test):
    test_df = df.copy()[-n_test:]
    train_df = df.copy()[:len(test_df)]
    return train_df, test_df

# %%
def ConditionalRNN_data_preparation(df, n_test=4380, T=24, HORIZON=24):
    df = src.preprocessing.preprocess(df, 'Canada')
    c2 = series_to_supervised(df)
    c1 = df.iloc[:,1:9]
    c1 = c1.loc[c2.index]
    short_df = df.iloc[:,[0,1,-4,-3,-2,-1]].copy()
    #check how to formulate more correctly
    short_df = short_df[146:]
    train_df, test_df = train_test_split(short_df, n_test)
    train_c1, test_c1 = train_test_split(c1, n_test)
    train_c2, test_c2 = train_test_split(c2, n_test)
    y_scaler = MinMaxScaler()
    y_scaler.fit(train_df[['value']])
    train_c2[['value(t-24)']] = y_scaler.fit_transform(train_c2[['value(t-24)']])
    train_c2[['value(t-168)']] = y_scaler.fit_transform(train_c2[['value(t-168)']])
    X_scaler = MinMaxScaler()
    train_df[train_df.columns] = X_scaler.fit_transform(train_df)
    test_df[train_df.columns] = X_scaler.fit_transform(test_df)
    tensor_structure = {'X':(range(-T+1, 1), ['value','fractional hour_sin','fractional hour_cos','day of year_sin','day of year_cos'])}
    train_inputs = TimeSeriesTensor(train_df, 'value', HORIZON, tensor_structure)
    test_inputs = TimeSeriesTensor(test_df, 'value', HORIZON, tensor_structure)
    train_c1 = c1.reindex(train_inputs.dataframe.index)
    train_c2 = c2.reindex(train_inputs.dataframe.index)
    test_c1 = c1.reindex(test_inputs.dataframe.index)
    test_c2 = c2.reindex(test_inputs.dataframe.index)
    return train_inputs, test_inputs, train_c1, test_c1, train_c2, test_c2, y_scaler

# %%
def MIMO_fulldata_preparation(df, n_test=4380, T=24, HORIZON=24):
    df = src.preprocessing.preprocess(df, 'Canada')
    df = df.merge(series_to_supervised(df), how='right', left_index=True, right_index=True)
    train_df, test_df = train_test_split(df, n_test)
    y_scaler = MinMaxScaler()
    y_scaler.fit(train_df[['value']])
    long_scaler = MinMaxScaler()
    test_df[test_df.columns] = long_scaler.fit_transform(test_df)
    train_df[train_df.columns] = long_scaler.fit_transform(train_df)
    tensor_structure = {'X':(range(-T+1, 1), train_df.columns)}
    train_inputs = TimeSeriesTensor(train_df, 'value', HORIZON, tensor_structure)
    test_inputs = TimeSeriesTensor(test_df, 'value', HORIZON, tensor_structure)
    return train_inputs, test_inputs, y_scaler
