# %%
import pandas as pd
import numpy as np
import datetime as dt
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
from workalendar.america import Canada
import itertools
import sys
# Deep learning: 
import tensorflow as tf
from tensorboard.plugins.hparams import api as hp
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.callbacks import CSVLogger
from tensorflow.keras.models import model_from_json
import itertools
from sklearn.preprocessing import MinMaxScaler
np.set_printoptions(threshold=sys.maxsize)

DAYS_IN_YEAR = 365
HOURS_IN_DAY = 24
MINUTES_IN_HOUR = 60
SECONDS_IN_MINUTE = 60
MINUTES_IN_DAY = MINUTES_IN_HOUR * HOURS_IN_DAY

# %%
class DeepModelTS():
    """
    A class to create a deep time series model
    """
    def __init__(
        self, 
        data_path: str,
        Y_var: str,
        model_save: str,
        model_load: str,
        granularity: str,
        export_file_path: str,
        lag: int,
        lag2: int,
        LSTM_layer_depth: int, 
        epochs=10, 
        batch_size=256,
        train_test_split=0,
        n_test = 96,
    ):
        
        self.data_path = data_path
        self.model_save = model_save
        self.model_load = model_load
        self.granularity = granularity
        self.export_file_path = export_file_path
        self.Y_var = Y_var 
        self.lag = lag 
        self.lag2 = lag2
        self.LSTM_layer_depth = LSTM_layer_depth
        self.batch_size = batch_size
        self.epochs = epochs
        self.train_test_split = train_test_split
        self.n_test = n_test
        self.data = pd.read_csv(data_path, index_col=0)
        self.data = self.preprocess(self.data)
    
    @classmethod
    def get_fractional_hour_from_series(self, series: pd.Series) -> pd.Series:
        """
        Return fractional hour in range 0-24, e.g. 12h30m --> 12.5.
        Accurate to 1 minute.
        """
        hour = series.hour
        minute = series.minute
        return hour + minute / MINUTES_IN_HOUR

    @classmethod
    def get_fractional_day_from_series(self, series: pd.Series) -> pd.Series:
        """
        Return fractional day in range 0-1, e.g. 12h30m --> 0.521.
        Accurate to 1 minute
        """
        fractional_hours = self.get_fractional_hour_from_series(series)
        return fractional_hours / HOURS_IN_DAY

    @classmethod
    def get_fractional_year_from_series(self, series: pd.Series) -> pd.Series:
        """
        Return fractional year in range 0-1.
        Accurate to 1 day
        """
        return (series.dayofyear - 1) / DAYS_IN_YEAR

    def preprocess(self, dataframe):
        dataframe.index = pd.to_datetime(dataframe.index)
        # Removing duplicates
        dataframe = dataframe[~dataframe.index.duplicated()]
        
        #Filling NaN values
        dataframe = dataframe.interpolate()
        
        # Setting the calendar holidats
        cal = Canada()
        years = list(range(2014, 2025))
        holidays = []
        for year in years:
            holidays.extend(cal.holidays(year))
            
        dataframe = dataframe.sort_index()

        # Rename the target column to 'Valeur' for convenience
        dataframe.rename(columns={dataframe.columns[0]: self.Y_var}, inplace=True)
        
        #working day {0,1}
        dataframe['working day'] = dataframe.index.map(cal.is_working_day).astype(np.float32)
        
        #fractional hour [0,1]
        dataframe['fractional hour'] = self.get_fractional_day_from_series(dataframe.index)
        
        # day of week one-hot encoded
        dataframe['day of week'] = dataframe.index.dayofweek + 1
        dataframe = pd.get_dummies(dataframe,prefix=['week'], columns = ['day of week'], drop_first=False)
        
        # fractional day of year
        dataframe['day of year'] = self.get_fractional_year_from_series(dataframe.index)
        
        # we encode cynical data into two dimensions using a sine and cosine transformations
        def encode(data, col, max_val):
            data[col + '_sin'] = np.sin(2 * np.pi * data[col]/max_val)
            data[col + '_cos'] = np.cos(2 * np.pi * data[col]/max_val)
            return data
        dataframe = encode(dataframe, 'fractional hour', HOURS_IN_DAY)
        dataframe = encode(dataframe, 'day of year', DAYS_IN_YEAR)
        # dropping original columns
        dataframe = dataframe.drop(['fractional hour','day of year'], axis=1)
        return dataframe
    
    @staticmethod    
    def plot_train_history(model):
        '''
        Convergence plots to have an idea on how the training performs
        '''
        loss = model.history.history['loss']
        val_loss = model.history.history['val_loss']
        plt.figure()
        plt.plot(range(len(loss)), loss, 'b', label='Training loss')
        plt.plot(range(len(val_loss)), val_loss, 'r', label='Validation loss')
        #plt.yscale("log")
        plt.xlabel('Epochs')
        plt.ylabel('Losses')
        plt.title('Training and validation losses')
        plt.legend()
        plt.show() 
    
    @staticmethod
    def validation(forecasted, real, parameter):
        ''' 
        compute some important parameters to compare forecasting results
        '''
        value = 0
        value_1 = 0
        value_2 = 0

        if parameter == 'SMAPE':
            for i in range(len(forecasted)):
                if real[i] + forecasted[i] == 0:
                    value += 0
                else: 
                    value += ((abs(real[i] - forecasted[i])) / (real[i] + forecasted[i])) * 100
            final_value = value / len(forecasted)  

        elif parameter == 'MAPE':
            for i in range(len(forecasted)):
                if real[i] == 0:
                    value += 0
                else: 
                    value += (abs(real[i] - forecasted[i]))/real[i]
            final_value = value / len(forecasted) * 100

        elif parameter == 'RMSE':
            for i in range(len(forecasted)):
                value += (real[i] - forecasted[i]) ** 2
            final_value = (value / len(forecasted)) ** (1 / 2) 

        elif parameter == 'R':
            for i in range(len(forecasted)):
                value += (real[i] - np.mean(real)) * (forecasted[i] - np.mean(forecasted))
                value_1 += (real[i] - np.mean(real)) ** 2
                value_2 += (forecasted[i] - np.mean(forecasted)) ** 2

            if value_1 == 0 or value_2 == 0:
                final_value = 100
            else:
                final_value = (value / ((value_1 ** (1 / 2)) * (value_2 ** (1 / 2))))*100

        return final_value
    
    def normalize(self, tensor):
        self.scaler = MinMaxScaler(feature_range=(0, 1))
        tensor = self.scaler.fit_transform(tensor)
        return tensor
    
    def denormalize(self, tensor):
        tensor = self.scaler.inverse_transform(tensor)
        return tensor      

    # convert series to supervised learning
    def series_to_supervised(self, data, dropnan=True):
        n_vars = 1
        df = pd.DataFrame(data)
        cols, names = list(), list()
        # input sequence (t-n, ... t-1)
        for i in [self.lag, self.lag2]:
            cols.append(df[self.Y_var].shift(i))
            names += [(self.Y_var+'(t-%d)' % (i))]
        # put it all together
        agg = pd.concat(cols, axis=1)
        agg.columns = names
        # drop rows with NaN values
        if dropnan:
            agg.dropna(inplace=True)
        return agg   
    
    def create_data_for_NN(self):
        reframed = self.data.merge(self.series_to_supervised(self.data), how='right', left_index=True, right_index=True)
        #print(reframed.head())
        # Normalize with a MinMax Scaler
        reframed = self.normalize(reframed)
        #reframed = np.array(reframed)
        #print(reframed[:10])
                
        test = reframed[-self.n_test:]
        index = len(reframed) - self.n_test
        train = reframed[:round(index * (1-self.train_test_split))]
        if self.train_test_split > 0:
            val = reframed[round(index * (1-self.train_test_split)):index]
            
        X_train, Y_train = train[:, 1:], train[:, 0]
        if self.train_test_split > 0:
            X_val, Y_val = val[:, 1:], val[:, 0]
        X_test, Y_test = test[:, 1:], test[:, 0]
        
        #print(X_train[:10])
        
        X_train = X_train.reshape((X_train.shape[0], 1, X_train.shape[1]))
        if self.train_test_split > 0:
            X_val = X_val.reshape((X_val.shape[0], 1, X_val.shape[1]))
        #print(X_test.shape)
        X_test = X_test.reshape((X_test.shape[0], 1, X_test.shape[1]))
        #print(X_train.shape, Y_train.shape, X_test.shape, Y_test.shape)
        
        return X_train, X_val, X_test, Y_train, Y_val, Y_test
    
    def save_model(self, model):
        model_json = model.to_json()
        with open(self.model_save+'.json', "w") as json_file:
            json_file.write(model_json)
        # serialize weights to HDF5
        model.save_weights(self.model_save+'.h5')
        print("Model saved to disk")
          
    def load_model(self):
        # load json and create model
        json_file = open(self.model_load+".json", 'r')
        loaded_model_json = json_file.read()
        json_file.close()
        self.model = model_from_json(loaded_model_json)
        # load weights into new model
        self.model.load_weights(self.model_load+".h5")
        print("Loaded model from disk")
    
    def LSTModel(self):
        """
        A method to fit the LSTM model 
        """
        # Getting the data 
        X_train, X_val, X_test, Y_train, Y_val, Y_test = self.create_data_for_NN()

        # Defining the model
        model = Sequential()
        model.add(LSTM(self.LSTM_layer_depth, activation='relu', return_sequences=True, input_shape=(X_train.shape[1],X_train.shape[2])))
        model.add(LSTM(self.LSTM_layer_depth, activation='relu'))
        model.add(tf.keras.layers.Dropout(0.2))
        model.add(Dense(1))
        model.compile(optimizer='adam', loss='mae')
        
        # Setting up early stopping
        earlyStop=EarlyStopping(monitor="val_loss",verbose=1,mode='min',patience=10)
        
        # Saving training history
        csv_logger = CSVLogger('training_B2_25ep.log', separator=',', append=False)
        
        # Defining the model parameter dict 
        keras_dict = {
            'x': X_train,
            'y': Y_train,
            'batch_size': self.batch_size,
            'epochs': self.epochs,
            'shuffle': False,
            #'callbacks': [earlyStop, csv_logger]
            'callbacks': [csv_logger]

        }

        if self.train_test_split > 0:
            keras_dict.update({
                'validation_data': (X_val, Y_val)
            })

        # Fitting the model 
        model.fit(
            **keras_dict
        )

        # Saving the model to the class 
        self.model = model
        # Plotting train history
        if self.train_test_split > 0:
            self.plot_train_history(model)
        # Saving the model in json and h5
        self.save_model(self.model)
        
        return model  

    def predict(self) -> list:
        """
        A method to predict using the test data used in creating the class
        """
        yhat = []

        # Getting the last n time series 
        _, _, X_test, _, _, Y_test = self.create_data_for_NN()
        
        # Making the prediction list 
        yhat = self.model.predict(X_test)

        # Reshape for merging with predictions
        X_test = X_test.reshape(X_test.shape[0], X_test.shape[2])

        # invert scaling for forecast
        inv_yhat = np.concatenate((yhat, X_test), axis=1)

        # denormalize
        inv_yhat = self.scaler.inverse_transform(inv_yhat)

        # invert scaling for actual
        Y_test = Y_test.reshape((len(Y_test), 1))
        inv_y = np.concatenate((Y_test, X_test), axis=1)

        # denormalize
        inv_y = self.scaler.inverse_transform(inv_y)
        
        act = [i[0] for i in inv_y] # last element is the predicted average energy
        pred = [i[0] for i in inv_yhat] # last element is the actual average energy

        return act, pred
    
    def results(self):
        expected, predictions = self.predict()# Constructing the forecast dataframe
        
        print('RMSE: %f [kWh]' % self.validation(predictions,expected, 'RMSE'))
        print('MAPE: %f %%' % self.validation(predictions,expected, 'MAPE'))
        print('\n')
    
    def plot_test(self):
        expected, predictions = self.predict()# Constructing the forecast dataframe      
        fc = self.data.tail(len(expected)).copy()
        print('RMSE: %f [kWh]' % self.validation(predictions,expected, 'RMSE'))
        print('MAPE: %f %%' % self.validation(predictions,expected, 'MAPE'))
        # Ploting the forecasts
        plt.figure(figsize=(12, 8))
        #for dtype in ['Valeur', 'forecast']:  
        plt.plot(fc.index, expected, label='Valeur',alpha=0.7)
        plt.plot(fc.index, predictions, label='forecast',alpha=0.7)
        plt.legend()
        plt.grid()

        plt.gca().set(ylabel='Consumption [kWh]', xlabel='timestamp')
        plt.yticks(fontsize=12, alpha=.7)
        plt.title("Consumption for test data", fontsize=20)

        plt.show()
    
    def predict_n_ahead(self, data_input, n_ahead: int):
        # Set up a dataset with next n timestamps
        dates = pd.date_range(data_input.index[-1], periods = n_ahead+1, freq=self.granularity)[1:]
        test = data_input.append(pd.DataFrame(index=dates))
        test.index=data_input.index.union(dates)

        # Add all temporal features
        test = self.preprocess(test)
        
        # Merge temporal features with lags
        test = test.merge(self.series_to_supervised(test), how='right', left_index=True, right_index=True)
        
        # Normalize with a MinMax scaler
        test = self.normalize(test)
        
        # Take out the forecasted metric
        test = test[:, 1:]
        
        # Reshape the tensor to LSTM input
        test = test.reshape((test.shape[0], 1, test.shape[1]))
        
        # Forecast for n_ahead steps ahead
        yhat = []
        yhat = self.model.predict(test)
        
        # Reshape for merging with predictions
        test = test.reshape(test.shape[0], test.shape[2])
        
        # invert scaling for forecast
        inv_yhat = np.concatenate((yhat, test), axis=1)
        
        # denormalize
        inv_yhat = self.scaler.inverse_transform(inv_yhat)
        
        yhat = [i[0] for i in inv_yhat] # last element is the predicted average energy
        return yhat[-n_ahead:]
    
    def evaluate_n_ahead(self, data_temp, n_ahead: int):
        # take the user input dataset as the one we predict ahead for
        yhat = []
        predictions = []
        data_temp.index = pd.to_datetime(data_temp.index)
        # Load model if no preloaded
        if hasattr('self', 'model') == False:
            self.load_model()
        # Slide through the dataset by window of 96 steps and refeed the predictions into inputs
        for i in tf.range(n_ahead//self.lag+1):
            y_hat = self.predict_n_ahead(data_temp, self.lag)
            data_temp = data_temp.append(pd.DataFrame(y_hat, columns=['Valeur'], index=pd.date_range(data_temp.index[-1], periods = self.lag+1, freq=self.granularity)[1:]))
            data_temp.drop(data_temp.head(self.lag).index, inplace=True)
            predictions.extend(y_hat)
        # Create a dataset for predictions
        predictions = predictions[:n_ahead]
        dates = pd.date_range(self.data_user.index[-1], periods = n_ahead+1, freq=self.granularity)[1:]
        #test = pd.DataFrame(predictions)
        #test.index = dates
        #test.index = pd.to_datetime(test.index)
        # Save to a csv
        test.to_csv(self.export_file_path, index=True)
        #expected = test_range.head(n_ahead).loc[:,"Valeur"]
        
        #predictions = test.iloc[:,0]
        #print('RMSE: %f [kWh]' % self.validation(predictions,expected, 'RMSE'))
        #print('MAPE: %f %%' % self.validation(predictions,expected, 'MAPE'))
        plt.figure(figsize=(25, 10))
        plt.grid()
        plt.gca().set(ylabel='Consumption [kWh]', xlabel='timestamp')
        plt.yticks(fontsize=12, alpha=.7)
        plt.title("Consumption forecast for given days ahead", fontsize=20)
        #plt.plot(test_range.index, test_range.loc[:,"Valeur"], color='orange', label='test', alpha=0.7)
        plt.plot(self.data_user.index, self.data_user.loc[:,"Valeur"], color='b', label='user input data', alpha=0.5)
        plt.plot(dates, predictions, color='black', linestyle='--', linewidth=3, label='Forecaster model',alpha=0.7)
        plt.legend(prop={'size': 20})
        return test

# %%
deep_learner = DeepModelTS(
# USER INPUT SETTINGS
Y_var = 'Valeur',
model_load = "model_B1_complete",
granularity = '15T',
export_file_path = './predictions.csv',
# TRAINING SETTINGS
data_path = '../data/Columbia_clean/Residential_18.csv',
#data_path = 'Consumption_15min.csv',
#data = holidata,
model_save = "model_B1_complete",
lag = 24,
lag2 = 168,
LSTM_layer_depth = 64,
epochs = 100,
batch_size = 128,
train_test_split = 0.15,
n_test = 168*2
)

# %%
model = deep_learner.LSTModel()
# Out:
# Epoch 1/100
# 172/172 [==============================] - 1s 6ms/step - loss: 0.9800 - val_loss: 1.0686
# Epoch 2/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.7719 - val_loss: 1.0236
# Epoch 3/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.7376 - val_loss: 0.9757
# Epoch 4/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.7216 - val_loss: 0.9651
# Epoch 5/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.7139 - val_loss: 0.9562
# Epoch 6/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.7149 - val_loss: 0.9517
# Epoch 7/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.7147 - val_loss: 0.9518
# Epoch 8/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.7132 - val_loss: 0.9448
# Epoch 9/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.7115 - val_loss: 0.9440
# Epoch 10/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.7117 - val_loss: 0.9433
# Epoch 11/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.7105 - val_loss: 0.9419
# Epoch 12/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.7102 - val_loss: 0.9444
# Epoch 13/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.7113 - val_loss: 0.9345
# Epoch 14/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.7096 - val_loss: 0.9364
# Epoch 15/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.7093 - val_loss: 0.9321
# Epoch 16/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.7087 - val_loss: 0.9316
# Epoch 17/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.7070 - val_loss: 0.9322
# Epoch 18/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.7068 - val_loss: 0.9336
# Epoch 19/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.7071 - val_loss: 0.9304
# Epoch 20/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.7068 - val_loss: 0.9262
# Epoch 21/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.7079 - val_loss: 0.9250
# Epoch 22/100
# 172/172 [==============================] - 1s 6ms/step - loss: 0.7063 - val_loss: 0.9263
# Epoch 23/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.7048 - val_loss: 0.9221
# Epoch 24/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.7048 - val_loss: 0.9240
# Epoch 25/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.7057 - val_loss: 0.9237
# Epoch 26/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.7037 - val_loss: 0.9215
# Epoch 27/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.7043 - val_loss: 0.9192
# Epoch 28/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.7040 - val_loss: 0.9196
# Epoch 29/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.7029 - val_loss: 0.9191
# Epoch 30/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.7041 - val_loss: 0.9191
# Epoch 31/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.7039 - val_loss: 0.9174
# Epoch 32/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.7019 - val_loss: 0.9179
# Epoch 33/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.7020 - val_loss: 0.9168
# Epoch 34/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.7022 - val_loss: 0.9154
# Epoch 35/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.7012 - val_loss: 0.9161
# Epoch 36/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.7029 - val_loss: 0.9152
# Epoch 37/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.7013 - val_loss: 0.9160
# Epoch 38/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.7026 - val_loss: 0.9158
# Epoch 39/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.7020 - val_loss: 0.9152
# Epoch 40/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.7016 - val_loss: 0.9150
# Epoch 41/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.7007 - val_loss: 0.9152
# Epoch 42/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.7014 - val_loss: 0.9153
# Epoch 43/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.7008 - val_loss: 0.9146
# Epoch 44/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.7014 - val_loss: 0.9148
# Epoch 45/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.7010 - val_loss: 0.9153
# Epoch 46/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.7009 - val_loss: 0.9147
# Epoch 47/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.7015 - val_loss: 0.9149
# Epoch 48/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.7011 - val_loss: 0.9146
# Epoch 49/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.7022 - val_loss: 0.9149
# Epoch 50/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.7022 - val_loss: 0.9148
# Epoch 51/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.7009 - val_loss: 0.9145
# Epoch 52/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.7013 - val_loss: 0.9144
# Epoch 53/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.7016 - val_loss: 0.9146
# Epoch 54/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.7010 - val_loss: 0.9145
# Epoch 55/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.7010 - val_loss: 0.9143
# Epoch 56/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.7009 - val_loss: 0.9143
# Epoch 57/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.7010 - val_loss: 0.9140
# Epoch 58/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.7005 - val_loss: 0.9146
# Epoch 59/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.7010 - val_loss: 0.9141
# Epoch 60/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.7004 - val_loss: 0.9142
# Epoch 61/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.7002 - val_loss: 0.9140
# Epoch 62/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.6998 - val_loss: 0.9136
# Epoch 63/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.7013 - val_loss: 0.9141
# Epoch 64/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.7012 - val_loss: 0.9136
# Epoch 65/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.6996 - val_loss: 0.9140
# Epoch 66/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.6995 - val_loss: 0.9138
# Epoch 67/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.7006 - val_loss: 0.9139
# Epoch 68/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.6999 - val_loss: 0.9138
# Epoch 69/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.6998 - val_loss: 0.9135
# Epoch 70/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.6993 - val_loss: 0.9135
# Epoch 71/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.6989 - val_loss: 0.9136
# Epoch 72/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.6984 - val_loss: 0.9137
# Epoch 73/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.6991 - val_loss: 0.9136
# Epoch 74/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.6998 - val_loss: 0.9134
# Epoch 75/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.6981 - val_loss: 0.9135
# Epoch 76/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.6991 - val_loss: 0.9137
# Epoch 77/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.6997 - val_loss: 0.9136
# Epoch 78/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.6983 - val_loss: 0.9132
# Epoch 79/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.6988 - val_loss: 0.9134
# Epoch 80/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.6993 - val_loss: 0.9128
# Epoch 81/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.6995 - val_loss: 0.9133
# Epoch 82/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.6997 - val_loss: 0.9129
# Epoch 83/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.6987 - val_loss: 0.9131
# Epoch 84/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.6988 - val_loss: 0.9129
# Epoch 85/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.6971 - val_loss: 0.9128
# Epoch 86/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.6986 - val_loss: 0.9131
# Epoch 87/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.6982 - val_loss: 0.9128
# Epoch 88/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.6985 - val_loss: 0.9129
# Epoch 89/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.6973 - val_loss: 0.9130
# Epoch 90/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.6987 - val_loss: 0.9130
# Epoch 91/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.6978 - val_loss: 0.9126
# Epoch 92/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.6984 - val_loss: 0.9126
# Epoch 93/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.6969 - val_loss: 0.9125
# Epoch 94/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.6981 - val_loss: 0.9127
# Epoch 95/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.6971 - val_loss: 0.9126
# Epoch 96/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.6976 - val_loss: 0.9129
# Epoch 97/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.6974 - val_loss: 0.9125
# Epoch 98/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.6970 - val_loss: 0.9127
# Epoch 99/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.6961 - val_loss: 0.9121
# Epoch 100/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.6965 - val_loss: 0.9123
# Model saved to disk

# %%
deep_learner.model = model

# %%
deep_learner.plot_test()
# Out:
# RMSE: 2.395431 [kWh]
# MAPE: 91.350667 %

# %%
i = 27
filename = '../data/Columbia_clean'+'/Residential_'+str(i)+'.csv'
data27 = pd.read_csv(filename, index_col=0)
data27 = data27[-168:]
data27
# Out:
#                      energy_kWh
# 2020-05-14 00:00:00        0.31
# 2020-05-14 01:00:00        0.15
# 2020-05-14 02:00:00        0.17
# 2020-05-14 03:00:00        0.22
# 2020-05-14 04:00:00        0.15
# ...                         ...
# 2020-05-20 19:00:00        0.17
# 2020-05-20 20:00:00        0.19
# 2020-05-20 21:00:00        0.24
# 2020-05-20 22:00:00        0.23
# 2020-05-20 23:00:00        0.16
#
# [168 rows x 1 columns]

# %%
deep_learner.evaluate_n_ahead(data27, 72)
# Out:
# Loaded model from disk
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-2e3a0a7dab4b> in <module>
# ----> 1 deep_learner.evaluate_n_ahead(data27, 72)
#
# <ipython-input-18-5d6289698703> in evaluate_n_ahead(self, data_temp, n_ahead)
#     400         # Slide through the dataset by window of 96 steps and refeed the predictions into inputs
#     401         for i in tf.range(n_ahead//self.lag+1):
# --> 402             y_hat = self.predict_n_ahead(data_temp, self.lag)
#     403             data_temp = data_temp.append(pd.DataFrame(y_hat, columns=['Valeur'], index=pd.date_range(data_temp.index[-1], periods = self.lag+1, freq=self.granularity)[1:]))
#     404             data_temp.drop(data_temp.head(self.lag).index, inplace=True)
#
# <ipython-input-18-5d6289698703> in predict_n_ahead(self, data_input, n_ahead)
#     379
#     380         # Reshape for merging with predictions
# --> 381         test = test.reshape(X_test.shape[0], X_test.shape[2])
#     382
#     383         # invert scaling for forecast
#
# NameError: name 'X_test' is not defined

# %%
for i in range(1,28):
    filename = '/Residential_'+str(i)+'.csv'
    print('Loading data '+filename)
    print('\n')
    deep_learner.data_path = '../data/Columbia_clean'+filename
    deep_learner.data = pd.read_csv(deep_learner.data_path, index_col=0)
    deep_learner.data = deep_learner.preprocess(deep_learner.data)
    deep_learner.model_save = 'model_Columbia_B'+str(i)
    # Fitting the model
    model = deep_learner.LSTModel()
    
    original_stdout = sys.stdout # Save a reference to the original standard output
    with open('results_Columbia_lags.txt', 'a') as f:
        sys.stdout = f # Change the standard output to the file we created.
        print('Building B'+str(i)+':')
        deep_learner.results()        
        sys.stdout = original_stdout # Reset the standard output to its origin
# Out:
# Loading data /Residential_1.csv
#
#
# Epoch 1/100
# 191/191 [==============================] - 1s 6ms/step - loss: 0.0352 - val_loss: 0.0303
# Epoch 2/100
# 191/191 [==============================] - 1s 4ms/step - loss: 0.0324 - val_loss: 0.0312
# Epoch 3/100
# 191/191 [==============================] - 1s 4ms/step - loss: 0.0320 - val_loss: 0.0309
# Epoch 4/100
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0319 - val_loss: 0.0302
# Epoch 5/100
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0316 - val_loss: 0.0306
# Epoch 6/100
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0315 - val_loss: 0.0309
# Epoch 7/100
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0312 - val_loss: 0.0311
# Epoch 8/100
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0312 - val_loss: 0.0320
# Epoch 9/100
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0313 - val_loss: 0.0316
# Epoch 10/100
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0312 - val_loss: 0.0320
# Epoch 11/100
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0313 - val_loss: 0.0314
# Epoch 12/100
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0313 - val_loss: 0.0308
# Epoch 13/100
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0312 - val_loss: 0.0305
# Epoch 14/100
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0310 - val_loss: 0.0302
# Epoch 15/100
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0309 - val_loss: 0.0299
# Epoch 16/100
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0307 - val_loss: 0.0296
# Epoch 17/100
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0304 - val_loss: 0.0286
# Epoch 18/100
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0299 - val_loss: 0.0281
# Epoch 19/100
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0297 - val_loss: 0.0278
# Epoch 20/100
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0295 - val_loss: 0.0277
# Epoch 21/100
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0296 - val_loss: 0.0281
# Epoch 22/100
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0295 - val_loss: 0.0285
# Epoch 23/100
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0295 - val_loss: 0.0288
# Epoch 24/100
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0295 - val_loss: 0.0295
# Epoch 25/100
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0294 - val_loss: 0.0292
# Epoch 26/100
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0293 - val_loss: 0.0290
# Epoch 27/100
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0293 - val_loss: 0.0294
# Epoch 28/100
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0293 - val_loss: 0.0291
# Epoch 29/100
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0292 - val_loss: 0.0292
# Epoch 30/100
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0292 - val_loss: 0.0289
# Epoch 31/100
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0291 - val_loss: 0.0292
# Epoch 32/100
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0290 - val_loss: 0.0293
# Epoch 33/100
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0290 - val_loss: 0.0293
# Epoch 34/100
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0289 - val_loss: 0.0291
# Epoch 35/100
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0289 - val_loss: 0.0290
# Epoch 36/100
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0289 - val_loss: 0.0290
# Epoch 37/100
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0288 - val_loss: 0.0290
# Epoch 38/100
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0287 - val_loss: 0.0289
# Epoch 39/100
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0287 - val_loss: 0.0291
# Epoch 40/100
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0286 - val_loss: 0.0295
# Epoch 41/100
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0286 - val_loss: 0.0292
# Epoch 42/100
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0287 - val_loss: 0.0295
# Epoch 43/100
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0285 - val_loss: 0.0291
# Epoch 44/100
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0286 - val_loss: 0.0292
# Epoch 45/100
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0285 - val_loss: 0.0295
# Epoch 46/100
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0285 - val_loss: 0.0293
# Epoch 47/100
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0284 - val_loss: 0.0299
# Epoch 48/100
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0283 - val_loss: 0.0298
# Epoch 49/100
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0283 - val_loss: 0.0299
# Epoch 50/100
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0284 - val_loss: 0.0300
# Epoch 51/100
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0283 - val_loss: 0.0302
# Epoch 52/100
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0282 - val_loss: 0.0301
# Epoch 53/100
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0282 - val_loss: 0.0299
# Epoch 54/100
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0282 - val_loss: 0.0300
# Epoch 55/100
# 191/191 [==============================] - 1s 6ms/step - loss: 0.0281 - val_loss: 0.0299
# Epoch 56/100
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0282 - val_loss: 0.0300
# Epoch 57/100
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0281 - val_loss: 0.0304
# Epoch 58/100
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0281 - val_loss: 0.0302
# Epoch 59/100
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0281 - val_loss: 0.0308
# Epoch 60/100
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0281 - val_loss: 0.0300
# Epoch 61/100
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0280 - val_loss: 0.0299
# Epoch 62/100
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0280 - val_loss: 0.0303
# Epoch 63/100
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0281 - val_loss: 0.0302
# Epoch 64/100
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0280 - val_loss: 0.0301
# Epoch 65/100
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0279 - val_loss: 0.0295
# Epoch 66/100
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0280 - val_loss: 0.0298
# Epoch 67/100
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0279 - val_loss: 0.0304
# Epoch 68/100
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0280 - val_loss: 0.0304
# Epoch 69/100
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0279 - val_loss: 0.0299
# Epoch 70/100
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0279 - val_loss: 0.0300
# Epoch 71/100
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0278 - val_loss: 0.0300
# Epoch 72/100
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0279 - val_loss: 0.0296
# Epoch 73/100
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0279 - val_loss: 0.0299
# Epoch 74/100
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0279 - val_loss: 0.0299
# Epoch 75/100
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0278 - val_loss: 0.0299
# Epoch 76/100
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0278 - val_loss: 0.0297
# Epoch 77/100
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0278 - val_loss: 0.0295
# Epoch 78/100
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0278 - val_loss: 0.0298
# Epoch 79/100
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0278 - val_loss: 0.0295
# Epoch 80/100
# 191/191 [==============================] - 1s 6ms/step - loss: 0.0278 - val_loss: 0.0297
# Epoch 81/100
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0277 - val_loss: 0.0296
# Epoch 82/100
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0277 - val_loss: 0.0298
# Epoch 83/100
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0277 - val_loss: 0.0295
# Epoch 84/100
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0278 - val_loss: 0.0301
# Epoch 85/100
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0277 - val_loss: 0.0295
# Epoch 86/100
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0277 - val_loss: 0.0289
# Epoch 87/100
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0277 - val_loss: 0.0295
# Epoch 88/100
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0276 - val_loss: 0.0297
# Epoch 89/100
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0277 - val_loss: 0.0294
# Epoch 90/100
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0277 - val_loss: 0.0296
# Epoch 91/100
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0277 - val_loss: 0.0292
# Epoch 92/100
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0277 - val_loss: 0.0293
# Epoch 93/100
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0276 - val_loss: 0.0294
# Epoch 94/100
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0276 - val_loss: 0.0296
# Epoch 95/100
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0277 - val_loss: 0.0296
# Epoch 96/100
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0276 - val_loss: 0.0293
# Epoch 97/100
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0276 - val_loss: 0.0296
# Epoch 98/100
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0277 - val_loss: 0.0295
# Epoch 99/100
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0276 - val_loss: 0.0295
# Epoch 100/100
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0276 - val_loss: 0.0297
# Model saved to disk
# Loading data /Residential_2.csv
#
#
# Epoch 1/100
# 198/198 [==============================] - 1s 7ms/step - loss: 0.0375 - val_loss: 0.0347
# Epoch 2/100
# 198/198 [==============================] - 1s 5ms/step - loss: 0.0360 - val_loss: 0.0354
# Epoch 3/100
# 198/198 [==============================] - 1s 6ms/step - loss: 0.0353 - val_loss: 0.0354
# Epoch 4/100
# 198/198 [==============================] - 1s 5ms/step - loss: 0.0347 - val_loss: 0.0353
# Epoch 5/100
# 198/198 [==============================] - 1s 5ms/step - loss: 0.0343 - val_loss: 0.0351
# Epoch 6/100
# 198/198 [==============================] - 1s 5ms/step - loss: 0.0339 - val_loss: 0.0351
# Epoch 7/100
# 198/198 [==============================] - 1s 5ms/step - loss: 0.0335 - val_loss: 0.0343
# Epoch 8/100
# 198/198 [==============================] - 1s 5ms/step - loss: 0.0330 - val_loss: 0.0331
# Epoch 9/100
# 198/198 [==============================] - 1s 5ms/step - loss: 0.0327 - val_loss: 0.0325
# Epoch 10/100
# 198/198 [==============================] - 1s 5ms/step - loss: 0.0324 - val_loss: 0.0317
# Epoch 11/100
# 198/198 [==============================] - 1s 5ms/step - loss: 0.0322 - val_loss: 0.0318
# Epoch 12/100
# 198/198 [==============================] - 1s 5ms/step - loss: 0.0321 - val_loss: 0.0323
# Epoch 13/100
# 198/198 [==============================] - 1s 5ms/step - loss: 0.0320 - val_loss: 0.0321
# Epoch 14/100
# 198/198 [==============================] - 1s 5ms/step - loss: 0.0320 - val_loss: 0.0318
# Epoch 15/100
# 198/198 [==============================] - 1s 5ms/step - loss: 0.0318 - val_loss: 0.0327
# Epoch 16/100
# 198/198 [==============================] - 1s 5ms/step - loss: 0.0319 - val_loss: 0.0323
# Epoch 17/100
# 198/198 [==============================] - 1s 5ms/step - loss: 0.0318 - val_loss: 0.0323
# Epoch 18/100
# 198/198 [==============================] - 1s 5ms/step - loss: 0.0317 - val_loss: 0.0326
# Epoch 19/100
# 198/198 [==============================] - 1s 5ms/step - loss: 0.0317 - val_loss: 0.0324
# Epoch 20/100
# 198/198 [==============================] - 1s 5ms/step - loss: 0.0316 - val_loss: 0.0326
# Epoch 21/100
# 198/198 [==============================] - 1s 5ms/step - loss: 0.0316 - val_loss: 0.0334
# Epoch 22/100
# 198/198 [==============================] - 1s 5ms/step - loss: 0.0316 - val_loss: 0.0325
# Epoch 23/100
# 198/198 [==============================] - 1s 5ms/step - loss: 0.0315 - val_loss: 0.0331
# Epoch 24/100
# 198/198 [==============================] - 1s 5ms/step - loss: 0.0315 - val_loss: 0.0330
# Epoch 25/100
# 198/198 [==============================] - 1s 5ms/step - loss: 0.0314 - val_loss: 0.0327
# Epoch 26/100
# 198/198 [==============================] - 1s 5ms/step - loss: 0.0314 - val_loss: 0.0332
# Epoch 27/100
# 198/198 [==============================] - 1s 5ms/step - loss: 0.0313 - val_loss: 0.0329
# Epoch 28/100
# 198/198 [==============================] - 1s 5ms/step - loss: 0.0313 - val_loss: 0.0328
# Epoch 29/100
# 198/198 [==============================] - 1s 5ms/step - loss: 0.0313 - val_loss: 0.0330
# Epoch 30/100
# 198/198 [==============================] - 1s 5ms/step - loss: 0.0312 - val_loss: 0.0324
# Epoch 31/100
# 198/198 [==============================] - 1s 5ms/step - loss: 0.0311 - val_loss: 0.0324
# Epoch 32/100
# 198/198 [==============================] - 1s 5ms/step - loss: 0.0312 - val_loss: 0.0327
# Epoch 33/100
# 198/198 [==============================] - 1s 5ms/step - loss: 0.0311 - val_loss: 0.0326
# Epoch 34/100
# 198/198 [==============================] - 1s 5ms/step - loss: 0.0311 - val_loss: 0.0324
# Epoch 35/100
# 198/198 [==============================] - 1s 5ms/step - loss: 0.0310 - val_loss: 0.0320
# Epoch 36/100
# 198/198 [==============================] - 1s 5ms/step - loss: 0.0310 - val_loss: 0.0323
# Epoch 37/100
# 198/198 [==============================] - 1s 5ms/step - loss: 0.0310 - val_loss: 0.0323
# Epoch 38/100
# 198/198 [==============================] - 1s 5ms/step - loss: 0.0310 - val_loss: 0.0323
# Epoch 39/100
# 198/198 [==============================] - 1s 5ms/step - loss: 0.0309 - val_loss: 0.0321
# Epoch 40/100
# 198/198 [==============================] - 1s 5ms/step - loss: 0.0310 - val_loss: 0.0323
# Epoch 41/100
# 198/198 [==============================] - 1s 5ms/step - loss: 0.0310 - val_loss: 0.0321
# Epoch 42/100
# 198/198 [==============================] - 1s 5ms/step - loss: 0.0309 - val_loss: 0.0320
# Epoch 43/100
# 198/198 [==============================] - 1s 5ms/step - loss: 0.0310 - val_loss: 0.0316
# Epoch 44/100
# 198/198 [==============================] - 1s 5ms/step - loss: 0.0310 - val_loss: 0.0319
# Epoch 45/100
# 198/198 [==============================] - 1s 5ms/step - loss: 0.0309 - val_loss: 0.0316
# Epoch 46/100
# 198/198 [==============================] - 1s 5ms/step - loss: 0.0309 - val_loss: 0.0314
# Epoch 47/100
# 198/198 [==============================] - 1s 5ms/step - loss: 0.0309 - val_loss: 0.0313
# Epoch 48/100
# 198/198 [==============================] - 1s 5ms/step - loss: 0.0309 - val_loss: 0.0318
# Epoch 49/100
# 198/198 [==============================] - 1s 5ms/step - loss: 0.0308 - val_loss: 0.0318
# Epoch 50/100
# 198/198 [==============================] - 1s 5ms/step - loss: 0.0308 - val_loss: 0.0313
# Epoch 51/100
# 198/198 [==============================] - 1s 5ms/step - loss: 0.0308 - val_loss: 0.0316
# Epoch 52/100
# 198/198 [==============================] - 1s 5ms/step - loss: 0.0308 - val_loss: 0.0311
# Epoch 53/100
# 198/198 [==============================] - 1s 5ms/step - loss: 0.0307 - val_loss: 0.0314
# Epoch 54/100
# 198/198 [==============================] - 1s 5ms/step - loss: 0.0308 - val_loss: 0.0308
# Epoch 55/100
# 198/198 [==============================] - 1s 5ms/step - loss: 0.0307 - val_loss: 0.0308
# Epoch 56/100
# 198/198 [==============================] - 1s 5ms/step - loss: 0.0307 - val_loss: 0.0310
# Epoch 57/100
# 198/198 [==============================] - 1s 5ms/step - loss: 0.0307 - val_loss: 0.0308
# Epoch 58/100
# 198/198 [==============================] - 1s 4ms/step - loss: 0.0307 - val_loss: 0.0302
# Epoch 59/100
# 198/198 [==============================] - 1s 4ms/step - loss: 0.0307 - val_loss: 0.0303
# Epoch 60/100
# 198/198 [==============================] - 1s 5ms/step - loss: 0.0307 - val_loss: 0.0304
# Epoch 61/100
# 198/198 [==============================] - 1s 5ms/step - loss: 0.0306 - val_loss: 0.0305
# Epoch 62/100
# 198/198 [==============================] - 1s 5ms/step - loss: 0.0307 - val_loss: 0.0303
# Epoch 63/100
# 198/198 [==============================] - 1s 5ms/step - loss: 0.0306 - val_loss: 0.0303
# Epoch 64/100
# 198/198 [==============================] - 1s 5ms/step - loss: 0.0306 - val_loss: 0.0304
# Epoch 65/100
# 198/198 [==============================] - 1s 5ms/step - loss: 0.0306 - val_loss: 0.0295
# Epoch 66/100
# 198/198 [==============================] - 1s 5ms/step - loss: 0.0306 - val_loss: 0.0301
# Epoch 67/100
# 198/198 [==============================] - 1s 5ms/step - loss: 0.0306 - val_loss: 0.0300
# Epoch 68/100
# 198/198 [==============================] - 1s 5ms/step - loss: 0.0306 - val_loss: 0.0294
# Epoch 69/100
# 198/198 [==============================] - 1s 5ms/step - loss: 0.0305 - val_loss: 0.0297
# Epoch 70/100
# 198/198 [==============================] - 1s 5ms/step - loss: 0.0305 - val_loss: 0.0298
# Epoch 71/100
# 198/198 [==============================] - 1s 5ms/step - loss: 0.0305 - val_loss: 0.0297
# Epoch 72/100
# 198/198 [==============================] - 1s 5ms/step - loss: 0.0305 - val_loss: 0.0295
# Epoch 73/100
# 198/198 [==============================] - 1s 5ms/step - loss: 0.0306 - val_loss: 0.0296
# Epoch 74/100
# 198/198 [==============================] - 1s 5ms/step - loss: 0.0305 - val_loss: 0.0294
# Epoch 75/100
# 198/198 [==============================] - 1s 5ms/step - loss: 0.0305 - val_loss: 0.0296
# Epoch 76/100
# 198/198 [==============================] - 1s 5ms/step - loss: 0.0305 - val_loss: 0.0298
# Epoch 77/100
# 198/198 [==============================] - 1s 5ms/step - loss: 0.0304 - val_loss: 0.0294
# Epoch 78/100
# 198/198 [==============================] - 1s 5ms/step - loss: 0.0304 - val_loss: 0.0295
# Epoch 79/100
# 198/198 [==============================] - 1s 5ms/step - loss: 0.0304 - val_loss: 0.0297
# Epoch 80/100
# 198/198 [==============================] - 1s 5ms/step - loss: 0.0304 - val_loss: 0.0296
# Epoch 81/100
# 198/198 [==============================] - 1s 5ms/step - loss: 0.0304 - val_loss: 0.0297
# Epoch 82/100
# 198/198 [==============================] - 1s 5ms/step - loss: 0.0304 - val_loss: 0.0297
# Epoch 83/100
# 198/198 [==============================] - 1s 5ms/step - loss: 0.0304 - val_loss: 0.0297
# Epoch 84/100
# 198/198 [==============================] - 1s 5ms/step - loss: 0.0304 - val_loss: 0.0295
# Epoch 85/100
# 198/198 [==============================] - 1s 5ms/step - loss: 0.0304 - val_loss: 0.0295
# Epoch 86/100
# 198/198 [==============================] - 1s 5ms/step - loss: 0.0303 - val_loss: 0.0299
# Epoch 87/100
# 198/198 [==============================] - 1s 5ms/step - loss: 0.0304 - val_loss: 0.0298
# Epoch 88/100
# 198/198 [==============================] - 1s 5ms/step - loss: 0.0303 - val_loss: 0.0296
# Epoch 89/100
# 198/198 [==============================] - 1s 5ms/step - loss: 0.0303 - val_loss: 0.0295
# Epoch 90/100
# 198/198 [==============================] - 1s 5ms/step - loss: 0.0304 - val_loss: 0.0298
# Epoch 91/100
# 198/198 [==============================] - 1s 5ms/step - loss: 0.0303 - val_loss: 0.0296
# Epoch 92/100
# 198/198 [==============================] - 1s 5ms/step - loss: 0.0303 - val_loss: 0.0295
# Epoch 93/100
# 198/198 [==============================] - 1s 5ms/step - loss: 0.0303 - val_loss: 0.0297
# Epoch 94/100
# 198/198 [==============================] - 1s 5ms/step - loss: 0.0302 - val_loss: 0.0298
# Epoch 95/100
# 198/198 [==============================] - 1s 5ms/step - loss: 0.0303 - val_loss: 0.0295
# Epoch 96/100
# 198/198 [==============================] - 1s 5ms/step - loss: 0.0303 - val_loss: 0.0296
# Epoch 97/100
# 198/198 [==============================] - 1s 5ms/step - loss: 0.0303 - val_loss: 0.0294
# Epoch 98/100
# 198/198 [==============================] - 1s 5ms/step - loss: 0.0303 - val_loss: 0.0295
# Epoch 99/100
# 198/198 [==============================] - 1s 5ms/step - loss: 0.0302 - val_loss: 0.0294
# Epoch 100/100
# 198/198 [==============================] - 1s 5ms/step - loss: 0.0302 - val_loss: 0.0295
# Model saved to disk
# Loading data /Residential_3.csv
#
#
# Epoch 1/100
# 172/172 [==============================] - 1s 8ms/step - loss: 0.0810 - val_loss: 0.0703
# Epoch 2/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0706 - val_loss: 0.0640
# Epoch 3/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0683 - val_loss: 0.0617
# Epoch 4/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0665 - val_loss: 0.0611
# Epoch 5/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0655 - val_loss: 0.0606
# Epoch 6/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0644 - val_loss: 0.0603
# Epoch 7/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0633 - val_loss: 0.0600
# Epoch 8/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0622 - val_loss: 0.0620
# Epoch 9/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0617 - val_loss: 0.0599
# Epoch 10/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0607 - val_loss: 0.0600
# Epoch 11/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0603 - val_loss: 0.0595
# Epoch 12/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0595 - val_loss: 0.0605
# Epoch 13/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0588 - val_loss: 0.0605
# Epoch 14/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0585 - val_loss: 0.0599
# Epoch 15/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0582 - val_loss: 0.0607
# Epoch 16/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0581 - val_loss: 0.0609
# Epoch 17/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0579 - val_loss: 0.0598
# Epoch 18/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0578 - val_loss: 0.0597
# Epoch 19/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0576 - val_loss: 0.0588
# Epoch 20/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0575 - val_loss: 0.0590
# Epoch 21/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0575 - val_loss: 0.0588
# Epoch 22/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0573 - val_loss: 0.0585
# Epoch 23/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0571 - val_loss: 0.0592
# Epoch 24/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0571 - val_loss: 0.0583
# Epoch 25/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0568 - val_loss: 0.0581
# Epoch 26/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0567 - val_loss: 0.0573
# Epoch 27/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0566 - val_loss: 0.0573
# Epoch 28/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0565 - val_loss: 0.0576
# Epoch 29/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0564 - val_loss: 0.0574
# Epoch 30/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0563 - val_loss: 0.0579
# Epoch 31/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0562 - val_loss: 0.0575
# Epoch 32/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0563 - val_loss: 0.0571
# Epoch 33/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0561 - val_loss: 0.0569
# Epoch 34/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0560 - val_loss: 0.0569
# Epoch 35/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0560 - val_loss: 0.0569
# Epoch 36/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0559 - val_loss: 0.0574
# Epoch 37/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0559 - val_loss: 0.0575
# Epoch 38/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0559 - val_loss: 0.0565
# Epoch 39/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0558 - val_loss: 0.0576
# Epoch 40/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0557 - val_loss: 0.0576
# Epoch 41/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0557 - val_loss: 0.0580
# Epoch 42/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0556 - val_loss: 0.0573
# Epoch 43/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0556 - val_loss: 0.0575
# Epoch 44/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0555 - val_loss: 0.0573
# Epoch 45/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0554 - val_loss: 0.0564
# Epoch 46/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0556 - val_loss: 0.0563
# Epoch 47/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0554 - val_loss: 0.0568
# Epoch 48/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0554 - val_loss: 0.0568
# Epoch 49/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0554 - val_loss: 0.0572
# Epoch 50/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0553 - val_loss: 0.0570
# Epoch 51/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0553 - val_loss: 0.0568
# Epoch 52/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0553 - val_loss: 0.0565
# Epoch 53/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0553 - val_loss: 0.0567
# Epoch 54/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0552 - val_loss: 0.0564
# Epoch 55/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0551 - val_loss: 0.0563
# Epoch 56/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0551 - val_loss: 0.0568
# Epoch 57/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0550 - val_loss: 0.0568
# Epoch 58/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0551 - val_loss: 0.0565
# Epoch 59/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0550 - val_loss: 0.0571
# Epoch 60/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0552 - val_loss: 0.0563
# Epoch 61/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0550 - val_loss: 0.0569
# Epoch 62/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0549 - val_loss: 0.0561
# Epoch 63/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0549 - val_loss: 0.0553
# Epoch 64/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0548 - val_loss: 0.0568
# Epoch 65/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0548 - val_loss: 0.0565
# Epoch 66/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0549 - val_loss: 0.0564
# Epoch 67/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0548 - val_loss: 0.0557
# Epoch 68/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0546 - val_loss: 0.0560
# Epoch 69/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0548 - val_loss: 0.0560
# Epoch 70/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0547 - val_loss: 0.0559
# Epoch 71/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0544 - val_loss: 0.0566
# Epoch 72/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0546 - val_loss: 0.0557
# Epoch 73/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0546 - val_loss: 0.0560
# Epoch 74/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0545 - val_loss: 0.0559
# Epoch 75/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0545 - val_loss: 0.0570
# Epoch 76/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0545 - val_loss: 0.0560
# Epoch 77/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0546 - val_loss: 0.0557
# Epoch 78/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0546 - val_loss: 0.0557
# Epoch 79/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0543 - val_loss: 0.0554
# Epoch 80/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0544 - val_loss: 0.0557
# Epoch 81/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0543 - val_loss: 0.0559
# Epoch 82/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0542 - val_loss: 0.0561
# Epoch 83/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0544 - val_loss: 0.0558
# Epoch 84/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0542 - val_loss: 0.0561
# Epoch 85/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0545 - val_loss: 0.0557
# Epoch 86/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0543 - val_loss: 0.0559
# Epoch 87/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0544 - val_loss: 0.0552
# Epoch 88/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0541 - val_loss: 0.0558
# Epoch 89/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0541 - val_loss: 0.0561
# Epoch 90/100
# 172/172 [==============================] - 1s 6ms/step - loss: 0.0541 - val_loss: 0.0552
# Epoch 91/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0542 - val_loss: 0.0556
# Epoch 92/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0539 - val_loss: 0.0561
# Epoch 93/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0542 - val_loss: 0.0555
# Epoch 94/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0540 - val_loss: 0.0556
# Epoch 95/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0540 - val_loss: 0.0558
# Epoch 96/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0541 - val_loss: 0.0561
# Epoch 97/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0541 - val_loss: 0.0556
# Epoch 98/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0541 - val_loss: 0.0563
# Epoch 99/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0540 - val_loss: 0.0554
# Epoch 100/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0540 - val_loss: 0.0554
# Model saved to disk
# Loading data /Residential_4.csv
#
#
# Epoch 1/100
# 172/172 [==============================] - 1s 6ms/step - loss: 0.0892 - val_loss: 0.0857
# Epoch 2/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0773 - val_loss: 0.0768
# Epoch 3/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0731 - val_loss: 0.0685
# Epoch 4/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0691 - val_loss: 0.0657
# Epoch 5/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0640 - val_loss: 0.0639
# Epoch 6/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0612 - val_loss: 0.0627
# Epoch 7/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0601 - val_loss: 0.0630
# Epoch 8/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0598 - val_loss: 0.0624
# Epoch 9/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0596 - val_loss: 0.0625
# Epoch 10/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0593 - val_loss: 0.0621
# Epoch 11/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0590 - val_loss: 0.0616
# Epoch 12/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0590 - val_loss: 0.0619
# Epoch 13/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0591 - val_loss: 0.0613
# Epoch 14/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0588 - val_loss: 0.0611
# Epoch 15/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0588 - val_loss: 0.0610
# Epoch 16/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0587 - val_loss: 0.0607
# Epoch 17/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0586 - val_loss: 0.0608
# Epoch 18/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0586 - val_loss: 0.0607
# Epoch 19/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0582 - val_loss: 0.0604
# Epoch 20/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0581 - val_loss: 0.0605
# Epoch 21/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0580 - val_loss: 0.0602
# Epoch 22/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0582 - val_loss: 0.0603
# Epoch 23/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0578 - val_loss: 0.0603
# Epoch 24/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0577 - val_loss: 0.0602
# Epoch 25/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0577 - val_loss: 0.0601
# Epoch 26/100
# 172/172 [==============================] - 1s 4ms/step - loss: 0.0574 - val_loss: 0.0600
# Epoch 27/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0574 - val_loss: 0.0600
# Epoch 28/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0575 - val_loss: 0.0603
# Epoch 29/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0573 - val_loss: 0.0602
# Epoch 30/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0572 - val_loss: 0.0602
# Epoch 31/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0572 - val_loss: 0.0600
# Epoch 32/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0571 - val_loss: 0.0601
# Epoch 33/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0570 - val_loss: 0.0600
# Epoch 34/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0569 - val_loss: 0.0601
# Epoch 35/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0570 - val_loss: 0.0599
# Epoch 36/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0570 - val_loss: 0.0599
# Epoch 37/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0570 - val_loss: 0.0599
# Epoch 38/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0568 - val_loss: 0.0599
# Epoch 39/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0567 - val_loss: 0.0599
# Epoch 40/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0566 - val_loss: 0.0599
# Epoch 41/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0566 - val_loss: 0.0601
# Epoch 42/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0566 - val_loss: 0.0598
# Epoch 43/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0564 - val_loss: 0.0598
# Epoch 44/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0567 - val_loss: 0.0598
# Epoch 45/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0564 - val_loss: 0.0598
# Epoch 46/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0562 - val_loss: 0.0598
# Epoch 47/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0564 - val_loss: 0.0599
# Epoch 48/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0562 - val_loss: 0.0599
# Epoch 49/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0563 - val_loss: 0.0598
# Epoch 50/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0562 - val_loss: 0.0599
# Epoch 51/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0559 - val_loss: 0.0597
# Epoch 52/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0561 - val_loss: 0.0600
# Epoch 53/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0561 - val_loss: 0.0598
# Epoch 54/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0560 - val_loss: 0.0599
# Epoch 55/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0560 - val_loss: 0.0598
# Epoch 56/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0559 - val_loss: 0.0597
# Epoch 57/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0560 - val_loss: 0.0598
# Epoch 58/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0560 - val_loss: 0.0598
# Epoch 59/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0560 - val_loss: 0.0598
# Epoch 60/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0557 - val_loss: 0.0598
# Epoch 61/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0559 - val_loss: 0.0599
# Epoch 62/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0557 - val_loss: 0.0597
# Epoch 63/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0557 - val_loss: 0.0600
# Epoch 64/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0557 - val_loss: 0.0598
# Epoch 65/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0556 - val_loss: 0.0599
# Epoch 66/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0555 - val_loss: 0.0598
# Epoch 67/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0556 - val_loss: 0.0597
# Epoch 68/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0554 - val_loss: 0.0597
# Epoch 69/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0554 - val_loss: 0.0597
# Epoch 70/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0553 - val_loss: 0.0598
# Epoch 71/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0553 - val_loss: 0.0597
# Epoch 72/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0556 - val_loss: 0.0596
# Epoch 73/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0553 - val_loss: 0.0601
# Epoch 74/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0552 - val_loss: 0.0595
# Epoch 75/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0551 - val_loss: 0.0597
# Epoch 76/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0551 - val_loss: 0.0595
# Epoch 77/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0552 - val_loss: 0.0594
# Epoch 78/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0552 - val_loss: 0.0596
# Epoch 79/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0552 - val_loss: 0.0595
# Epoch 80/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0551 - val_loss: 0.0598
# Epoch 81/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0551 - val_loss: 0.0597
# Epoch 82/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0548 - val_loss: 0.0597
# Epoch 83/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0550 - val_loss: 0.0594
# Epoch 84/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0549 - val_loss: 0.0597
# Epoch 85/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0548 - val_loss: 0.0594
# Epoch 86/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0551 - val_loss: 0.0596
# Epoch 87/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0548 - val_loss: 0.0595
# Epoch 88/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0549 - val_loss: 0.0595
# Epoch 89/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0548 - val_loss: 0.0593
# Epoch 90/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0549 - val_loss: 0.0596
# Epoch 91/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0548 - val_loss: 0.0595
# Epoch 92/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0548 - val_loss: 0.0597
# Epoch 93/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0548 - val_loss: 0.0597
# Epoch 94/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0547 - val_loss: 0.0595
# Epoch 95/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0546 - val_loss: 0.0594
# Epoch 96/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0546 - val_loss: 0.0593
# Epoch 97/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0545 - val_loss: 0.0594
# Epoch 98/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0547 - val_loss: 0.0593
# Epoch 99/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0545 - val_loss: 0.0595
# Epoch 100/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0545 - val_loss: 0.0595
# Model saved to disk
# Loading data /Residential_5.csv
#
#
# Epoch 1/100
# 172/172 [==============================] - 1s 7ms/step - loss: 0.0579 - val_loss: 0.0565
# Epoch 2/100
# 172/172 [==============================] - 1s 6ms/step - loss: 0.0539 - val_loss: 0.0543
# Epoch 3/100
# 172/172 [==============================] - 1s 6ms/step - loss: 0.0529 - val_loss: 0.0537
# Epoch 4/100
# 172/172 [==============================] - 1s 6ms/step - loss: 0.0520 - val_loss: 0.0540
# Epoch 5/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0512 - val_loss: 0.0545
# Epoch 6/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0500 - val_loss: 0.0539
# Epoch 7/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0491 - val_loss: 0.0534
# Epoch 8/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0484 - val_loss: 0.0529
# Epoch 9/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0476 - val_loss: 0.0522
# Epoch 10/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0474 - val_loss: 0.0521
# Epoch 11/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0471 - val_loss: 0.0520
# Epoch 12/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0469 - val_loss: 0.0518
# Epoch 13/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0470 - val_loss: 0.0519
# Epoch 14/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0471 - val_loss: 0.0517
# Epoch 15/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0470 - val_loss: 0.0518
# Epoch 16/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0469 - val_loss: 0.0515
# Epoch 17/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0468 - val_loss: 0.0512
# Epoch 18/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0467 - val_loss: 0.0510
# Epoch 19/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0464 - val_loss: 0.0507
# Epoch 20/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0466 - val_loss: 0.0505
# Epoch 21/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0464 - val_loss: 0.0507
# Epoch 22/100
# 172/172 [==============================] - 1s 6ms/step - loss: 0.0463 - val_loss: 0.0503
# Epoch 23/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0464 - val_loss: 0.0507
# Epoch 24/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0461 - val_loss: 0.0502
# Epoch 25/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0463 - val_loss: 0.0505
# Epoch 26/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0462 - val_loss: 0.0504
# Epoch 27/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0460 - val_loss: 0.0503
# Epoch 28/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0461 - val_loss: 0.0503
# Epoch 29/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0462 - val_loss: 0.0502
# Epoch 30/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0461 - val_loss: 0.0502
# Epoch 31/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0460 - val_loss: 0.0501
# Epoch 32/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0461 - val_loss: 0.0501
# Epoch 33/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0459 - val_loss: 0.0501
# Epoch 34/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0461 - val_loss: 0.0501
# Epoch 35/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0461 - val_loss: 0.0502
# Epoch 36/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0458 - val_loss: 0.0499
# Epoch 37/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0458 - val_loss: 0.0500
# Epoch 38/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0459 - val_loss: 0.0501
# Epoch 39/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0458 - val_loss: 0.0500
# Epoch 40/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0458 - val_loss: 0.0499
# Epoch 41/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0458 - val_loss: 0.0501
# Epoch 42/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0458 - val_loss: 0.0500
# Epoch 43/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0457 - val_loss: 0.0500
# Epoch 44/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0457 - val_loss: 0.0500
# Epoch 45/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0456 - val_loss: 0.0501
# Epoch 46/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0456 - val_loss: 0.0499
# Epoch 47/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0456 - val_loss: 0.0498
# Epoch 48/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0453 - val_loss: 0.0498
# Epoch 49/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0455 - val_loss: 0.0498
# Epoch 50/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0454 - val_loss: 0.0498
# Epoch 51/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0455 - val_loss: 0.0496
# Epoch 52/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0453 - val_loss: 0.0499
# Epoch 53/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0455 - val_loss: 0.0498
# Epoch 54/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0452 - val_loss: 0.0496
# Epoch 55/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0453 - val_loss: 0.0497
# Epoch 56/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0453 - val_loss: 0.0497
# Epoch 57/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0453 - val_loss: 0.0496
# Epoch 58/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0452 - val_loss: 0.0496
# Epoch 59/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0451 - val_loss: 0.0496
# Epoch 60/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0452 - val_loss: 0.0497
# Epoch 61/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0450 - val_loss: 0.0493
# Epoch 62/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0450 - val_loss: 0.0493
# Epoch 63/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0451 - val_loss: 0.0493
# Epoch 64/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0451 - val_loss: 0.0494
# Epoch 65/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0449 - val_loss: 0.0494
# Epoch 66/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0449 - val_loss: 0.0493
# Epoch 67/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0450 - val_loss: 0.0495
# Epoch 68/100
# 172/172 [==============================] - 1s 5ms/step - loss: 0.0448 - val_loss: 0.0493
# Epoch 69/100
# ...
# Epoch 42/100
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0380 - val_loss: 0.0328
# Epoch 43/100
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0379 - val_loss: 0.0327
# Epoch 44/100
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0378 - val_loss: 0.0327
# Epoch 45/100
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0378 - val_loss: 0.0327
# Epoch 46/100
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0379 - val_loss: 0.0327
# Epoch 47/100
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0378 - val_loss: 0.0326
# Epoch 48/100
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0377 - val_loss: 0.0326
# Epoch 49/100
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0376 - val_loss: 0.0325
# Epoch 50/100
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0376 - val_loss: 0.0324
# Epoch 51/100
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0375 - val_loss: 0.0325
# Epoch 52/100
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0374 - val_loss: 0.0324
# Epoch 53/100
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0372 - val_loss: 0.0323
# Epoch 54/100
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0374 - val_loss: 0.0322
# Epoch 55/100
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0374 - val_loss: 0.0324
# Epoch 56/100
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0371 - val_loss: 0.0323
# Epoch 57/100
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0374 - val_loss: 0.0324
# Epoch 58/100
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0372 - val_loss: 0.0323
# Epoch 59/100
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0375 - val_loss: 0.0324
# Epoch 60/100
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0372 - val_loss: 0.0323
# Epoch 61/100
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0372 - val_loss: 0.0321
# Epoch 62/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0371 - val_loss: 0.0322
# Epoch 63/100
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0370 - val_loss: 0.0321
# Epoch 64/100
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0370 - val_loss: 0.0321
# Epoch 65/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0368 - val_loss: 0.0320
# Epoch 66/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0368 - val_loss: 0.0320
# Epoch 67/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0367 - val_loss: 0.0320
# Epoch 68/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0369 - val_loss: 0.0320
# Epoch 69/100
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0367 - val_loss: 0.0321
# Epoch 70/100
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0368 - val_loss: 0.0320
# Epoch 71/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0368 - val_loss: 0.0320
# Epoch 72/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0367 - val_loss: 0.0319
# Epoch 73/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0367 - val_loss: 0.0320
# Epoch 74/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0366 - val_loss: 0.0319
# Epoch 75/100
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0367 - val_loss: 0.0318
# Epoch 76/100
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0366 - val_loss: 0.0317
# Epoch 77/100
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0366 - val_loss: 0.0317
# Epoch 78/100
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0366 - val_loss: 0.0316
# Epoch 79/100
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0365 - val_loss: 0.0318
# Epoch 80/100
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0364 - val_loss: 0.0316
# Epoch 81/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0365 - val_loss: 0.0318
# Epoch 82/100
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0363 - val_loss: 0.0316
# Epoch 83/100
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0366 - val_loss: 0.0318
# Epoch 84/100
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0365 - val_loss: 0.0315
# Epoch 85/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0364 - val_loss: 0.0316
# Epoch 86/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0362 - val_loss: 0.0315
# Epoch 87/100
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0363 - val_loss: 0.0316
# Epoch 88/100
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0361 - val_loss: 0.0313
# Epoch 89/100
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0363 - val_loss: 0.0316
# Epoch 90/100
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0360 - val_loss: 0.0315
# Epoch 91/100
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0360 - val_loss: 0.0317
# Epoch 92/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0360 - val_loss: 0.0316
# Epoch 93/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0361 - val_loss: 0.0316
# Epoch 94/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0362 - val_loss: 0.0315
# Epoch 95/100
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0362 - val_loss: 0.0316
# Epoch 96/100
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0358 - val_loss: 0.0314
# Epoch 97/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0359 - val_loss: 0.0314
# Epoch 98/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0359 - val_loss: 0.0315
# Epoch 99/100
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0360 - val_loss: 0.0315
# Epoch 100/100
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0359 - val_loss: 0.0315
# Model saved to disk
# Loading data /Residential_27.csv
#
#
# Epoch 1/100
# 68/68 [==============================] - 1s 9ms/step - loss: 0.1001 - val_loss: 0.1152
# Epoch 2/100
# 68/68 [==============================] - 0s 5ms/step - loss: 0.1098 - val_loss: 0.0752
# Epoch 3/100
# 68/68 [==============================] - 0s 5ms/step - loss: 0.1056 - val_loss: 0.0689
# Epoch 4/100
# 68/68 [==============================] - 0s 6ms/step - loss: 0.1000 - val_loss: 0.0724
# Epoch 5/100
# 68/68 [==============================] - 0s 5ms/step - loss: 0.0955 - val_loss: 0.0698
# Epoch 6/100
# 68/68 [==============================] - 0s 5ms/step - loss: 0.0916 - val_loss: 0.0600
# Epoch 7/100
# 68/68 [==============================] - 0s 5ms/step - loss: 0.0892 - val_loss: 0.0623
# Epoch 8/100
# 68/68 [==============================] - 0s 5ms/step - loss: 0.0876 - val_loss: 0.0607
# Epoch 9/100
# 68/68 [==============================] - 0s 5ms/step - loss: 0.0854 - val_loss: 0.0595
# Epoch 10/100
# 68/68 [==============================] - 0s 5ms/step - loss: 0.0836 - val_loss: 0.0611
# Epoch 11/100
# 68/68 [==============================] - 0s 5ms/step - loss: 0.0820 - val_loss: 0.0618
# Epoch 12/100
# 68/68 [==============================] - 0s 5ms/step - loss: 0.0804 - val_loss: 0.0618
# Epoch 13/100
# 68/68 [==============================] - 0s 4ms/step - loss: 0.0799 - val_loss: 0.0621
# Epoch 14/100
# 68/68 [==============================] - 0s 5ms/step - loss: 0.0798 - val_loss: 0.0622
# Epoch 15/100
# 68/68 [==============================] - 0s 5ms/step - loss: 0.0790 - val_loss: 0.0618
# Epoch 16/100
# 68/68 [==============================] - 0s 5ms/step - loss: 0.0790 - val_loss: 0.0617
# Epoch 17/100
# 68/68 [==============================] - 0s 5ms/step - loss: 0.0788 - val_loss: 0.0616
# Epoch 18/100
# 68/68 [==============================] - 0s 5ms/step - loss: 0.0784 - val_loss: 0.0611
# Epoch 19/100
# 68/68 [==============================] - 0s 5ms/step - loss: 0.0779 - val_loss: 0.0612
# Epoch 20/100
# 68/68 [==============================] - 0s 5ms/step - loss: 0.0783 - val_loss: 0.0613
# Epoch 21/100
# 68/68 [==============================] - 0s 5ms/step - loss: 0.0776 - val_loss: 0.0609
# Epoch 22/100
# 68/68 [==============================] - 0s 5ms/step - loss: 0.0774 - val_loss: 0.0609
# Epoch 23/100
# 68/68 [==============================] - 0s 5ms/step - loss: 0.0776 - val_loss: 0.0609
# Epoch 24/100
# 68/68 [==============================] - 0s 5ms/step - loss: 0.0774 - val_loss: 0.0610
# Epoch 25/100
# 68/68 [==============================] - 0s 5ms/step - loss: 0.0773 - val_loss: 0.0609
# Epoch 26/100
# 68/68 [==============================] - 0s 5ms/step - loss: 0.0773 - val_loss: 0.0608
# Epoch 27/100
# 68/68 [==============================] - 0s 5ms/step - loss: 0.0771 - val_loss: 0.0608
# Epoch 28/100
# 68/68 [==============================] - 0s 5ms/step - loss: 0.0771 - val_loss: 0.0608
# Epoch 29/100
# 68/68 [==============================] - 0s 5ms/step - loss: 0.0771 - val_loss: 0.0605
# Epoch 30/100
# 68/68 [==============================] - 0s 5ms/step - loss: 0.0770 - val_loss: 0.0606
# Epoch 31/100
# 68/68 [==============================] - 0s 5ms/step - loss: 0.0767 - val_loss: 0.0607
# Epoch 32/100
# 68/68 [==============================] - 0s 5ms/step - loss: 0.0768 - val_loss: 0.0607
# Epoch 33/100
# 68/68 [==============================] - 0s 5ms/step - loss: 0.0765 - val_loss: 0.0607
# Epoch 34/100
# 68/68 [==============================] - 0s 5ms/step - loss: 0.0764 - val_loss: 0.0607
# Epoch 35/100
# 68/68 [==============================] - 0s 5ms/step - loss: 0.0764 - val_loss: 0.0605
# Epoch 36/100
# 68/68 [==============================] - 0s 5ms/step - loss: 0.0761 - val_loss: 0.0605
# Epoch 37/100
# 68/68 [==============================] - 0s 5ms/step - loss: 0.0761 - val_loss: 0.0602
# Epoch 38/100
# 68/68 [==============================] - 0s 5ms/step - loss: 0.0761 - val_loss: 0.0601
# Epoch 39/100
# 68/68 [==============================] - 0s 5ms/step - loss: 0.0758 - val_loss: 0.0604
# Epoch 40/100
# 68/68 [==============================] - 0s 5ms/step - loss: 0.0759 - val_loss: 0.0603
# Epoch 41/100
# 68/68 [==============================] - 0s 5ms/step - loss: 0.0758 - val_loss: 0.0604
# Epoch 42/100
# 68/68 [==============================] - 0s 5ms/step - loss: 0.0759 - val_loss: 0.0601
# Epoch 43/100
# 68/68 [==============================] - 0s 5ms/step - loss: 0.0757 - val_loss: 0.0601
# Epoch 44/100
# 68/68 [==============================] - 0s 5ms/step - loss: 0.0758 - val_loss: 0.0601
# Epoch 45/100
# 68/68 [==============================] - 0s 5ms/step - loss: 0.0756 - val_loss: 0.0602
# Epoch 46/100
# 68/68 [==============================] - 0s 5ms/step - loss: 0.0755 - val_loss: 0.0601
# Epoch 47/100
# 68/68 [==============================] - 0s 5ms/step - loss: 0.0752 - val_loss: 0.0601
# Epoch 48/100
# 68/68 [==============================] - 0s 5ms/step - loss: 0.0751 - val_loss: 0.0602
# Epoch 49/100
# 68/68 [==============================] - 0s 5ms/step - loss: 0.0750 - val_loss: 0.0600
# Epoch 50/100
# 68/68 [==============================] - 0s 5ms/step - loss: 0.0754 - val_loss: 0.0604
# Epoch 51/100
# 68/68 [==============================] - 0s 5ms/step - loss: 0.0750 - val_loss: 0.0600
# Epoch 52/100
# 68/68 [==============================] - 0s 5ms/step - loss: 0.0748 - val_loss: 0.0600
# Epoch 53/100
# 68/68 [==============================] - 0s 5ms/step - loss: 0.0749 - val_loss: 0.0603
# Epoch 54/100
# 68/68 [==============================] - 0s 5ms/step - loss: 0.0750 - val_loss: 0.0604
# Epoch 55/100
# 68/68 [==============================] - 0s 5ms/step - loss: 0.0746 - val_loss: 0.0602
# Epoch 56/100
# 68/68 [==============================] - 0s 5ms/step - loss: 0.0744 - val_loss: 0.0606
# Epoch 57/100
# 68/68 [==============================] - 0s 5ms/step - loss: 0.0743 - val_loss: 0.0605
# Epoch 58/100
# 68/68 [==============================] - 0s 6ms/step - loss: 0.0742 - val_loss: 0.0608
# Epoch 59/100
# 68/68 [==============================] - 0s 5ms/step - loss: 0.0742 - val_loss: 0.0607
# Epoch 60/100
# 68/68 [==============================] - 0s 5ms/step - loss: 0.0741 - val_loss: 0.0608
# Epoch 61/100
# 68/68 [==============================] - 0s 5ms/step - loss: 0.0738 - val_loss: 0.0610
# Epoch 62/100
# 68/68 [==============================] - 0s 5ms/step - loss: 0.0742 - val_loss: 0.0606
# Epoch 63/100
# 68/68 [==============================] - 0s 5ms/step - loss: 0.0739 - val_loss: 0.0607
# Epoch 64/100
# 68/68 [==============================] - 0s 5ms/step - loss: 0.0738 - val_loss: 0.0607
# Epoch 65/100
# 68/68 [==============================] - 0s 6ms/step - loss: 0.0737 - val_loss: 0.0608
# Epoch 66/100
# 68/68 [==============================] - 0s 5ms/step - loss: 0.0736 - val_loss: 0.0607
# Epoch 67/100
# 68/68 [==============================] - 0s 5ms/step - loss: 0.0737 - val_loss: 0.0609
# Epoch 68/100
# 68/68 [==============================] - 0s 6ms/step - loss: 0.0735 - val_loss: 0.0608
# Epoch 69/100
# 68/68 [==============================] - 0s 6ms/step - loss: 0.0737 - val_loss: 0.0610
# Epoch 70/100
# 68/68 [==============================] - 0s 5ms/step - loss: 0.0735 - val_loss: 0.0608
# Epoch 71/100
# 68/68 [==============================] - 0s 6ms/step - loss: 0.0736 - val_loss: 0.0614
# Epoch 72/100
# 68/68 [==============================] - 0s 6ms/step - loss: 0.0733 - val_loss: 0.0610
# Epoch 73/100
# 68/68 [==============================] - 0s 5ms/step - loss: 0.0734 - val_loss: 0.0613
# Epoch 74/100
# 68/68 [==============================] - 0s 6ms/step - loss: 0.0733 - val_loss: 0.0614
# Epoch 75/100
# 68/68 [==============================] - 0s 5ms/step - loss: 0.0732 - val_loss: 0.0612
# Epoch 76/100
# 68/68 [==============================] - 0s 5ms/step - loss: 0.0732 - val_loss: 0.0611
# Epoch 77/100
# 68/68 [==============================] - 0s 5ms/step - loss: 0.0728 - val_loss: 0.0615
# Epoch 78/100
# 68/68 [==============================] - 0s 5ms/step - loss: 0.0730 - val_loss: 0.0615
# Epoch 79/100
# 68/68 [==============================] - 0s 5ms/step - loss: 0.0732 - val_loss: 0.0616
# Epoch 80/100
# 68/68 [==============================] - 0s 5ms/step - loss: 0.0729 - val_loss: 0.0614
# Epoch 81/100
# 68/68 [==============================] - 0s 5ms/step - loss: 0.0729 - val_loss: 0.0615
# Epoch 82/100
# 68/68 [==============================] - 0s 5ms/step - loss: 0.0727 - val_loss: 0.0615
# Epoch 83/100
# 68/68 [==============================] - 0s 5ms/step - loss: 0.0724 - val_loss: 0.0616
# Epoch 84/100
# 68/68 [==============================] - 0s 5ms/step - loss: 0.0725 - val_loss: 0.0613
# Epoch 85/100
# 68/68 [==============================] - 0s 5ms/step - loss: 0.0726 - val_loss: 0.0616
# Epoch 86/100
# 68/68 [==============================] - 0s 5ms/step - loss: 0.0722 - val_loss: 0.0619
# Epoch 87/100
# 68/68 [==============================] - 0s 5ms/step - loss: 0.0719 - val_loss: 0.0612
# Epoch 88/100
# 68/68 [==============================] - 0s 5ms/step - loss: 0.0720 - val_loss: 0.0620
# Epoch 89/100
# 68/68 [==============================] - 0s 5ms/step - loss: 0.0719 - val_loss: 0.0616
# Epoch 90/100
# 68/68 [==============================] - 0s 5ms/step - loss: 0.0720 - val_loss: 0.0618
# Epoch 91/100
# 68/68 [==============================] - 0s 5ms/step - loss: 0.0721 - val_loss: 0.0622
# Epoch 92/100
# 68/68 [==============================] - 0s 5ms/step - loss: 0.0719 - val_loss: 0.0622
# Epoch 93/100
# 68/68 [==============================] - 0s 5ms/step - loss: 0.0720 - val_loss: 0.0617
# Epoch 94/100
# 68/68 [==============================] - 0s 5ms/step - loss: 0.0716 - val_loss: 0.0619
# Epoch 95/100
# 68/68 [==============================] - 0s 5ms/step - loss: 0.0715 - val_loss: 0.0615
# Epoch 96/100
# 68/68 [==============================] - 0s 5ms/step - loss: 0.0716 - val_loss: 0.0615
# Epoch 97/100
# 68/68 [==============================] - 0s 5ms/step - loss: 0.0719 - val_loss: 0.0618
# Epoch 98/100
# 68/68 [==============================] - 0s 5ms/step - loss: 0.0718 - val_loss: 0.0613
# Epoch 99/100
# 68/68 [==============================] - 0s 5ms/step - loss: 0.0718 - val_loss: 0.0614
# Epoch 100/100
# 68/68 [==============================] - 0s 5ms/step - loss: 0.0709 - val_loss: 0.0622
# Model saved to disk
