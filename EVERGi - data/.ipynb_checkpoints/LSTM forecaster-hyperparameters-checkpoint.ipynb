# %%
import pandas as pd
import numpy as np
import datetime as dt
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
from workalendar.europe import Belgium
import itertools
import sys
# Deep learning: 
import tensorflow as tf
from tensorboard.plugins.hparams import api as hp
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.callbacks import CSVLogger
from tensorflow.keras.models import model_from_json
import itertools
from sklearn.preprocessing import MinMaxScaler
np.set_printoptions(threshold=sys.maxsize)

# %%
# Load the TensorBoard notebook extension
# %load_ext tensorboard
logdir = './logs/'

# %%
class DeepModelTS():
    """
    A class to create a deep time series model
    """
    def __init__(
        self, 
        #data: pd.DataFrame,
        data_path: str,
        Y_var: str,
        model_save: str,
        model_load: str,
        import_file_path: str,
        export_file_path: str,
        lag: int,
        lag2: int,
        LSTM_layer_depth: int, 
        epochs=10, 
        batch_size=256,
        train_test_split=0,
        n_test = 96,
        holi_var = 'working day',
        hour_var_sin = 'hour of day_sin',
        hour_var_cos = 'hour of day_cos',
        day_week_sin = 'day of week_sin',
        day_week_cos = 'day of week_cos',
        month_sin = 'month_sin',
        month_cos = 'month_cos',
        minutes_sin = 'minutes_sin',
        minutes_cos = 'minutes_cos',

    ):
        
        self.data_path = data_path
        self.data = pd.read_csv(data_path, index_col=0)
        #self.data = data
        self.import_file_path = import_file_path
        self.data_user = pd.read_csv(import_file_path, index_col=0)
        self.data_user.index = pd.to_datetime(self.data_user.index)
        self.model_save = model_save
        self.model_load = model_load
        self.export_file_path = export_file_path
        self.Y_var = Y_var 
        self.holi_var = holi_var
        self.hour_var_sin = hour_var_sin
        self.hour_var_cos = hour_var_cos
        self.day_week_sin = day_week_sin
        self.day_week_cos = day_week_cos
        self.month_sin = month_sin
        self.month_cos = month_cos
        self.minutes_sin = minutes_sin
        self.minutes_cos = minutes_cos
        self.lag = lag 
        self.lag2 = lag2
        self.LSTM_layer_depth = LSTM_layer_depth
        self.batch_size = batch_size
        self.epochs = epochs
        self.train_test_split = train_test_split
        self.n_test = n_test

    def preprocess(self, dataframe):
        dataframe.index = pd.to_datetime(dataframe.index)
        cal = Belgium()
        years = list(range(2014, 2025))
        holidays = []
        for year in years:
            holidays.extend(cal.holidays(year))
        dataframe = dataframe.sort_index()
        dataframe[self.Y_var] = dataframe.iloc[:,0]
        dataframe['working day'] = dataframe.index.map(cal.is_working_day)
        dataframe['hour of day'] = dataframe.index.hour
        dataframe['day of week'] = dataframe.index.dayofweek
        dataframe['date'] = dataframe.index.date
        dataframe['month'] = dataframe.index.month
        dataframe['minutes'] = dataframe.index.minute
        # we encode cynical data into two dimensions using a sine and cosine transformations
        def encode(data, col, max_val):
            data[col + '_sin'] = np.sin(2 * np.pi * data[col]/max_val)
            data[col + '_cos'] = np.cos(2 * np.pi * data[col]/max_val)
            return data
        dataframe = encode(dataframe, 'hour of day', 23)
        dataframe = encode(dataframe, 'day of week', 6)
        dataframe = encode(dataframe, 'month', 12)
        dataframe = encode(dataframe, 'minutes', 60)
        dataframe = dataframe.drop(['hour of day', 'day of week', 'month', 'minutes'], axis=1)
        dataframe = dataframe.fillna(method='ffill')
        return dataframe
    
    @staticmethod    
    def plot_train_history(model):
        '''
        Convergence plots to have an idea on how the training performs
        '''
        loss = model.history.history['loss']
        val_loss = model.history.history['val_loss']
        plt.figure()
        plt.plot(range(len(loss)), loss, 'b', label='Training loss')
        plt.plot(range(len(val_loss)), val_loss, 'r', label='Validation loss')
        #plt.yscale("log")
        plt.xlabel('Epochs')
        plt.ylabel('Losses')
        plt.title('Training and validation losses')
        plt.legend()
        plt.show() 
    
    @staticmethod
    def validation(forecasted, real, parameter):
        ''' 
        compute some important parameters to compare forecasting results
        '''
        value = 0
        value_1 = 0
        value_2 = 0

        if parameter == 'SMAPE':
            for i in range(len(forecasted)):
                if real[i] + forecasted[i] == 0:
                    value += 0
                else: 
                    value += ((abs(real[i] - forecasted[i])) / (real[i] + forecasted[i])) * 100
            final_value = value / len(forecasted)  

        elif parameter == 'MAPE':
            for i in range(len(forecasted)):
                if real[i] == 0:
                    value += 0
                else: 
                    value += (abs(real[i] - forecasted[i]))/real[i]
            final_value = value / len(forecasted) * 100

        elif parameter == 'RMSE':
            for i in range(len(forecasted)):
                value += (real[i] - forecasted[i]) ** 2
            final_value = (value / len(forecasted)) ** (1 / 2) 

        elif parameter == 'R':
            for i in range(len(forecasted)):
                value += (real[i] - np.mean(real)) * (forecasted[i] - np.mean(forecasted))
                value_1 += (real[i] - np.mean(real)) ** 2
                value_2 += (forecasted[i] - np.mean(forecasted)) ** 2

            if value_1 == 0 or value_2 == 0:
                final_value = 100
            else:
                final_value = (value / ((value_1 ** (1 / 2)) * (value_2 ** (1 / 2))))*100

        return final_value
        
    @staticmethod
    def create_X_Y(ts: list, holiday: list, hour_cos: list, hour_sin: list, week_cos: list, week_sin: list, month_cos: list, month_sin: list, minute_cos: list, minute_sin: list, lag: int, lag2: int) -> tuple:
        """
        A method to create X and Y matrix from a time series list for the training of 
        deep learning models 
        """
        X, Y = [], []

        if len(ts) - lag <= 0:
            X.append(ts)
        else:
            for i in range(len(ts) - lag2):
                Y.append(ts[i + lag2])
                # Substacted 96 for not knowing the day before
                #ab = list(itertools.chain([holiday[i + lag]], [hour_cos[i + lag]], [hour_sin[i + lag]], [week_cos[i + lag]], [week_sin[i + lag]], [minute_cos[i + lag]], [minute_sin[i + lag]], [month_cos[i + lag]], [month_sin[i + lag]]))
                #ab = list(itertools.chain([ts[i+lag - lag]], [ts[i+lag - lag2]], [holiday[i + lag]], [hour_cos[i + lag]], [hour_sin[i + lag]], [week_cos[i + lag]], [week_sin[i + lag]], [minute_cos[i + lag]], [minute_sin[i + lag]], [month_cos[i + lag]], [month_sin[i + lag]]))
                ab = list(itertools.chain([ts[i+lag2 - lag]], [ts[i+lag2 - lag2]], [holiday[i + lag2]], [hour_cos[i + lag2]], [hour_sin[i + lag2]], [week_cos[i + lag2]], [week_sin[i + lag2]], [minute_cos[i + lag2]], [minute_sin[i + lag2]], [month_cos[i + lag2]], [month_sin[i + lag2]]))
                X.append(ab)
                #X.append(ts[i:(i + lag - 96)] + [holiday[i + lag]] + [hour_cos[i + lag]] + [hour_sin[i + lag]] + )
        
        X, Y = np.array(X), np.array(Y)

        # Reshaping the X array to an LSTM input shape 
        X = np.reshape(X, (X.shape[0], 1, X.shape[1]))

        return X, Y         

    def create_data_for_NN(
        self,
        use_last_n=None, ahead=False):
        """
        A method to create data for the neural network model
        """
        self.data = self.preprocess(self.data)
        #print(self.data.columns.values)
        
        # Extracting the main variable we want to model/forecast
        y = self.data[self.Y_var].tolist()
        y_holiday = self.data[self.holi_var].tolist()
        y_hour_cos = self.data[self.hour_var_cos].tolist()
        y_hour_sin = self.data[self.hour_var_sin].tolist()
        y_weekday_cos = self.data[self.day_week_cos].tolist()
        y_weekday_sin = self.data[self.day_week_sin].tolist()
        y_month_cos = self.data[self.month_cos].tolist()
        y_month_sin = self.data[self.month_sin].tolist()
        y_minute_cos = self.data[self.minutes_cos].tolist()
        y_minute_sin = self.data[self.minutes_sin].tolist()
        



        # Subseting the time series if needed
        if use_last_n is not None:
            y = y[-use_last_n:]
            y_holiday = y_holiday[-use_last_n:]
            y_hour_cos = y_hour_cos[-use_last_n:]
            y_hour_sin = y_hour_sin[-use_last_n:]
            y_weekday_cos = y_weekday_cos[-use_last_n:]
            y_weekday_sin = y_weekday_sin[-use_last_n:]
            y_month_cos = y_month_cos[-use_last_n:]
            y_month_sin = y_month_sin[-use_last_n:]
            y_minute_cos = y_minute_cos[-use_last_n:]
            y_minute_sin =  y_minute_sin[-use_last_n:]

        # The X matrix will hold the lags of Y 
        X, Y = self.create_X_Y(y, y_holiday, y_hour_cos, y_hour_sin, y_weekday_cos, y_weekday_sin, y_month_cos, y_month_sin, y_minute_cos, y_minute_sin, self.lag, self.lag2)

        # Creating training and test sets 
        X_train = X
        X_val = []
        X_test = []

        Y_train = Y
        Y_val = []
        Y_test = []
        if ahead == False:
            if self.train_test_split > 0:
                index = len(X) - self.n_test
                X_train = X[:round(index * (1-self.train_test_split))]
                X_val = X[round(index * (1-self.train_test_split)):index]
                X_test = X[-self.n_test:]     
                
                Y_train = Y[:round(index * (1-self.train_test_split))]
                Y_val = Y[round(index * (1-self.train_test_split)):index]
                Y_test = Y[-self.n_test:]
        #print(X_train.shape)
        #print(Y_train.shape)
        return X_train, X_val, X_test, Y_train, Y_val, Y_test
   
    def save_model(self, model):
        model_json = model.to_json()
        with open(self.model_save+'.json', "w") as json_file:
            json_file.write(model_json)
        # serialize weights to HDF5
        model.save_weights(self.model_save+'.h5')
          
    def load_model(self):
        # load json and create model
        json_file = open(self.model_load+".json", 'r')
        loaded_model_json = json_file.read()
        json_file.close()
        self.model = model_from_json(loaded_model_json)
        # load weights into new model
        self.model.load_weights(self.model_load+".h5")
        print("Loaded model from disk")
    
    def LSTModel(self, hparams):
        """
        A method to fit the LSTM model 
        """
        # Getting the data 
        X_train, X_val, X_test, Y_train, Y_val, Y_test = self.create_data_for_NN()

        # Defining the model
        model = tf.keras.models.Sequential()
        model.add(tf.keras.layers.LSTM(hparams[HP_DEPTH], return_sequences=True, input_shape=(X_train.shape[1],X_train.shape[2])))
        model.add(tf.keras.layers.LSTM(hparams[HP_DEPTH], input_shape=(X_train.shape[1],X_train.shape[2])))
        model.add(tf.keras.layers.Dropout(hparams[HP_DROPOUT]))
        model.add(tf.keras.layers.Dense(1))
        model.compile(optimizer='adam', loss='msle', metrics=['msle'])
        
        # Setting up early stopping
        earlyStop=EarlyStopping(monitor="val_loss",verbose=1,mode='min',patience=7)
        
        # Saving training history
        csv_logger = CSVLogger('training_B2_25ep.log', separator=',', append=False)
        
        # Defining the model parameter dict 
        keras_dict = {
            'x': X_train,
            'y': Y_train,
            'batch_size': hparams[HP_BATCH_SIZE],
            'epochs': self.epochs,
            'shuffle': False,
            'callbacks': [earlyStop, 
                          csv_logger,
                          tf.keras.callbacks.TensorBoard(logdir),  # log metrics,
                          hp.KerasCallback(logdir, hparams),  # log hparams
            ]
            #'callbacks': [csv_logger]
        }

        if self.train_test_split > 0:
            keras_dict.update({
                'validation_data': (X_val, Y_val)
            })
            
        #tf.profiler.experimental.start('logdir')
        # Fitting the model 
        model.fit(
            **keras_dict
        )
        #tf.profiler.experimental.stop(
        #save=True
        #)
        
        # Saving the model to the class 
        self.model = model
        # Plotting train history
        #self.plot_train_history(model)
        # Saving the model in json and h5
        self.save_model(self.model)
        
        _, accuracy = model.evaluate(X_test, Y_test)
        return accuracy

    def run(self, run_dir, hparams):
        with tf.summary.create_file_writer(run_dir).as_default():
            hp.hparams(hparams)  # record the values used in this trial
            accuracy = self.LSTModel(hparams)
            tf.summary.scalar(METRIC_ACCURACY, accuracy, step=1)

    
    def predict(self) -> list:
        """
        A method to predict using the test data used in creating the class
        """
        yhat = []

        if(self.train_test_split > 0):
        
            # Getting the last n time series 
            _, _, X_test, _, _, _ = self.create_data_for_NN()        

            # Making the prediction list 
            yhat = [y[0] for y in self.model.predict(X_test)]

        return yhat
    
    def plot_test(self):
        yhat = self.predict()# Constructing the forecast dataframe
        fc = self.data.tail(len(yhat)).copy()
        fc['forecast'] = yhat
        expected = fc.loc[:,'Valeur']
        predictions = fc.loc[:,'forecast']
        print('RMSE: %f [kWh]' % self.validation(predictions,expected, 'RMSE'))
        print('MAPE: %f %%' % self.validation(predictions,expected, 'MAPE'))
        # Ploting the forecasts
        plt.figure(figsize=(12, 8))
        for dtype in ['Valeur', 'forecast']:  
            plt.plot(fc.index, fc[dtype],label=dtype,alpha=0.7)
        plt.legend()
        plt.grid()

        plt.gca().set(ylabel='Consumption [kWh]', xlabel='timestamp')
        plt.yticks(fontsize=12, alpha=.7)
        plt.title("Consumption for test data", fontsize=20)

        plt.show()
    
    def predict_n_ahead(self, data_input, n_ahead: int):
        dates = pd.date_range(data_input.index[-1], periods = n_ahead+1, freq='15T')[1:]
        #data_input.index = pd.to_datetime(data_input.index)
        test = data_input.append(pd.DataFrame(index=dates))
        test.index=data_input.index.union(dates)
        test = self.preprocess(test)
        #print(test.columns.values)
        y = test[self.Y_var].tolist()
        #print(len(y))
        y_holiday = test[self.holi_var].tolist()
        #print(len(y_holiday))
        y_hour_cos = test[self.hour_var_cos].tolist()
        y_hour_sin = test[self.hour_var_sin].tolist()
        y_weekday_cos = test[self.day_week_cos].tolist()
        y_weekday_sin = test[self.day_week_sin].tolist()
        y_month_cos = test[self.month_cos].tolist()
        y_month_sin = test[self.month_sin].tolist()
        y_minute_cos = test[self.minutes_cos].tolist()
        y_minute_sin = test[self.minutes_sin].tolist()
        yhat = []
        X, _ = deep_learner.create_X_Y(y, y_holiday, y_hour_cos, y_hour_sin, y_weekday_cos, y_weekday_sin, y_month_cos, y_month_sin, y_minute_cos, y_minute_sin, self.lag, self.lag2)
        #print(X.shape)
        #print(self.model)
        yhat = [y[0] for y in self.model.predict(X)]
        return yhat[-n_ahead:]
    
    def evaluate_n_ahead(self, n_ahead: int):
        data_temp = self.data_user
        #print(len(data_temp))
        #print(data_temp.columns.values)
        yhat = []
        predictions = []
        if hasattr('self', 'model') == False:
            self.load_model()
        for i in tf.range(n_ahead//96+1):
            y_hat = self.predict_n_ahead(data_temp, self.lag)
            #print(len(y_hat))
            data_temp = data_temp.append(pd.DataFrame(y_hat, columns=['Valeur'], index=pd.date_range(data_temp.index[-1], periods = self.lag+1, freq='15T')[1:]))
            #data_temp.resample('15T').interpolate('cubic')
            data_temp.drop(data_temp.head(self.lag).index, inplace=True)
            #print(len(data_temp))
            #print(predictions)
            #print(data_temp.columns.values)
            predictions.extend(y_hat)
        #print(len(predictions))
        predictions = predictions[:n_ahead]
        #print(len(predictions))
        dates = pd.date_range(self.data_user.index[-1], periods = n_ahead+1, freq='15T')[1:]
        #print(len(dates))
        #print(len(predictions))
        test = pd.DataFrame(predictions)
        test.index = dates
        test.index = pd.to_datetime(test.index)
        test.to_csv(self.export_file_path, index=True)
        expected = test_range.head(n_ahead).loc[:,"Valeur"]
        predictions = test.iloc[:,0]
        print('RMSE: %f [kWh]' % self.validation(predictions,expected, 'RMSE'))
        print('MAPE: %f %%' % self.validation(predictions,expected, 'MAPE'))
        plt.figure(figsize=(25, 10))
        plt.grid()
        plt.gca().set(ylabel='Consumption [kWh]', xlabel='timestamp')
        plt.yticks(fontsize=12, alpha=.7)
        plt.title("Consumption forecast for given days ahead", fontsize=20)
        plt.plot(test_range.index, test_range.loc[:,"Valeur"], color='orange', label='test', alpha=0.7)
        plt.plot(self.data_user.index, self.data_user.loc[:,"Valeur"], color='b', label='user input data', alpha=0.5)
        plt.plot(test.index, test.iloc[:,0], color='black', linestyle='--', linewidth=3, label='Forecaster model',alpha=0.7)
        plt.legend(prop={'size': 20})
        return test

# %%
deep_learner = DeepModelTS(
# USER INPUT SETTINGS
Y_var = 'Valeur',
model_load = "model_B1_complete",
import_file_path = './building1_input.csv',
export_file_path = './predictions.csv',
# TRAINING SETTINGS
data_path = './Consumption_15min.csv',
#data = holidata,
model_save = "model_B1_complete",
lag = 96,
lag2 = 672,
LSTM_layer_depth = 50,
epochs = 200,
batch_size = 128,
train_test_split = 0.15,
n_test = 672*5
)

# %%
HP_BATCH_SIZE = hp.HParam('num_batch', hp.Discrete([1, 2, 4, 8, 16, 32, 64, 128]))
HP_DEPTH = hp.HParam('num_neurons', hp.Discrete([8, 16, 32, 64, 128]))
HP_DROPOUT = hp.HParam('dropout', hp.RealInterval(0.1, 0.2))

METRIC_ACCURACY = 'msle'

with tf.summary.create_file_writer('logs/hparam_tuning').as_default():
    hp.hparams_config(
        hparams=[HP_BATCH_SIZE, HP_DEPTH, HP_DROPOUT],
        metrics=[hp.Metric(METRIC_ACCURACY, display_name='Val loss')],
    )

# %%
session_num = 0


for num_batch in HP_BATCH_SIZE.domain.values:
    for num_neurons in HP_DEPTH.domain.values:
        for dropout in (HP_DROPOUT.domain.min_value, HP_DROPOUT.domain.max_value):
            hparams = {
              HP_BATCH_SIZE: num_batch,
              HP_DEPTH: num_neurons,
              HP_DROPOUT: dropout,
            }
            run_name = "run-%d" % session_num
            print('--- Starting trial: %s' % run_name)
            print({h.name: hparams[h] for h in hparams})
            deep_learner.run('logs/hparam_tuning/' + run_name, hparams)
            session_num += 1
# Out:
# --- Starting trial: run-0
# {'num_batch': 1, 'num_neurons': 8, 'dropout': 0.1}
# Epoch 1/200
#      2/147696 [..............................] - ETA: 1:39:28 - loss: 4.1090 - msle: 4.1090WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0050s vs `on_train_batch_end` time: 0.0754s). Check your callbacks.
# 147696/147696 [==============================] - 350s 2ms/step - loss: 0.1152 - msle: 0.1152 - val_loss: 0.1005 - val_msle: 0.1005
# Epoch 2/200
# 147696/147696 [==============================] - 310s 2ms/step - loss: 0.0903 - msle: 0.0903 - val_loss: 0.1050 - val_msle: 0.1050
# Epoch 3/200
# 147696/147696 [==============================] - 337s 2ms/step - loss: 0.0935 - msle: 0.0935 - val_loss: 0.1098 - val_msle: 0.1098
# Epoch 4/200
# 147696/147696 [==============================] - 308s 2ms/step - loss: 0.0951 - msle: 0.0951 - val_loss: 0.1036 - val_msle: 0.1036
# Epoch 5/200
# 147696/147696 [==============================] - 305s 2ms/step - loss: 0.0950 - msle: 0.0950 - val_loss: 0.0966 - val_msle: 0.0966
# Epoch 6/200
# 147696/147696 [==============================] - 347s 2ms/step - loss: 0.0942 - msle: 0.0942 - val_loss: 0.0924 - val_msle: 0.0924
# Epoch 7/200
# 147696/147696 [==============================] - 299s 2ms/step - loss: 0.0915 - msle: 0.0915 - val_loss: 0.0909 - val_msle: 0.0909
# Epoch 8/200
# 147696/147696 [==============================] - 296s 2ms/step - loss: 0.0927 - msle: 0.0927 - val_loss: 0.0866 - val_msle: 0.0866
# Epoch 9/200
# 147696/147696 [==============================] - 313s 2ms/step - loss: 0.0909 - msle: 0.0909 - val_loss: 0.0910 - val_msle: 0.0910
# Epoch 10/200
# 147696/147696 [==============================] - 323s 2ms/step - loss: 0.0912 - msle: 0.0912 - val_loss: 0.0883 - val_msle: 0.0883
# Epoch 11/200
# 147696/147696 [==============================] - 340s 2ms/step - loss: 0.0940 - msle: 0.0940 - val_loss: 0.1063 - val_msle: 0.1063
# Epoch 12/200
# 147696/147696 [==============================] - 299s 2ms/step - loss: 0.0947 - msle: 0.0947 - val_loss: 0.0885 - val_msle: 0.0885
# Epoch 13/200
# 147696/147696 [==============================] - 334s 2ms/step - loss: 0.0962 - msle: 0.0962 - val_loss: 0.0883 - val_msle: 0.0883
# Epoch 14/200
# 147696/147696 [==============================] - 299s 2ms/step - loss: 0.0967 - msle: 0.0967 - val_loss: 0.0878 - val_msle: 0.0878
# Epoch 15/200
# 147696/147696 [==============================] - 295s 2ms/step - loss: 0.0949 - msle: 0.0949 - val_loss: 0.0872 - val_msle: 0.0872
# Epoch 00015: early stopping
# 105/105 [==============================] - 0s 1ms/step - loss: 0.1197 - msle: 0.1197
# --- Starting trial: run-1
# {'num_batch': 1, 'num_neurons': 8, 'dropout': 0.2}
# Epoch 1/200
#      2/147696 [..............................] - ETA: 2:05:14 - loss: 4.1212 - msle: 4.1212WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0045s vs `on_train_batch_end` time: 0.0970s). Check your callbacks.
# 147696/147696 [==============================] - 306s 2ms/step - loss: 0.1124 - msle: 0.1124 - val_loss: 0.1074 - val_msle: 0.1074
# Epoch 2/200
# 147696/147696 [==============================] - 304s 2ms/step - loss: 0.0993 - msle: 0.0993 - val_loss: 0.0922 - val_msle: 0.0922
# Epoch 3/200
# 147696/147696 [==============================] - 295s 2ms/step - loss: 0.0919 - msle: 0.0919 - val_loss: 0.0842 - val_msle: 0.0842
# Epoch 4/200
# 147696/147696 [==============================] - 306s 2ms/step - loss: 0.0910 - msle: 0.0910 - val_loss: 0.0903 - val_msle: 0.0903
# Epoch 5/200
# 147696/147696 [==============================] - 300s 2ms/step - loss: 0.0954 - msle: 0.0954 - val_loss: 0.0962 - val_msle: 0.0962
# Epoch 6/200
# 147696/147696 [==============================] - 301s 2ms/step - loss: 0.0925 - msle: 0.0925 - val_loss: 0.0860 - val_msle: 0.0860
# Epoch 7/200
# 147696/147696 [==============================] - 305s 2ms/step - loss: 0.0911 - msle: 0.0911 - val_loss: 0.0897 - val_msle: 0.0897
# Epoch 8/200
# 147696/147696 [==============================] - 337s 2ms/step - loss: 0.0929 - msle: 0.0929 - val_loss: 0.0874 - val_msle: 0.0874
# Epoch 9/200
# 147696/147696 [==============================] - 341s 2ms/step - loss: 0.0920 - msle: 0.0920 - val_loss: 0.0880 - val_msle: 0.0880
# Epoch 10/200
# 147696/147696 [==============================] - 315s 2ms/step - loss: 0.0901 - msle: 0.0901 - val_loss: 0.0898 - val_msle: 0.0898
# Epoch 00010: early stopping
# 105/105 [==============================] - 0s 2ms/step - loss: 0.1102 - msle: 0.1102
# --- Starting trial: run-2
# {'num_batch': 1, 'num_neurons': 16, 'dropout': 0.1}
# Epoch 1/200
#      2/147696 [..............................] - ETA: 2:09:03 - loss: 4.0654 - msle: 4.0654WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0073s vs `on_train_batch_end` time: 0.0977s). Check your callbacks.
# 147696/147696 [==============================] - 329s 2ms/step - loss: 0.0952 - msle: 0.0952 - val_loss: 0.1073 - val_msle: 0.1073
# Epoch 2/200
# 147696/147696 [==============================] - 323s 2ms/step - loss: 0.0870 - msle: 0.0870 - val_loss: 0.1024 - val_msle: 0.1024
# Epoch 3/200
# 147696/147696 [==============================] - 330s 2ms/step - loss: 0.0888 - msle: 0.0888 - val_loss: 0.0963 - val_msle: 0.0963
# Epoch 4/200
# 147696/147696 [==============================] - 324s 2ms/step - loss: 0.0879 - msle: 0.0879 - val_loss: 0.0982 - val_msle: 0.0982
# Epoch 5/200
# 147696/147696 [==============================] - 322s 2ms/step - loss: 0.0874 - msle: 0.0874 - val_loss: 0.0934 - val_msle: 0.0934
# Epoch 6/200
# 147696/147696 [==============================] - 319s 2ms/step - loss: 0.0885 - msle: 0.0885 - val_loss: 0.0946 - val_msle: 0.0946
# Epoch 7/200
# 147696/147696 [==============================] - 323s 2ms/step - loss: 0.0883 - msle: 0.0883 - val_loss: 0.0933 - val_msle: 0.0933
# Epoch 8/200
# 147696/147696 [==============================] - 323s 2ms/step - loss: 0.0890 - msle: 0.0890 - val_loss: 0.1065 - val_msle: 0.1065
# Epoch 9/200
# 147696/147696 [==============================] - 319s 2ms/step - loss: 0.0890 - msle: 0.0890 - val_loss: 0.1006 - val_msle: 0.1006
# Epoch 10/200
# 147696/147696 [==============================] - 321s 2ms/step - loss: 0.0876 - msle: 0.0876 - val_loss: 0.0944 - val_msle: 0.0944
# Epoch 11/200
# 147696/147696 [==============================] - 315s 2ms/step - loss: 0.0875 - msle: 0.0875 - val_loss: 0.0955 - val_msle: 0.0955
# Epoch 12/200
# 147696/147696 [==============================] - 315s 2ms/step - loss: 0.0889 - msle: 0.0889 - val_loss: 0.0870 - val_msle: 0.0870
# Epoch 13/200
# 147696/147696 [==============================] - 307s 2ms/step - loss: 0.0862 - msle: 0.0862 - val_loss: 0.0966 - val_msle: 0.0966
# Epoch 14/200
# 147696/147696 [==============================] - 323s 2ms/step - loss: 0.0877 - msle: 0.0877 - val_loss: 0.0920 - val_msle: 0.0920
# Epoch 15/200
# 147696/147696 [==============================] - 321s 2ms/step - loss: 0.0869 - msle: 0.0869 - val_loss: 0.0905 - val_msle: 0.0905
# Epoch 16/200
# 147696/147696 [==============================] - 318s 2ms/step - loss: 0.0858 - msle: 0.0858 - val_loss: 0.1053 - val_msle: 0.1053
# Epoch 17/200
# 147696/147696 [==============================] - 313s 2ms/step - loss: 0.0857 - msle: 0.0857 - val_loss: 0.0895 - val_msle: 0.0895
# Epoch 18/200
# 147696/147696 [==============================] - 315s 2ms/step - loss: 0.0870 - msle: 0.0870 - val_loss: 0.0934 - val_msle: 0.0934
# Epoch 19/200
# 147696/147696 [==============================] - 320s 2ms/step - loss: 0.0871 - msle: 0.0871 - val_loss: 0.0900 - val_msle: 0.0900
# Epoch 00019: early stopping
# 105/105 [==============================] - 0s 1ms/step - loss: 0.1014 - msle: 0.1014
# --- Starting trial: run-3
# {'num_batch': 1, 'num_neurons': 16, 'dropout': 0.2}
# Epoch 1/200
#      2/147696 [..............................] - ETA: 2:00:42 - loss: 4.1212 - msle: 4.1212WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0066s vs `on_train_batch_end` time: 0.0914s). Check your callbacks.
# 147696/147696 [==============================] - 309s 2ms/step - loss: 0.0922 - msle: 0.0922 - val_loss: 0.1031 - val_msle: 0.1031
# Epoch 2/200
# 147696/147696 [==============================] - 319s 2ms/step - loss: 0.0917 - msle: 0.0917 - val_loss: 0.1029 - val_msle: 0.1029
# Epoch 3/200
# 147696/147696 [==============================] - 312s 2ms/step - loss: 0.0888 - msle: 0.0888 - val_loss: 0.0900 - val_msle: 0.0900
# Epoch 4/200
# 147696/147696 [==============================] - 317s 2ms/step - loss: 0.0917 - msle: 0.0917 - val_loss: 0.0913 - val_msle: 0.0913
# Epoch 5/200
# 147696/147696 [==============================] - 307s 2ms/step - loss: 0.0872 - msle: 0.0872 - val_loss: 0.0939 - val_msle: 0.0939
# Epoch 6/200
# 147696/147696 [==============================] - 308s 2ms/step - loss: 0.0885 - msle: 0.0885 - val_loss: 0.0936 - val_msle: 0.0936
# Epoch 7/200
# 147696/147696 [==============================] - 315s 2ms/step - loss: 0.0892 - msle: 0.0892 - val_loss: 0.0936 - val_msle: 0.0936
# Epoch 8/200
# 147696/147696 [==============================] - 318s 2ms/step - loss: 0.0880 - msle: 0.0880 - val_loss: 0.0904 - val_msle: 0.0904
# Epoch 9/200
# 147696/147696 [==============================] - 314s 2ms/step - loss: 0.0886 - msle: 0.0886 - val_loss: 0.0882 - val_msle: 0.0882
# Epoch 10/200
# 147696/147696 [==============================] - 310s 2ms/step - loss: 0.0878 - msle: 0.0878 - val_loss: 0.0903 - val_msle: 0.0903
# Epoch 11/200
# 147696/147696 [==============================] - 316s 2ms/step - loss: 0.0892 - msle: 0.0892 - val_loss: 0.0860 - val_msle: 0.0860
# Epoch 12/200
# 147696/147696 [==============================] - 309s 2ms/step - loss: 0.0864 - msle: 0.0864 - val_loss: 0.0889 - val_msle: 0.0889
# Epoch 13/200
# 147696/147696 [==============================] - 310s 2ms/step - loss: 0.0848 - msle: 0.0848 - val_loss: 0.0879 - val_msle: 0.0879
# Epoch 14/200
# 147696/147696 [==============================] - 311s 2ms/step - loss: 0.0874 - msle: 0.0874 - val_loss: 0.0912 - val_msle: 0.0912
# Epoch 15/200
# 147696/147696 [==============================] - 318s 2ms/step - loss: 0.0877 - msle: 0.0877 - val_loss: 0.0900 - val_msle: 0.0900
# Epoch 16/200
# 147696/147696 [==============================] - 311s 2ms/step - loss: 0.0890 - msle: 0.0890 - val_loss: 0.0891 - val_msle: 0.0891
# Epoch 17/200
# 147696/147696 [==============================] - 318s 2ms/step - loss: 0.0895 - msle: 0.0895 - val_loss: 0.0874 - val_msle: 0.0874
# Epoch 18/200
# 147696/147696 [==============================] - 310s 2ms/step - loss: 0.0902 - msle: 0.0902 - val_loss: 0.0893 - val_msle: 0.0893
# Epoch 00018: early stopping
# 105/105 [==============================] - 0s 1ms/step - loss: 0.1129 - msle: 0.1129
# --- Starting trial: run-4
# {'num_batch': 1, 'num_neurons': 32, 'dropout': 0.1}
# Epoch 1/200
#      2/147696 [..............................] - ETA: 2:00:23 - loss: 3.9881 - msle: 3.9881WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0049s vs `on_train_batch_end` time: 0.0927s). Check your callbacks.
# 147696/147696 [==============================] - 326s 2ms/step - loss: 0.0832 - msle: 0.0832 - val_loss: 0.1111 - val_msle: 0.1111
# Epoch 2/200
# 147696/147696 [==============================] - 327s 2ms/step - loss: 0.0833 - msle: 0.0833 - val_loss: 0.1004 - val_msle: 0.1004
# Epoch 3/200
# 147696/147696 [==============================] - 332s 2ms/step - loss: 0.0821 - msle: 0.0821 - val_loss: 0.1051 - val_msle: 0.1051
# Epoch 4/200
# 147696/147696 [==============================] - 332s 2ms/step - loss: 0.0813 - msle: 0.0813 - val_loss: 0.1086 - val_msle: 0.1086
# Epoch 5/200
# 147696/147696 [==============================] - 324s 2ms/step - loss: 0.0845 - msle: 0.0845 - val_loss: 0.1096 - val_msle: 0.1096
# Epoch 6/200
# 147696/147696 [==============================] - 330s 2ms/step - loss: 0.0843 - msle: 0.0843 - val_loss: 0.1026 - val_msle: 0.1026
# Epoch 7/200
# 147696/147696 [==============================] - 330s 2ms/step - loss: 0.0825 - msle: 0.0825 - val_loss: 0.0976 - val_msle: 0.0976
# Epoch 8/200
# 147696/147696 [==============================] - 331s 2ms/step - loss: 0.0828 - msle: 0.0828 - val_loss: 0.0958 - val_msle: 0.0958
# Epoch 9/200
# 147696/147696 [==============================] - 323s 2ms/step - loss: 0.0827 - msle: 0.0827 - val_loss: 0.0978 - val_msle: 0.0978
# Epoch 10/200
# 147696/147696 [==============================] - 331s 2ms/step - loss: 0.0839 - msle: 0.0839 - val_loss: 0.1038 - val_msle: 0.1038
# Epoch 11/200
# 147696/147696 [==============================] - 326s 2ms/step - loss: 0.0816 - msle: 0.0816 - val_loss: 0.1180 - val_msle: 0.1180
# Epoch 12/200
# 147696/147696 [==============================] - 328s 2ms/step - loss: 0.0813 - msle: 0.0813 - val_loss: 0.0992 - val_msle: 0.0992
# Epoch 13/200
# 147696/147696 [==============================] - 326s 2ms/step - loss: 0.0825 - msle: 0.0825 - val_loss: 0.1027 - val_msle: 0.1027
# Epoch 14/200
# 147696/147696 [==============================] - 327s 2ms/step - loss: 0.0848 - msle: 0.0848 - val_loss: 0.1060 - val_msle: 0.1060
# Epoch 15/200
# 147696/147696 [==============================] - 320s 2ms/step - loss: 0.0832 - msle: 0.0832 - val_loss: 0.0987 - val_msle: 0.0987
# Epoch 00015: early stopping
# 105/105 [==============================] - 0s 1ms/step - loss: 0.1095 - msle: 0.1095
# --- Starting trial: run-5
# {'num_batch': 1, 'num_neurons': 32, 'dropout': 0.2}
# Epoch 1/200
#      2/147696 [..............................] - ETA: 2:03:23 - loss: 4.0277 - msle: 4.0277WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0070s vs `on_train_batch_end` time: 0.0932s). Check your callbacks.
# 147696/147696 [==============================] - 325s 2ms/step - loss: 0.0839 - msle: 0.0839 - val_loss: 0.1096 - val_msle: 0.1096
# Epoch 2/200
# 147696/147696 [==============================] - 324s 2ms/step - loss: 0.0810 - msle: 0.0810 - val_loss: 0.0969 - val_msle: 0.0969
# Epoch 3/200
# 147696/147696 [==============================] - 320s 2ms/step - loss: 0.0800 - msle: 0.0800 - val_loss: 0.0955 - val_msle: 0.0955
# Epoch 4/200
# 147696/147696 [==============================] - 317s 2ms/step - loss: 0.0837 - msle: 0.0837 - val_loss: 0.0943 - val_msle: 0.0943
# Epoch 5/200
# 147696/147696 [==============================] - 323s 2ms/step - loss: 0.0872 - msle: 0.0872 - val_loss: 0.0952 - val_msle: 0.0952
# Epoch 6/200
# 147696/147696 [==============================] - 321s 2ms/step - loss: 0.0851 - msle: 0.0851 - val_loss: 0.0925 - val_msle: 0.0925
# Epoch 7/200
# 147696/147696 [==============================] - 305s 2ms/step - loss: 0.0853 - msle: 0.0853 - val_loss: 0.0937 - val_msle: 0.0937
# Epoch 8/200
# 147696/147696 [==============================] - 299s 2ms/step - loss: 0.0852 - msle: 0.0852 - val_loss: 0.0972 - val_msle: 0.0972
# Epoch 9/200
# 147696/147696 [==============================] - 307s 2ms/step - loss: 0.0855 - msle: 0.0855 - val_loss: 0.0952 - val_msle: 0.0952
# Epoch 10/200
# 147696/147696 [==============================] - 315s 2ms/step - loss: 0.0874 - msle: 0.0874 - val_loss: 0.0914 - val_msle: 0.0914
# Epoch 11/200
# 147696/147696 [==============================] - 300s 2ms/step - loss: 0.0845 - msle: 0.0845 - val_loss: 0.0966 - val_msle: 0.0966
# Epoch 12/200
# 147696/147696 [==============================] - 316s 2ms/step - loss: 0.0858 - msle: 0.0858 - val_loss: 0.0886 - val_msle: 0.0886
# Epoch 13/200
# 147696/147696 [==============================] - 301s 2ms/step - loss: 0.0870 - msle: 0.0870 - val_loss: 0.0959 - val_msle: 0.0959
# Epoch 14/200
# 147696/147696 [==============================] - 308s 2ms/step - loss: 0.0873 - msle: 0.0873 - val_loss: 0.0894 - val_msle: 0.0894
# Epoch 15/200
# 147696/147696 [==============================] - 317s 2ms/step - loss: 0.0862 - msle: 0.0862 - val_loss: 0.0899 - val_msle: 0.0899
# Epoch 16/200
# 147696/147696 [==============================] - 324s 2ms/step - loss: 0.0857 - msle: 0.0857 - val_loss: 0.0956 - val_msle: 0.0956
# Epoch 17/200
# 147696/147696 [==============================] - 326s 2ms/step - loss: 0.0856 - msle: 0.0856 - val_loss: 0.0933 - val_msle: 0.0933
# Epoch 18/200
# 147696/147696 [==============================] - 331s 2ms/step - loss: 0.0871 - msle: 0.0871 - val_loss: 0.0948 - val_msle: 0.0948
# Epoch 19/200
# 147696/147696 [==============================] - 325s 2ms/step - loss: 0.0879 - msle: 0.0879 - val_loss: 0.0961 - val_msle: 0.0961
# Epoch 00019: early stopping
# 105/105 [==============================] - 0s 1ms/step - loss: 0.1181 - msle: 0.1181
# --- Starting trial: run-6
# {'num_batch': 1, 'num_neurons': 64, 'dropout': 0.1}
# Epoch 1/200
#      2/147696 [..............................] - ETA: 1:57:28 - loss: 4.0176 - msle: 4.0176WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0054s vs `on_train_batch_end` time: 0.0898s). Check your callbacks.
# 147696/147696 [==============================] - 347s 2ms/step - loss: 0.0717 - msle: 0.0717 - val_loss: 0.1067 - val_msle: 0.1067
# Epoch 2/200
# 147696/147696 [==============================] - 345s 2ms/step - loss: 0.0728 - msle: 0.0728 - val_loss: 0.1105 - val_msle: 0.1105
# Epoch 3/200
# 147696/147696 [==============================] - 340s 2ms/step - loss: 0.0750 - msle: 0.0750 - val_loss: 0.1081 - val_msle: 0.1081
# Epoch 4/200
# 147696/147696 [==============================] - 336s 2ms/step - loss: 0.0741 - msle: 0.0741 - val_loss: 0.1071 - val_msle: 0.1071
# Epoch 5/200
# 147696/147696 [==============================] - 335s 2ms/step - loss: 0.0747 - msle: 0.0747 - val_loss: 0.0969 - val_msle: 0.0969
# Epoch 6/200
# 147696/147696 [==============================] - 341s 2ms/step - loss: 0.0764 - msle: 0.0764 - val_loss: 0.0942 - val_msle: 0.0942
# Epoch 7/200
# 147696/147696 [==============================] - 345s 2ms/step - loss: 0.0795 - msle: 0.0795 - val_loss: 0.0978 - val_msle: 0.0978
# Epoch 8/200
# 147696/147696 [==============================] - 345s 2ms/step - loss: 0.0800 - msle: 0.0800 - val_loss: 0.0956 - val_msle: 0.0956
# Epoch 9/200
# 147696/147696 [==============================] - 334s 2ms/step - loss: 0.0800 - msle: 0.0800 - val_loss: 0.0995 - val_msle: 0.0995
# Epoch 10/200
# 147696/147696 [==============================] - 333s 2ms/step - loss: 0.0814 - msle: 0.0814 - val_loss: 0.0949 - val_msle: 0.0949
# Epoch 11/200
# 147696/147696 [==============================] - 334s 2ms/step - loss: 0.0795 - msle: 0.0795 - val_loss: 0.0980 - val_msle: 0.0980
# Epoch 12/200
# 147696/147696 [==============================] - 336s 2ms/step - loss: 0.0779 - msle: 0.0779 - val_loss: 0.0934 - val_msle: 0.0934
# Epoch 13/200
# 147696/147696 [==============================] - 334s 2ms/step - loss: 0.0802 - msle: 0.0802 - val_loss: 0.0966 - val_msle: 0.0966
# Epoch 14/200
# 147696/147696 [==============================] - 338s 2ms/step - loss: 0.0803 - msle: 0.0803 - val_loss: 0.0953 - val_msle: 0.0953
# Epoch 15/200
# 147696/147696 [==============================] - 322s 2ms/step - loss: 0.0780 - msle: 0.0780 - val_loss: 0.0963 - val_msle: 0.0963
# Epoch 16/200
# 147696/147696 [==============================] - 332s 2ms/step - loss: 0.0796 - msle: 0.0796 - val_loss: 0.0971 - val_msle: 0.0971
# Epoch 17/200
# 147696/147696 [==============================] - 332s 2ms/step - loss: 0.0819 - msle: 0.0819 - val_loss: 0.0985 - val_msle: 0.0985
# Epoch 18/200
# 147696/147696 [==============================] - 340s 2ms/step - loss: 0.0810 - msle: 0.0810 - val_loss: 0.0979 - val_msle: 0.0979
# Epoch 19/200
# 147696/147696 [==============================] - 337s 2ms/step - loss: 0.0793 - msle: 0.0793 - val_loss: 0.0987 - val_msle: 0.0987
# Epoch 00019: early stopping
# 105/105 [==============================] - 0s 2ms/step - loss: 0.1158 - msle: 0.1158
# --- Starting trial: run-7
# {'num_batch': 1, 'num_neurons': 64, 'dropout': 0.2}
# Epoch 1/200
#      2/147696 [..............................] - ETA: 2:00:06 - loss: 4.1212 - msle: 4.1212WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0037s vs `on_train_batch_end` time: 0.0934s). Check your callbacks.
# 147696/147696 [==============================] - 332s 2ms/step - loss: 0.0695 - msle: 0.0695 - val_loss: 0.1023 - val_msle: 0.1023
# Epoch 2/200
# 147696/147696 [==============================] - 339s 2ms/step - loss: 0.0709 - msle: 0.0709 - val_loss: 0.1004 - val_msle: 0.1004
# Epoch 3/200
# 147696/147696 [==============================] - 328s 2ms/step - loss: 0.0734 - msle: 0.0734 - val_loss: 0.1004 - val_msle: 0.1004
# Epoch 4/200
# 147696/147696 [==============================] - 297s 2ms/step - loss: 0.0758 - msle: 0.0758 - val_loss: 0.1011 - val_msle: 0.1011
# Epoch 5/200
# 147696/147696 [==============================] - 287s 2ms/step - loss: 0.0750 - msle: 0.0750 - val_loss: 0.1102 - val_msle: 0.1102
# Epoch 6/200
# 147696/147696 [==============================] - 317s 2ms/step - loss: 0.0769 - msle: 0.0769 - val_loss: 0.0975 - val_msle: 0.0975
# Epoch 7/200
# 147696/147696 [==============================] - 321s 2ms/step - loss: 0.0781 - msle: 0.0781 - val_loss: 0.0972 - val_msle: 0.0972
# Epoch 8/200
# 147696/147696 [==============================] - 329s 2ms/step - loss: 0.0803 - msle: 0.0803 - val_loss: 0.0899 - val_msle: 0.0899
# Epoch 9/200
# 147696/147696 [==============================] - 329s 2ms/step - loss: 0.0794 - msle: 0.0794 - val_loss: 0.0980 - val_msle: 0.0980
# Epoch 10/200
# 147696/147696 [==============================] - 334s 2ms/step - loss: 0.0758 - msle: 0.0758 - val_loss: 0.1016 - val_msle: 0.1016
# Epoch 11/200
# 147696/147696 [==============================] - 327s 2ms/step - loss: 0.0780 - msle: 0.0780 - val_loss: 0.0952 - val_msle: 0.0952
# Epoch 12/200
# 147696/147696 [==============================] - 324s 2ms/step - loss: 0.0800 - msle: 0.0800 - val_loss: 0.1038 - val_msle: 0.1038
# Epoch 13/200
# 147696/147696 [==============================] - 329s 2ms/step - loss: 0.0808 - msle: 0.0808 - val_loss: 0.1056 - val_msle: 0.1056
# Epoch 14/200
# 147696/147696 [==============================] - 331s 2ms/step - loss: 0.0791 - msle: 0.0791 - val_loss: 0.0993 - val_msle: 0.0993
# Epoch 15/200
# 147696/147696 [==============================] - 329s 2ms/step - loss: 0.0810 - msle: 0.0810 - val_loss: 0.0961 - val_msle: 0.0961
# Epoch 00015: early stopping
# 105/105 [==============================] - 0s 2ms/step - loss: 0.1269 - msle: 0.1269
# --- Starting trial: run-8
# {'num_batch': 1, 'num_neurons': 128, 'dropout': 0.1}
# Epoch 1/200
#      2/147696 [..............................] - ETA: 2:00:44 - loss: 4.1212 - msle: 4.1212WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0068s vs `on_train_batch_end` time: 0.0911s). Check your callbacks.
# 147696/147696 [==============================] - 410s 3ms/step - loss: 0.0680 - msle: 0.0680 - val_loss: 0.1077 - val_msle: 0.1077
# Epoch 2/200
# 147696/147696 [==============================] - 400s 3ms/step - loss: 0.0653 - msle: 0.0653 - val_loss: 0.1100 - val_msle: 0.1100
# Epoch 3/200
# 147696/147696 [==============================] - 355s 2ms/step - loss: 0.0678 - msle: 0.0678 - val_loss: 0.1011 - val_msle: 0.1011
# Epoch 4/200
# 147696/147696 [==============================] - 353s 2ms/step - loss: 0.0667 - msle: 0.0667 - val_loss: 0.1045 - val_msle: 0.1045
# Epoch 5/200
# 147696/147696 [==============================] - 368s 2ms/step - loss: 0.0719 - msle: 0.0719 - val_loss: 0.1111 - val_msle: 0.1111
# Epoch 6/200
# 147696/147696 [==============================] - 384s 3ms/step - loss: 0.0713 - msle: 0.0713 - val_loss: 0.1056 - val_msle: 0.1056
# Epoch 7/200
# 147696/147696 [==============================] - 387s 3ms/step - loss: 0.0719 - msle: 0.0719 - val_loss: 0.1068 - val_msle: 0.1068
# Epoch 8/200
# 147696/147696 [==============================] - 385s 3ms/step - loss: 0.0739 - msle: 0.0739 - val_loss: 0.1047 - val_msle: 0.1047
# Epoch 9/200
# 147696/147696 [==============================] - 369s 2ms/step - loss: 0.0712 - msle: 0.0712 - val_loss: 0.1012 - val_msle: 0.1012
# Epoch 10/200
# 147696/147696 [==============================] - 404s 3ms/step - loss: 0.0705 - msle: 0.0705 - val_loss: 0.0966 - val_msle: 0.0966
# Epoch 11/200
# 147696/147696 [==============================] - 397s 3ms/step - loss: 0.0660 - msle: 0.0660 - val_loss: 0.1017 - val_msle: 0.1017
# Epoch 12/200
# 147696/147696 [==============================] - 402s 3ms/step - loss: 0.0677 - msle: 0.0677 - val_loss: 0.0922 - val_msle: 0.0922
# Epoch 13/200
# 147696/147696 [==============================] - 375s 3ms/step - loss: 0.0716 - msle: 0.0716 - val_loss: 0.1006 - val_msle: 0.1006
# Epoch 14/200
# 147696/147696 [==============================] - 351s 2ms/step - loss: 0.0713 - msle: 0.0713 - val_loss: 0.1041 - val_msle: 0.1041
# Epoch 15/200
# 147696/147696 [==============================] - 364s 2ms/step - loss: 0.0739 - msle: 0.0739 - val_loss: 0.1005 - val_msle: 0.1005
# Epoch 16/200
# 147696/147696 [==============================] - 396s 3ms/step - loss: 0.0672 - msle: 0.0672 - val_loss: 0.1023 - val_msle: 0.1023
# Epoch 17/200
# 147696/147696 [==============================] - 397s 3ms/step - loss: 0.0688 - msle: 0.0688 - val_loss: 0.1202 - val_msle: 0.1202
# Epoch 18/200
# 147696/147696 [==============================] - 400s 3ms/step - loss: 0.0675 - msle: 0.0675 - val_loss: 0.1068 - val_msle: 0.1068
# Epoch 19/200
# 147696/147696 [==============================] - 390s 3ms/step - loss: 0.0683 - msle: 0.0683 - val_loss: 0.0973 - val_msle: 0.0973
# Epoch 00019: early stopping
# 105/105 [==============================] - 0s 3ms/step - loss: 0.1086 - msle: 0.1086
# --- Starting trial: run-9
# {'num_batch': 1, 'num_neurons': 128, 'dropout': 0.2}
# Epoch 1/200
#      2/147696 [..............................] - ETA: 2:03:01 - loss: 4.1212 - msle: 4.1212WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0061s vs `on_train_batch_end` time: 0.0933s). Check your callbacks.
# 147696/147696 [==============================] - 424s 3ms/step - loss: 0.0693 - msle: 0.0693 - val_loss: 0.1025 - val_msle: 0.1025
# Epoch 2/200
# 147696/147696 [==============================] - 406s 3ms/step - loss: 0.0658 - msle: 0.0658 - val_loss: 0.1084 - val_msle: 0.1084
# Epoch 3/200
# 147696/147696 [==============================] - 414s 3ms/step - loss: 0.0693 - msle: 0.0693 - val_loss: 0.0984 - val_msle: 0.0984
# Epoch 4/200
# 147696/147696 [==============================] - 411s 3ms/step - loss: 0.0715 - msle: 0.0715 - val_loss: 0.1007 - val_msle: 0.1007
# Epoch 5/200
# 147696/147696 [==============================] - 407s 3ms/step - loss: 0.0726 - msle: 0.0726 - val_loss: 0.1043 - val_msle: 0.1043
# Epoch 6/200
# 147696/147696 [==============================] - 407s 3ms/step - loss: 0.0748 - msle: 0.0748 - val_loss: 0.0964 - val_msle: 0.0964
# Epoch 7/200
# 147696/147696 [==============================] - 399s 3ms/step - loss: 0.0729 - msle: 0.0729 - val_loss: 0.1000 - val_msle: 0.1000
# Epoch 8/200
# 147696/147696 [==============================] - 404s 3ms/step - loss: 0.0721 - msle: 0.0721 - val_loss: 0.1009 - val_msle: 0.1009
# Epoch 9/200
# 147696/147696 [==============================] - 407s 3ms/step - loss: 0.0732 - msle: 0.0732 - val_loss: 0.0999 - val_msle: 0.0999
# Epoch 10/200
# 147696/147696 [==============================] - 409s 3ms/step - loss: 0.0737 - msle: 0.0737 - val_loss: 0.0989 - val_msle: 0.0989
# Epoch 11/200
# 147696/147696 [==============================] - 403s 3ms/step - loss: 0.0740 - msle: 0.0740 - val_loss: 0.0960 - val_msle: 0.0960
# Epoch 12/200
# 147696/147696 [==============================] - 409s 3ms/step - loss: 0.0720 - msle: 0.0720 - val_loss: 0.1021 - val_msle: 0.1021
# Epoch 13/200
# 147696/147696 [==============================] - 406s 3ms/step - loss: 0.0745 - msle: 0.0745 - val_loss: 0.0967 - val_msle: 0.0967
# Epoch 14/200
# 147696/147696 [==============================] - 408s 3ms/step - loss: 0.0758 - msle: 0.0758 - val_loss: 0.1090 - val_msle: 0.1090
# Epoch 15/200
# 147696/147696 [==============================] - 403s 3ms/step - loss: 0.0747 - msle: 0.0747 - val_loss: 0.1024 - val_msle: 0.1024
# Epoch 16/200
# 147696/147696 [==============================] - 406s 3ms/step - loss: 0.0773 - msle: 0.0773 - val_loss: 0.0944 - val_msle: 0.0944
# Epoch 17/200
# 147696/147696 [==============================] - 404s 3ms/step - loss: 0.0746 - msle: 0.0746 - val_loss: 0.0950 - val_msle: 0.0950
# Epoch 18/200
# 147696/147696 [==============================] - 396s 3ms/step - loss: 0.0750 - msle: 0.0750 - val_loss: 0.0932 - val_msle: 0.0932
# Epoch 19/200
# 147696/147696 [==============================] - 397s 3ms/step - loss: 0.0749 - msle: 0.0749 - val_loss: 0.1033 - val_msle: 0.1033
# Epoch 20/200
# 147696/147696 [==============================] - 399s 3ms/step - loss: 0.0744 - msle: 0.0744 - val_loss: 0.0949 - val_msle: 0.0949
# Epoch 21/200
# 147696/147696 [==============================] - 399s 3ms/step - loss: 0.0769 - msle: 0.0769 - val_loss: 0.0986 - val_msle: 0.0986
# Epoch 22/200
# 147696/147696 [==============================] - 404s 3ms/step - loss: 0.0779 - msle: 0.0779 - val_loss: 0.1001 - val_msle: 0.1001
# Epoch 23/200
# 147696/147696 [==============================] - 403s 3ms/step - loss: 0.0786 - msle: 0.0786 - val_loss: 0.0978 - val_msle: 0.0978
# Epoch 24/200
# 147696/147696 [==============================] - 391s 3ms/step - loss: 0.0727 - msle: 0.0727 - val_loss: 0.0970 - val_msle: 0.0970
# Epoch 25/200
# 147696/147696 [==============================] - 395s 3ms/step - loss: 0.0755 - msle: 0.0755 - val_loss: 0.0977 - val_msle: 0.0977
# Epoch 00025: early stopping
# 105/105 [==============================] - 0s 3ms/step - loss: 0.1337 - msle: 0.1337
# --- Starting trial: run-10
# {'num_batch': 2, 'num_neurons': 8, 'dropout': 0.1}
# Epoch 1/200
#     2/73848 [..............................] - ETA: 59:04 - loss: 4.1446 - msle: 4.1446WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0048s vs `on_train_batch_end` time: 0.0908s). Check your callbacks.
# 73848/73848 [==============================] - 161s 2ms/step - loss: 0.1429 - msle: 0.1429 - val_loss: 0.0996 - val_msle: 0.0996
# Epoch 2/200
# 73848/73848 [==============================] - 158s 2ms/step - loss: 0.1046 - msle: 0.1046 - val_loss: 0.0937 - val_msle: 0.0937
# Epoch 3/200
# 73848/73848 [==============================] - 156s 2ms/step - loss: 0.1019 - msle: 0.1019 - val_loss: 0.0975 - val_msle: 0.0975
# Epoch 4/200
# 73848/73848 [==============================] - 158s 2ms/step - loss: 0.0994 - msle: 0.0994 - val_loss: 0.0986 - val_msle: 0.0986
# Epoch 5/200
# 73848/73848 [==============================] - 155s 2ms/step - loss: 0.0998 - msle: 0.0998 - val_loss: 0.0910 - val_msle: 0.0910
# Epoch 6/200
# 73848/73848 [==============================] - 157s 2ms/step - loss: 0.1015 - msle: 0.1015 - val_loss: 0.0936 - val_msle: 0.0936
# Epoch 7/200
# 73848/73848 [==============================] - 156s 2ms/step - loss: 0.1014 - msle: 0.1014 - val_loss: 0.0901 - val_msle: 0.0901
# Epoch 8/200
# 73848/73848 [==============================] - 155s 2ms/step - loss: 0.0991 - msle: 0.0991 - val_loss: 0.0901 - val_msle: 0.0901
# Epoch 9/200
# 73848/73848 [==============================] - 159s 2ms/step - loss: 0.0976 - msle: 0.0976 - val_loss: 0.0884 - val_msle: 0.0884
# Epoch 10/200
# 73848/73848 [==============================] - 158s 2ms/step - loss: 0.0969 - msle: 0.0969 - val_loss: 0.0911 - val_msle: 0.0911
# Epoch 11/200
# 73848/73848 [==============================] - 156s 2ms/step - loss: 0.0966 - msle: 0.0966 - val_loss: 0.0921 - val_msle: 0.0921
# Epoch 12/200
# 73848/73848 [==============================] - 161s 2ms/step - loss: 0.0972 - msle: 0.0972 - val_loss: 0.0890 - val_msle: 0.0890
# Epoch 13/200
# 73848/73848 [==============================] - 159s 2ms/step - loss: 0.0959 - msle: 0.0959 - val_loss: 0.0877 - val_msle: 0.0877
# Epoch 14/200
# 73848/73848 [==============================] - 154s 2ms/step - loss: 0.0954 - msle: 0.0954 - val_loss: 0.0882 - val_msle: 0.0882
# Epoch 15/200
# 73848/73848 [==============================] - 159s 2ms/step - loss: 0.0952 - msle: 0.0952 - val_loss: 0.0901 - val_msle: 0.0901
# Epoch 16/200
# 73848/73848 [==============================] - 153s 2ms/step - loss: 0.0948 - msle: 0.0948 - val_loss: 0.0921 - val_msle: 0.0921
# Epoch 17/200
# 73848/73848 [==============================] - 152s 2ms/step - loss: 0.0941 - msle: 0.0941 - val_loss: 0.0901 - val_msle: 0.0901
# Epoch 18/200
# 73848/73848 [==============================] - 158s 2ms/step - loss: 0.0940 - msle: 0.0940 - val_loss: 0.0928 - val_msle: 0.0928
# Epoch 19/200
# 73848/73848 [==============================] - 157s 2ms/step - loss: 0.0943 - msle: 0.0943 - val_loss: 0.0891 - val_msle: 0.0891
# Epoch 20/200
# 73848/73848 [==============================] - 156s 2ms/step - loss: 0.0940 - msle: 0.0940 - val_loss: 0.0891 - val_msle: 0.0891
# Epoch 00020: early stopping
# 105/105 [==============================] - 0s 1ms/step - loss: 0.1067 - msle: 0.1067
# --- Starting trial: run-11
# {'num_batch': 2, 'num_neurons': 8, 'dropout': 0.2}
# Epoch 1/200
#     2/73848 [..............................] - ETA: 58:12 - loss: 4.1459 - msle: 4.1459WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0045s vs `on_train_batch_end` time: 0.0898s). Check your callbacks.
# 73848/73848 [==============================] - 157s 2ms/step - loss: 0.1531 - msle: 0.1531 - val_loss: 0.0963 - val_msle: 0.0963
# Epoch 2/200
# 73848/73848 [==============================] - 157s 2ms/step - loss: 0.1105 - msle: 0.1105 - val_loss: 0.0936 - val_msle: 0.0936
# Epoch 3/200
# 73848/73848 [==============================] - 154s 2ms/step - loss: 0.1035 - msle: 0.1035 - val_loss: 0.0891 - val_msle: 0.0891
# Epoch 4/200
# 73848/73848 [==============================] - 154s 2ms/step - loss: 0.1017 - msle: 0.1017 - val_loss: 0.0960 - val_msle: 0.0960
# Epoch 5/200
# 73848/73848 [==============================] - 152s 2ms/step - loss: 0.0998 - msle: 0.0998 - val_loss: 0.0920 - val_msle: 0.0920
# Epoch 6/200
# 73848/73848 [==============================] - 151s 2ms/step - loss: 0.0998 - msle: 0.0998 - val_loss: 0.0888 - val_msle: 0.0888
# Epoch 7/200
# 73848/73848 [==============================] - 156s 2ms/step - loss: 0.1052 - msle: 0.1052 - val_loss: 0.0937 - val_msle: 0.0937
# Epoch 8/200
# 73848/73848 [==============================] - 152s 2ms/step - loss: 0.0988 - msle: 0.0988 - val_loss: 0.0893 - val_msle: 0.0893
# Epoch 9/200
# 73848/73848 [==============================] - 154s 2ms/step - loss: 0.0996 - msle: 0.0996 - val_loss: 0.0895 - val_msle: 0.0895
# Epoch 10/200
# 73848/73848 [==============================] - 157s 2ms/step - loss: 0.0983 - msle: 0.0983 - val_loss: 0.0900 - val_msle: 0.0900
# Epoch 11/200
# 73848/73848 [==============================] - 159s 2ms/step - loss: 0.0981 - msle: 0.0981 - val_loss: 0.0906 - val_msle: 0.0906
# Epoch 12/200
# 21645/73848 [=======>......................] - ETA: 1:45 - loss: 0.0980 - msle: 0.0980

# %%
# Fitting the model
model = deep_learner.LSTModel ()
# Out:
# Epoch 1/200
# 1196/1196 [==============================] - 4s 3ms/step - loss: 0.2363 - val_loss: 0.0629
# Epoch 2/200
# 1196/1196 [==============================] - 3s 3ms/step - loss: 0.0608 - val_loss: 0.0592
# Epoch 3/200
# 1196/1196 [==============================] - 3s 3ms/step - loss: 0.0578 - val_loss: 0.0627
# Epoch 4/200
# 1196/1196 [==============================] - 3s 3ms/step - loss: 0.0548 - val_loss: 0.0599
# Epoch 5/200
# 1196/1196 [==============================] - 3s 3ms/step - loss: 0.0526 - val_loss: 0.0573
# Epoch 6/200
# 1196/1196 [==============================] - 3s 3ms/step - loss: 0.0512 - val_loss: 0.0588
# Epoch 7/200
# 1196/1196 [==============================] - 3s 3ms/step - loss: 0.0504 - val_loss: 0.0605
# Epoch 8/200
# 1196/1196 [==============================] - 3s 3ms/step - loss: 0.0500 - val_loss: 0.0600
# Epoch 9/200
# 1196/1196 [==============================] - 3s 3ms/step - loss: 0.0497 - val_loss: 0.0588
# Epoch 10/200
# 1196/1196 [==============================] - 3s 3ms/step - loss: 0.0494 - val_loss: 0.0579
# Epoch 11/200
# 1196/1196 [==============================] - 3s 3ms/step - loss: 0.0492 - val_loss: 0.0572
# Epoch 12/200
# 1196/1196 [==============================] - 3s 3ms/step - loss: 0.0489 - val_loss: 0.0567
# Epoch 13/200
# 1196/1196 [==============================] - 3s 3ms/step - loss: 0.0487 - val_loss: 0.0562
# Epoch 14/200
# 1196/1196 [==============================] - 3s 3ms/step - loss: 0.0485 - val_loss: 0.0557
# Epoch 15/200
# 1196/1196 [==============================] - 3s 2ms/step - loss: 0.0483 - val_loss: 0.0554
# Epoch 16/200
# 1196/1196 [==============================] - 3s 2ms/step - loss: 0.0481 - val_loss: 0.0552
# Epoch 17/200
# 1196/1196 [==============================] - 3s 2ms/step - loss: 0.0479 - val_loss: 0.0552
# Epoch 18/200
# 1196/1196 [==============================] - 3s 2ms/step - loss: 0.0477 - val_loss: 0.0554
# Epoch 19/200
# 1196/1196 [==============================] - 3s 2ms/step - loss: 0.0476 - val_loss: 0.0552
# Epoch 20/200
# 1196/1196 [==============================] - 3s 2ms/step - loss: 0.0474 - val_loss: 0.0549
# Epoch 21/200
# 1196/1196 [==============================] - 3s 2ms/step - loss: 0.0473 - val_loss: 0.0546
# Epoch 22/200
# 1196/1196 [==============================] - 3s 2ms/step - loss: 0.0472 - val_loss: 0.0543
# Epoch 23/200
# 1196/1196 [==============================] - 3s 2ms/step - loss: 0.0471 - val_loss: 0.0540
# Epoch 24/200
# 1196/1196 [==============================] - 3s 2ms/step - loss: 0.0470 - val_loss: 0.0536
# Epoch 25/200
# 1196/1196 [==============================] - 3s 2ms/step - loss: 0.0469 - val_loss: 0.0532
# Epoch 26/200
# 1196/1196 [==============================] - 3s 2ms/step - loss: 0.0468 - val_loss: 0.0530
# Epoch 27/200
# 1196/1196 [==============================] - 3s 2ms/step - loss: 0.0467 - val_loss: 0.0527
# Epoch 28/200
# 1196/1196 [==============================] - 3s 3ms/step - loss: 0.0466 - val_loss: 0.0524
# Epoch 29/200
# 1196/1196 [==============================] - 3s 3ms/step - loss: 0.0466 - val_loss: 0.0521
# Epoch 30/200
# 1196/1196 [==============================] - 3s 3ms/step - loss: 0.0465 - val_loss: 0.0518
# Epoch 31/200
# 1196/1196 [==============================] - 3s 2ms/step - loss: 0.0464 - val_loss: 0.0516
# Epoch 32/200
# 1196/1196 [==============================] - 3s 2ms/step - loss: 0.0464 - val_loss: 0.0513
# Epoch 33/200
# 1196/1196 [==============================] - 3s 2ms/step - loss: 0.0463 - val_loss: 0.0510
# Epoch 34/200
# 1196/1196 [==============================] - 3s 3ms/step - loss: 0.0462 - val_loss: 0.0508
# Epoch 35/200
# 1196/1196 [==============================] - 3s 3ms/step - loss: 0.0462 - val_loss: 0.0506
# Epoch 36/200
# 1196/1196 [==============================] - 3s 3ms/step - loss: 0.0461 - val_loss: 0.0504
# Epoch 37/200
# 1196/1196 [==============================] - 3s 3ms/step - loss: 0.0461 - val_loss: 0.0503
# Epoch 38/200
# 1196/1196 [==============================] - 3s 3ms/step - loss: 0.0460 - val_loss: 0.0500
# Epoch 39/200
# 1196/1196 [==============================] - 3s 3ms/step - loss: 0.0460 - val_loss: 0.0499
# Epoch 40/200
# 1196/1196 [==============================] - 3s 3ms/step - loss: 0.0459 - val_loss: 0.0497
# Epoch 41/200
# 1196/1196 [==============================] - 3s 3ms/step - loss: 0.0459 - val_loss: 0.0495
# Epoch 42/200
# 1196/1196 [==============================] - 3s 3ms/step - loss: 0.0459 - val_loss: 0.0494
# Epoch 43/200
# 1196/1196 [==============================] - 3s 3ms/step - loss: 0.0458 - val_loss: 0.0492
# Epoch 44/200
# 1196/1196 [==============================] - 3s 3ms/step - loss: 0.0458 - val_loss: 0.0491
# Epoch 45/200
# 1196/1196 [==============================] - 3s 3ms/step - loss: 0.0457 - val_loss: 0.0490
# Epoch 46/200
# 1196/1196 [==============================] - 3s 2ms/step - loss: 0.0457 - val_loss: 0.0489
# Epoch 47/200
# 1196/1196 [==============================] - 3s 2ms/step - loss: 0.0456 - val_loss: 0.0488
# Epoch 48/200
# 1196/1196 [==============================] - 3s 2ms/step - loss: 0.0456 - val_loss: 0.0487
# Epoch 49/200
# 1196/1196 [==============================] - 3s 3ms/step - loss: 0.0455 - val_loss: 0.0486
# Epoch 50/200
# 1196/1196 [==============================] - 3s 3ms/step - loss: 0.0455 - val_loss: 0.0485
# Epoch 51/200
# 1196/1196 [==============================] - 3s 3ms/step - loss: 0.0454 - val_loss: 0.0485
# Epoch 52/200
# 1196/1196 [==============================] - 3s 3ms/step - loss: 0.0454 - val_loss: 0.0483
# Epoch 53/200
# 1196/1196 [==============================] - 3s 3ms/step - loss: 0.0454 - val_loss: 0.0482
# Epoch 54/200
# 1196/1196 [==============================] - 3s 3ms/step - loss: 0.0453 - val_loss: 0.0482
# Epoch 55/200
# 1196/1196 [==============================] - 3s 3ms/step - loss: 0.0453 - val_loss: 0.0481
# Epoch 56/200
# 1196/1196 [==============================] - 3s 3ms/step - loss: 0.0452 - val_loss: 0.0480
# Epoch 57/200
# 1196/1196 [==============================] - 3s 3ms/step - loss: 0.0452 - val_loss: 0.0479
# Epoch 58/200
# 1196/1196 [==============================] - 3s 3ms/step - loss: 0.0452 - val_loss: 0.0479
# Epoch 59/200
# 1196/1196 [==============================] - 3s 3ms/step - loss: 0.0451 - val_loss: 0.0478
# Epoch 60/200
# 1196/1196 [==============================] - 3s 3ms/step - loss: 0.0451 - val_loss: 0.0478
# Epoch 61/200
# 1196/1196 [==============================] - 3s 3ms/step - loss: 0.0451 - val_loss: 0.0477
# Epoch 62/200
# 1196/1196 [==============================] - 3s 3ms/step - loss: 0.0450 - val_loss: 0.0477
# Epoch 63/200
# 1196/1196 [==============================] - 3s 3ms/step - loss: 0.0450 - val_loss: 0.0477
# Epoch 64/200
# 1196/1196 [==============================] - 3s 3ms/step - loss: 0.0450 - val_loss: 0.0477
# Epoch 65/200
# 1196/1196 [==============================] - 3s 3ms/step - loss: 0.0449 - val_loss: 0.0476
# Epoch 66/200
# 1196/1196 [==============================] - 3s 3ms/step - loss: 0.0449 - val_loss: 0.0476
# Epoch 67/200
# 1196/1196 [==============================] - 3s 3ms/step - loss: 0.0449 - val_loss: 0.0476
# Epoch 68/200
# 1196/1196 [==============================] - 3s 3ms/step - loss: 0.0449 - val_loss: 0.0476
# Epoch 69/200
# 1196/1196 [==============================] - 3s 3ms/step - loss: 0.0448 - val_loss: 0.0475
# Epoch 70/200
# 1196/1196 [==============================] - 3s 3ms/step - loss: 0.0448 - val_loss: 0.0475
# Epoch 71/200
# 1196/1196 [==============================] - 3s 3ms/step - loss: 0.0448 - val_loss: 0.0474
# Epoch 72/200
# 1196/1196 [==============================] - 3s 3ms/step - loss: 0.0447 - val_loss: 0.0474
# Epoch 73/200
# 1196/1196 [==============================] - 3s 3ms/step - loss: 0.0447 - val_loss: 0.0474
# Epoch 74/200
# 1196/1196 [==============================] - 3s 3ms/step - loss: 0.0447 - val_loss: 0.0474
# Epoch 75/200
# 1196/1196 [==============================] - 3s 3ms/step - loss: 0.0447 - val_loss: 0.0474
# Epoch 76/200
# 1196/1196 [==============================] - 3s 3ms/step - loss: 0.0446 - val_loss: 0.0474
# Epoch 77/200
# 1196/1196 [==============================] - 3s 3ms/step - loss: 0.0446 - val_loss: 0.0474
# Epoch 78/200
# 1196/1196 [==============================] - 3s 3ms/step - loss: 0.0446 - val_loss: 0.0474
# Epoch 79/200
# 1196/1196 [==============================] - 3s 3ms/step - loss: 0.0446 - val_loss: 0.0474
# Epoch 80/200
# 1196/1196 [==============================] - 3s 3ms/step - loss: 0.0445 - val_loss: 0.0474
# Epoch 81/200
# 1196/1196 [==============================] - 3s 3ms/step - loss: 0.0445 - val_loss: 0.0474
# Epoch 82/200
# 1196/1196 [==============================] - 3s 3ms/step - loss: 0.0445 - val_loss: 0.0474
# Epoch 83/200
# 1196/1196 [==============================] - 3s 3ms/step - loss: 0.0445 - val_loss: 0.0474
# Epoch 84/200
# 1196/1196 [==============================] - 3s 3ms/step - loss: 0.0445 - val_loss: 0.0474
# Epoch 85/200
# 1196/1196 [==============================] - 3s 3ms/step - loss: 0.0444 - val_loss: 0.0474
# Epoch 86/200
# 1196/1196 [==============================] - 3s 3ms/step - loss: 0.0444 - val_loss: 0.0474
# Epoch 87/200
# 1196/1196 [==============================] - 3s 3ms/step - loss: 0.0444 - val_loss: 0.0474
# Epoch 88/200
# 1196/1196 [==============================] - 3s 3ms/step - loss: 0.0444 - val_loss: 0.0474
# Epoch 89/200
# 1196/1196 [==============================] - 3s 3ms/step - loss: 0.0443 - val_loss: 0.0474
# Epoch 90/200
# 1196/1196 [==============================] - 3s 3ms/step - loss: 0.0443 - val_loss: 0.0474
# Epoch 91/200
# 1196/1196 [==============================] - 3s 3ms/step - loss: 0.0443 - val_loss: 0.0474
# Epoch 92/200
# 1196/1196 [==============================] - 3s 3ms/step - loss: 0.0443 - val_loss: 0.0474
# Epoch 93/200
# 1196/1196 [==============================] - 3s 3ms/step - loss: 0.0443 - val_loss: 0.0474
# Epoch 94/200
# 1196/1196 [==============================] - 3s 3ms/step - loss: 0.0442 - val_loss: 0.0474
# Epoch 95/200
# 1196/1196 [==============================] - 3s 2ms/step - loss: 0.0442 - val_loss: 0.0474
# Epoch 00095: early stopping

# %%
deep_learner.plot_test()

# %%
deep_learner.test = deep_learner.evaluate_n_ahead(672)
# Out:
# Loaded model from disk
# RMSE: 3.238013 [kWh]
# MAPE: 28.755458 %
