# %%
import pandas as pd
import numpy as np
from numpy import log
import datetime as dt
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
from workalendar.america import Canada
import itertools
import sys
# Deep learning: 
import tensorflow as tf
from tensorboard.plugins.hparams import api as hp
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.callbacks import CSVLogger
from tensorflow.keras.models import model_from_json
import itertools
from sklearn.preprocessing import MinMaxScaler
np.set_printoptions(threshold=sys.maxsize)

DAYS_IN_YEAR = 365
HOURS_IN_DAY = 24
DAYS_OF_WEEK = ['week_1','week_2','week_3','week_4','week_5','week_6','week_7']
MINUTES_IN_HOUR = 60
SECONDS_IN_MINUTE = 60
MINUTES_IN_DAY = MINUTES_IN_HOUR * HOURS_IN_DAY

# %%
class DeepModelTS():
    """
    A class to create a deep time series model
    """
    def __init__(
        self, 
        data_path: str,
        Y_var: str,
        model_save: str,
        model_load: str,
        granularity: str,
        export_file_path: str,
        lag: int,
        lag2: int,
        n_test: int,
        LSTM_layer_depth: int, 
        batch_size: int,
        epochs: int, 
        train_test_split=0,
        
    ):
        
        self.data_path = data_path
        self.model_save = model_save
        self.model_load = model_load
        self.granularity = granularity
        self.export_file_path = export_file_path
        self.Y_var = Y_var 
        self.lag = lag 
        self.lag2 = lag2
        self.LSTM_layer_depth = LSTM_layer_depth
        self.batch_size = batch_size
        self.epochs = epochs
        self.train_test_split = train_test_split
        self.n_test = n_test
        self.data = pd.read_csv(data_path, index_col=0)
        self.data = self.preprocess(self.data)
    
    @classmethod
    def get_fractional_hour_from_series(self, series: pd.Series) -> pd.Series:
        """
        Return fractional hour in range 0-24, e.g. 12h30m --> 12.5.
        Accurate to 1 minute.
        """
        hour = series.hour
        minute = series.minute
        return hour + minute / MINUTES_IN_HOUR

    @classmethod
    def get_fractional_day_from_series(self, series: pd.Series) -> pd.Series:
        """
        Return fractional day in range 0-1, e.g. 12h30m --> 0.521.
        Accurate to 1 minute
        """
        fractional_hours = self.get_fractional_hour_from_series(series)
        return fractional_hours / HOURS_IN_DAY

    @classmethod
    def get_fractional_year_from_series(self, series: pd.Series) -> pd.Series:
        """
        Return fractional year in range 0-1.
        Accurate to 1 day
        """
        return (series.dayofyear - 1) / DAYS_IN_YEAR

    def preprocess(self, dataframe):
        dataframe.index = pd.to_datetime(dataframe.index)
        # Removing duplicates
        dataframe = dataframe[~dataframe.index.duplicated()]
        
        #Filling NaN values
        dataframe = dataframe.interpolate()
        
        # Setting the calendar holidats
        cal = Canada()
        years = list(range(2014, 2025))
        holidays = []
        for year in years:
            holidays.extend(cal.holidays(year))
            
        dataframe = dataframe.sort_index()
        
        #print('preprocess:')
        #print(dataframe.columns)
        # Rename the target column to 'Valeur' for convenience
        dataframe.rename(columns={dataframe.columns[0]: self.Y_var}, inplace=True)
        
        # Logarithmic transform add 1 for non-negative data (zeros in the series)
        #dataframe[self.Y_var] = log(dataframe[self.Y_var] + 1)
        
        #working day {0,1}
        dataframe['working day'] = dataframe.index.map(cal.is_working_day).astype(np.float32)
        
        #fractional hour [0,1]
        dataframe['fractional hour'] = self.get_fractional_day_from_series(dataframe.index)
        
        # day of week one-hot encoded
        dataframe['day of week'] = dataframe.index.dayofweek + 1
        dataframe['day of week'] = pd.Categorical(dataframe['day of week'], categories=[1,2,3,4,5,6,7], ordered=True)
        dataframe = pd.get_dummies(dataframe,prefix=['week'], columns = ['day of week'], drop_first=False)
        #dataframe = pd.concat([dataframe, pd.DataFrame(columns=DAYS_OF_WEEK)]).fillna(0)
        
        
        # fractional day of year
        dataframe['day of year'] = self.get_fractional_year_from_series(dataframe.index)
        
        # we encode cynical data into two dimensions using a sine and cosine transformations
        def encode(data, col, max_val):
            data[col + '_sin'] = np.sin(2 * np.pi * data[col]/max_val)
            data[col + '_cos'] = np.cos(2 * np.pi * data[col]/max_val)
            return data
        dataframe = encode(dataframe, 'fractional hour', HOURS_IN_DAY)
        dataframe = encode(dataframe, 'day of year', DAYS_IN_YEAR)
        # dropping original columns
        dataframe = dataframe.drop(['fractional hour','day of year'], axis=1)
        return dataframe
    
    @staticmethod    
    def plot_train_history(model):
        '''
        Convergence plots to have an idea on how the training performs
        '''
        loss = model.history.history['loss']
        val_loss = model.history.history['val_loss']
        plt.figure()
        plt.plot(range(len(loss)), loss, 'b', label='Training loss')
        plt.plot(range(len(val_loss)), val_loss, 'r', label='Validation loss')
        #plt.yscale("log")
        plt.xlabel('Epochs')
        plt.ylabel('Losses')
        plt.title('Training and validation losses')
        plt.legend()
        plt.show() 
    
    @staticmethod
    def validation(forecasted, real, parameter):
        ''' 
        compute some important parameters to compare forecasting results
        '''
        value = 0
        value_1 = 0
        value_2 = 0

        if parameter == 'SMAPE':
            for i in range(len(forecasted)):
                if real[i] + forecasted[i] == 0:
                    value += 0
                else: 
                    value += ((abs(real[i] - forecasted[i])) / (real[i] + forecasted[i])) * 100
            final_value = value / len(forecasted)  

        elif parameter == 'MAPE':
            for i in range(len(forecasted)):
                if real[i] == 0:
                    value += 0
                else: 
                    value += (abs(real[i] - forecasted[i]))/real[i]
            final_value = value / len(forecasted) * 100

        elif parameter == 'RMSE':
            for i in range(len(forecasted)):
                value += (real[i] - forecasted[i]) ** 2
            final_value = (value / len(forecasted)) ** (1 / 2) 

        elif parameter == 'R':
            for i in range(len(forecasted)):
                value += (real[i] - np.mean(real)) * (forecasted[i] - np.mean(forecasted))
                value_1 += (real[i] - np.mean(real)) ** 2
                value_2 += (forecasted[i] - np.mean(forecasted)) ** 2

            if value_1 == 0 or value_2 == 0:
                final_value = 100
            else:
                final_value = (value / ((value_1 ** (1 / 2)) * (value_2 ** (1 / 2))))*100

        return final_value
    
    def normalize(self, tensor):
        self.scaler = MinMaxScaler(feature_range=(0, 1))
        tensor = self.scaler.fit_transform(tensor)
        return tensor
    
    def denormalize(self, tensor):
        tensor = self.scaler.inverse_transform(tensor)
        return tensor      

    # convert series to supervised learning
    def series_to_supervised(self, data, dropnan=True):
        n_vars = 1
        df = pd.DataFrame(data)
        cols, names = list(), list()
        # input sequence (t-n, ... t-1)
        for i in [self.lag, self.lag2]:
            cols.append(df[self.Y_var].shift(i))
            names += [(self.Y_var+'(t-%d)' % (i))]
        # put it all together
        agg = pd.concat(cols, axis=1)
        agg.columns = names
        # drop rows with NaN values
        if dropnan:
            agg.dropna(inplace=True)
        return agg   
    
    def create_data_for_NN(self):
        reframed = self.data.merge(self.series_to_supervised(self.data), how='right', left_index=True, right_index=True)
        #print(reframed.head())
        # Normalize with a MinMax Scaler
        reframed = self.normalize(reframed)
        #reframed = np.array(reframed)
        #print(reframed[:10])
        
        #Assign validation data to fix referencing
        X_val, Y_val = [], []
        
        test = reframed[-self.n_test:]
        index = len(reframed) - self.n_test
        train = reframed[:round(index * (1-self.train_test_split))]
        if self.train_test_split > 0:
            val = reframed[round(index * (1-self.train_test_split)):index]
            
        X_train, Y_train = train[:, 1:], train[:, 0]
        if self.train_test_split > 0:
            X_val, Y_val = val[:, 1:], val[:, 0]
        X_test, Y_test = test[:, 1:], test[:, 0]
        
        #print(X_train[:10])
        
        X_train = X_train.reshape((X_train.shape[0], 1, X_train.shape[1]))
        if self.train_test_split > 0:
            X_val = X_val.reshape((X_val.shape[0], 1, X_val.shape[1]))
        #print(X_test.shape)
        X_test = X_test.reshape((X_test.shape[0], 1, X_test.shape[1]))
        #print(X_train.shape, Y_train.shape, X_test.shape, Y_test.shape)
        
        return X_train, X_val, X_test, Y_train, Y_val, Y_test
    
    def save_model(self, model):
        model_json = model.to_json()
        with open(self.model_save+'.json', "w") as json_file:
            json_file.write(model_json)
        # serialize weights to HDF5
        model.save_weights(self.model_save+'.h5')
        print("Model saved to disk")
          
    def load_model(self):
        # load json and create model
        json_file = open(self.model_load+".json", 'r')
        loaded_model_json = json_file.read()
        json_file.close()
        self.model = model_from_json(loaded_model_json)
        # load weights into new model
        self.model.load_weights(self.model_load+".h5")
        print("Loaded model from disk")
    
    def LSTModel(self):
        """
        A method to fit the LSTM model 
        """
        # Getting the data 
        X_train, X_val, X_test, Y_train, Y_val, Y_test = self.create_data_for_NN()

        # Defining the model
        model = Sequential()
        model.add(LSTM(self.LSTM_layer_depth, activation='relu', return_sequences=True, input_shape=(X_train.shape[1],X_train.shape[2])))
        model.add(LSTM(self.LSTM_layer_depth, activation='relu'))
        model.add(tf.keras.layers.Dropout(0.2))
        model.add(Dense(1))
        model.compile(optimizer='adam', loss='mae')
        
        # Setting up early stopping
        earlyStop=EarlyStopping(monitor="val_loss",verbose=1,mode='min',patience=10)
        
        # Saving training history
        csv_logger = CSVLogger('training_B2_25ep.log', separator=',', append=False)
        
        # Defining the model parameter dict 
        keras_dict = {
            'x': X_train,
            'y': Y_train,
            'batch_size': self.batch_size,
            'epochs': self.epochs,
            'shuffle': False,
            'callbacks': [earlyStop, csv_logger]
            #'callbacks': [csv_logger]

        }

        if self.train_test_split > 0:
            keras_dict.update({
                'validation_data': (X_val, Y_val)
            })

        # Fitting the model 
        model.fit(
            **keras_dict
        )

        # Saving the model to the class 
        self.model = model
        # Plotting train history
        if self.train_test_split > 0:
            self.plot_train_history(model)
        # Saving the model in json and h5
        self.save_model(self.model)
        
        return model  

    def predict(self) -> list:
        """
        A method to predict using the test data used in creating the class
        """
        yhat = []

        # Getting the last n time series 
        _, _, X_test, _, _, Y_test = self.create_data_for_NN()
        
        # Making the prediction list 
        yhat = self.model.predict(X_test)

        # Reshape for merging with predictions
        X_test = X_test.reshape(X_test.shape[0], X_test.shape[2])

        # invert scaling for forecast
        inv_yhat = np.concatenate((yhat, X_test), axis=1)

        # denormalize
        inv_yhat = self.scaler.inverse_transform(inv_yhat)

        # invert scaling for actual
        Y_test = Y_test.reshape((len(Y_test), 1))

        inv_y = np.concatenate((Y_test, X_test), axis=1)

        # denormalize
        inv_y = self.scaler.inverse_transform(inv_y)
        
        act = [i[0] for i in inv_y] # last element is the predicted average energy
        pred = [i[0] for i in inv_yhat] # last element is the actual average energy

        # Reverse the log transformation and substract by one if the data contains zero
        #act = np.exp(act) - 1
        #pred = np.exp(pred) - 1
        
        return act, pred
    
    def results(self):
        expected, predictions = self.predict()# Constructing the forecast dataframe
        
        print('RMSE: %f [kWh]' % self.validation(predictions,expected, 'RMSE'))
        print('MAPE: %f %%' % self.validation(predictions,expected, 'MAPE'))
        print('\n')
    
    def plot_test(self):
        expected, predictions = self.predict()# Constructing the forecast dataframe      
        fc = self.data.tail(len(expected)).copy()
        print('RMSE: %f [kWh]' % self.validation(predictions,expected, 'RMSE'))
        print('MAPE: %f %%' % self.validation(predictions,expected, 'MAPE'))
        # Ploting the forecasts
        plt.figure(figsize=(12, 8))
        #for dtype in ['Valeur', 'forecast']:  
        plt.plot(fc.index, expected, label='Valeur',alpha=0.7)
        plt.plot(fc.index, predictions, label='forecast',alpha=0.7)
        plt.legend()
        plt.grid()

        plt.gca().set(ylabel='Consumption [kWh]', xlabel='timestamp')
        plt.yticks(fontsize=12, alpha=.7)
        plt.title("Consumption for test data", fontsize=20)

        plt.show()
    
    def predict_n_ahead(self, data_input, n_ahead: int):
        # Set up a dataset with n timestamps ahead
        dates = pd.date_range(data_input.index[-1], periods = n_ahead+1, freq=self.granularity)[1:]
        test = data_input.append(pd.DataFrame(index=dates))
        test.index=data_input.index.union(dates)

        # Add all temporal features
        test = self.preprocess(test)
        
        # Merge temporal features with lags
        test = test.merge(self.series_to_supervised(test), how='right', left_index=True, right_index=True)
        
        # Normalize with a MinMax scaler
        test = self.normalize(test)
        
        # Take out the forecasted metric
        test = test[:, 1:]
        
        # Reshape the tensor to LSTM input
        test = test.reshape((test.shape[0], 1, test.shape[1]))
        
        # Forecast for n_ahead steps ahead
        yhat = []
        yhat = self.model.predict(test)
        
        # Reshape for merging with predictions
        test = test.reshape(test.shape[0], test.shape[2])
        
        # invert scaling for forecast
        inv_yhat = np.concatenate((yhat, test), axis=1)
        
        # denormalize
        inv_yhat = self.scaler.inverse_transform(inv_yhat)
        
        yhat = [i[0] for i in inv_yhat] # last element is the predicted average energy
        return yhat[-n_ahead:]
    
    def evaluate_n_ahead(self, data_temp, n_ahead: int):
        # take the user input dataset as the one we predict ahead for
        yhat = []
        predictions = []
        # Rename the first column so it is consistent along the code
        data_temp.rename(columns={data_temp.columns[0]: self.Y_var}, inplace=True)
        data_temp.index = pd.to_datetime(data_temp.index)
        # Load model if no preloaded
        if hasattr('self', 'model') == False:
            self.load_model()
        # Slide through the dataset by window of 96 steps and refeed the predictions into inputs
        for i in tf.range(n_ahead//self.lag+1):
            y_hat = self.predict_n_ahead(data_temp, self.lag)
            data_temp = data_temp.append(pd.DataFrame(y_hat, columns=['Valeur'], index=pd.date_range(data_temp.index[-1], periods = self.lag+1, freq=self.granularity)[1:]))
            data_temp.drop(data_temp.head(self.lag).index, inplace=True)
            predictions.extend(y_hat)
        # Create a dataset for predictions
        predictions = predictions[:n_ahead]
        dates = pd.date_range(data_temp.index[-1], periods = n_ahead+1, freq=self.granularity)[1:]
        test = pd.DataFrame(predictions)
        test.index = dates
        test.index = pd.to_datetime(test.index)
        # Save to a csv
        test.to_csv(self.export_file_path, index=True)
        #expected = test_range.head(n_ahead).loc[:,"Valeur"]
        
        #predictions = test.iloc[:,0]
        #print('RMSE: %f [kWh]' % self.validation(predictions,expected, 'RMSE'))
        #print('MAPE: %f %%' % self.validation(predictions,expected, 'MAPE'))
        plt.figure(figsize=(25, 10))
        plt.grid()
        plt.gca().set(ylabel='Consumption [kWh]', xlabel='timestamp')
        plt.yticks(fontsize=12, alpha=.7)
        plt.title("Consumption forecast for given days ahead", fontsize=20)
        #plt.plot(test_range.index, test_range.loc[:,"Valeur"], color='orange', label='test', alpha=0.7)
        plt.plot(data_temp.index, data_temp.loc[:,"Valeur"], color='b', label='user input data', alpha=0.5)
        plt.plot(dates, predictions, color='black', linestyle='--', linewidth=3, label='Forecaster model',alpha=0.7)
        plt.legend(prop={'size': 20})
        return test

# %%
deep_learner = DeepModelTS(
# USER INPUT SETTINGS
Y_var = 'Valeur',
model_load = "model_B1_complete",
granularity = 'D',
export_file_path = './predictions.csv',
# TRAINING SETTINGS
#data_path = '../data/Columbia_clean/Residential_18.csv',
data_path = '../data/EFC2012_clean/zone_1.csv',
#data = holidata,
model_save = "model_B1_complete",
lag = 1,
lag2 = 7,
LSTM_layer_depth = 64,
epochs = 100,
batch_size = 128,
train_test_split = 0.15,
n_test = 7
)

# %%
# loop throught the Columbia dataset and save accuracies to file
for i in range(1,20):
    filename = '/zone_'+str(i)+'.csv'
    print('Loading data '+filename)
    print('\n')
    deep_learner.data_path = '../data/EFC2012_clean/'+filename
    deep_learner.data = pd.read_csv(deep_learner.data_path, index_col=0)
    deep_learner.data = deep_learner.preprocess(deep_learner.data)
    deep_learner.model_save = 'model_EFC'+str(i)
    # Fitting the model
    model = deep_learner.LSTModel()
    
    original_stdout = sys.stdout # Save a reference to the original standard output
    with open('results_EFC_logdata.txt', 'a') as f:
        sys.stdout = f # Change the standard output to the file we created.
        print('Zone'+str(i)+':')
        deep_learner.results()        
        sys.stdout = original_stdout # Reset the standard output to its origin
# Out:
# Loading data /zone_1.csv
#
#
# Epoch 1/100
# 263/263 [==============================] - 2s 6ms/step - loss: 0.1266 - val_loss: 0.0809
# Epoch 2/100
# 263/263 [==============================] - 1s 5ms/step - loss: 0.0734 - val_loss: 0.0826
# Epoch 3/100
# 263/263 [==============================] - 1s 5ms/step - loss: 0.0429 - val_loss: 0.0431
# Epoch 4/100
# 263/263 [==============================] - 1s 5ms/step - loss: 0.0342 - val_loss: 0.0480
# Epoch 5/100
# 263/263 [==============================] - 1s 5ms/step - loss: 0.0331 - val_loss: 0.0482
# Epoch 6/100
# 263/263 [==============================] - 1s 5ms/step - loss: 0.0319 - val_loss: 0.0500
# Epoch 7/100
# 263/263 [==============================] - 1s 5ms/step - loss: 0.0314 - val_loss: 0.0515
# Epoch 8/100
# 263/263 [==============================] - 1s 5ms/step - loss: 0.0310 - val_loss: 0.0540
# Epoch 9/100
# 263/263 [==============================] - 1s 5ms/step - loss: 0.0309 - val_loss: 0.0536
# Epoch 10/100
# 263/263 [==============================] - 1s 5ms/step - loss: 0.0308 - val_loss: 0.0510
# Epoch 11/100
# 263/263 [==============================] - 1s 5ms/step - loss: 0.0305 - val_loss: 0.0526
# Epoch 12/100
# 263/263 [==============================] - 1s 5ms/step - loss: 0.0300 - val_loss: 0.0504
# Epoch 13/100
# 263/263 [==============================] - 1s 5ms/step - loss: 0.0293 - val_loss: 0.0491
# Epoch 00013: early stopping
# Model saved to disk
# Loading data /zone_2.csv
#
#
# Epoch 1/100
# 263/263 [==============================] - 2s 7ms/step - loss: 0.1350 - val_loss: 0.0846
# Epoch 2/100
# 263/263 [==============================] - 1s 5ms/step - loss: 0.0920 - val_loss: 0.0695
# Epoch 3/100
# 263/263 [==============================] - 1s 5ms/step - loss: 0.0609 - val_loss: 0.0907
# Epoch 4/100
# 263/263 [==============================] - 1s 5ms/step - loss: 0.0484 - val_loss: 0.0444
# Epoch 5/100
# 263/263 [==============================] - 1s 5ms/step - loss: 0.0366 - val_loss: 0.0281
# Epoch 6/100
# 263/263 [==============================] - 1s 5ms/step - loss: 0.0329 - val_loss: 0.0293
# Epoch 7/100
# 263/263 [==============================] - 1s 5ms/step - loss: 0.0325 - val_loss: 0.0322
# Epoch 8/100
# 263/263 [==============================] - 1s 5ms/step - loss: 0.0321 - val_loss: 0.0345
# Epoch 9/100
# 263/263 [==============================] - 1s 6ms/step - loss: 0.0317 - val_loss: 0.0287
# Epoch 10/100
# 263/263 [==============================] - 1s 6ms/step - loss: 0.0296 - val_loss: 0.0310
# Epoch 11/100
# 263/263 [==============================] - 1s 5ms/step - loss: 0.0287 - val_loss: 0.0283
# Epoch 12/100
# 263/263 [==============================] - 1s 5ms/step - loss: 0.0281 - val_loss: 0.0257
# Epoch 13/100
# 263/263 [==============================] - 1s 5ms/step - loss: 0.0274 - val_loss: 0.0269
# Epoch 14/100
# 263/263 [==============================] - 1s 5ms/step - loss: 0.0271 - val_loss: 0.0246
# Epoch 15/100
# 263/263 [==============================] - 1s 5ms/step - loss: 0.0265 - val_loss: 0.0255
# Epoch 16/100
# 263/263 [==============================] - 1s 5ms/step - loss: 0.
100
# 263/263 [==============================] - 1s 5ms/step - loss: 0.0227 - val_loss: 0.0197
# Epoch 26/100
# 263/263 [==============================] - 1s 5ms/step - loss: 0.0221 - val_loss: 0.0200
# Epoch 27/100
# 263/263 [==============================] - 1s 5ms/step - loss: 0.0218 - val_loss: 0.0194
# Epoch 28/100
# 263/263 [==============================] - 1s 5ms/step - loss: 0.0215 - val_loss: 0.0189
# Epoch 29/100
# 263/263 [==============================] - 1s 5ms/step - loss: 0.0214 - val_loss: 0.0190
# Epoch 30/100
# 263/263 [==============================] - 1s 5ms/step - loss: 0.0210 - val_loss: 0.0186
# Epoch 31/100
# 263/263 [==============================] - 1s 5ms/step - loss: 0.0209 - val_loss: 0.0191
# Epoch 32/100
# 263/263 [==============================] - 1s 5ms/step - loss: 0.0209 - val_loss: 0.0187
# Epoch 33/100
# 263/263 [==============================] - 1s 5ms/step - loss: 0.0213 - val_loss: 0.0208
# Epoch 34/100
# 263/263 [==============================] - 1s 5ms/step - loss: 0.0213 - val_loss: 0.0210
# Epoch 35/100
# 263/263 [==============================] - 1s 5ms/step - loss: 0.0210 - val_loss: 0.0191
# Epoch 36/100
# 263/263 [==============================] - 1s 5ms/step - loss: 0.0205 - val_loss: 0.0192
# Epoch 37/100
# 263/263 [==============================] - 1s 5ms/step - loss: 0.0205 - val_loss: 0.0196
# Epoch 38/100
# 263/263 [==============================] - 1s 5ms/step - loss: 0.0205 - val_loss: 0.0180
# Epoch 39/100
# 263/263 [==============================] - 1s 5ms/step - loss: 0.0200 - val_loss: 0.0194
# Epoch 40/100
# 263/263 [==============================] - 1s 5ms/step - loss: 0.0202 - val_loss: 0.0196
# Epoch 41/100
# 263/263 [==============================] - 1s 5ms/step - loss: 0.0201 - val_loss: 0.0189
# Epoch 42/100
# 263/263 [==============================] - 1s 5ms/step - loss: 0.0198 - val_loss: 0.0196
# Epoch 43/100
# 263/263 [==============================] - 1s 5ms/step - loss: 0.0202 - val_loss: 0.0183
# Epoch 44/100
# 263/263 [==============================] - 1s 5ms/step - loss: 0.0201 - val_loss: 0.0214
# Epoch 45/100
# 263/263 [==============================] - 1s 5ms/step - loss: 0.0203 - val_loss: 0.0203
# Epoch 46/100
# 263/263 [==============================] - 1s 5ms/step - loss: 0.0202 - val_loss: 0.0227
# Epoch 47/100
# 263/263 [==============================] - 1s 5ms/step - loss: 0.0199 - val_loss: 0.0242
# Epoch 48/100
# 263/263 [==============================] - 1s 5ms/step - loss: 0.0205 - val_loss: 0.0249
# Epoch 00048: early stopping
# Model saved to disk
# WARNING:tensorflow:7 out of the last 7 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f205c7ada60> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Loading data /zone_7.csv
#
#
# Epoch 1/100
# 263/263 [==============================] - 2s 6ms/step - loss: 0.1335 - val_loss: 0.0849
# Epoch 2/100
# 263/263 [==============================] - 1s 5ms/step - loss: 0.0929 - val_loss: 0.0678
# Epoch 3/100
# 263/263 [==============================] - 1s 5ms/step - loss: 0.0605 - val_loss: 0.0941
# Epoch 4/100
# 263/263 [==============================] - 1s 5ms/step - loss: 0.0463 - val_loss: 0.0411
# Epoch 5/100
# 263/263 [==============================] - 1s 5ms/step - loss: 0.0338 - val_loss: 0.0264
# Epoch 6/100
# 263/263 [==============================] - 1s 5ms/step - loss: 0.0304 - val_loss: 0.0244
# Epoch 7/100
# 263/263 [==============================] - 1s 6ms/step - loss: 0.0295 - val_loss: 0.0257
# Epoch 8/100
# 263/263 [==============================] - ETA: 0s - loss: 0.028 - 1s 5ms/step - loss: 0.0286 - val_loss: 0.0259
# Epoch 9/100
# 263/263 [==============================] - 1s 5ms/step - loss: 0.0284 - val_loss: 0.0259
# Epoch 10/100
# 263/263 [==============================] - 1s 5ms/step - loss: 0.0276 - val_loss: 0.0282
# Epoch 11/100
# 263/263 [==============================] - 1s 5ms/step - loss: 0.0276 - val_loss: 0.0270
# Epoch 12/100
# 263/263 [==============================] - 1s 5ms/step - loss: 0.0277 - val_loss: 0.0305
# Epoch 13/100
# 263/263 [==============================] - 1s 5ms/step - loss: 0.0282 - val_loss: 0.0286
# Epoch 14/100
# 263/263 [==============================] - 1s 5ms/step - loss: 0.0271 - val_loss: 0.0267
# Epoch 15/100
# 263/263 [==============================] - 1s 5ms/step - loss: 0.0260 - val_loss: 0.0250
# Epoch 16/100
# 263/263 [==============================] - 1s 5ms/step - loss: 0.0250 - val_loss: 0.0242
# Epoch 17/100
# 263/263 [==============================] - 1s 5ms/step - loss: 0.0243 - val_loss: 0.0229
# Epoch 18/100
# 263/263 [==============================] - 1s 5ms/step - loss: 0.0236 - val_loss: 0.0233
# Epoch 19/100
# 263/263 [==============================] - 1s 5ms/step - loss: 0.0227 - val_loss: 0.0252
# Epoch 20/100
# 263/263 [==============================] - 1s 5ms/step - loss: 0.0223 - val_loss: 0.0260
# Epoch 21/100
# 263/263 [==============================] - 1s 5ms/step - loss: 0.0219 - val_loss: 0.0252
# Epoch 22/100
# 263/263 [==============================] - 1s 5ms/step - loss: 0.0215 - val_loss: 0.0275
# Epoch 23/100
# 263/263 [==============================] - 1s 5ms/step - loss: 0.0212 - val_loss: 0.0339
# Epoch 24/100
# 263/263 [==============================] - 1s 5ms/step - loss: 0.0211 - val_loss: 0.0310
# Epoch 25/100
# 263/263 [==============================] - 1s 5ms/step - loss: 0.0208 - val_loss: 0.0293
# Epoch 26/100
# 263/263 [==============================] - 1s 5ms/step - loss: 0.0206 - val_loss: 0.0337
# Epoch 27/100
# 263/263 [==============================] - 1s 5ms/step - loss: 0.0206 - val_loss: 0.0341
# Epoch 00027: early stopping
# Model saved to disk
# WARNING:tensorflow:8 out of the last 8 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f2004798f70> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Loading data /zone_8.csv
#
#
# Epoch 1/100
# 263/263 [==============================] - 2s 6ms/step - loss: 0.1394 - val_loss: 0.1343
# Epoch 2/100
# 263/263 [==============================] - 1s 5ms/step - loss: 0.1017 - val_loss: 0.1073
# Epoch 3/100
# 263/263 [==============================] - 1s 5ms/step - loss: 0.0621 - val_loss: 0.0366
# Epoch 4/100
# 263/263 [==============================] - 1s 5ms/step - loss: 0.0353 - val_loss: 0.0319
# Epoch 5/100
# 263/263 [==============================] - 1s 5ms/step - loss: 0.0331 - val_loss: 0.0327
# Epoch 6/100
# 263/263 [==============================] - 1s 5ms/step - loss: 0.0323 - val_loss: 0.0301
# Epoch 7/100
# 263/263 [==============================] - 1s 5ms/step - loss: 0.0315 - val_loss: 0.0301
# Epoch 8/100
# 263/263 [==============================] - 1s 5ms/step - loss: 0.0307 - val_loss: 0.0300
# Epoch 9/100
# 263/263 [==============================] - 1s 5ms/step - loss: 0.0306 - val_loss: 0.0322
# Epoch 10/100
# 263/263 [==============================] - 1s 5ms/step - loss: 0.0298 - val_loss: 0.0320
# Epoch 11/100
# 263/263 [==============================] - 1s 5ms/step - loss: 0.0294 - val_loss: 0.0302
# Epoch 12/100
# 263/263 [==============================] - 1s 5ms/step - loss: 0.0286 - val_loss: 0.0303
# Epoch 13/100
# 263/263 [==============================] - 1s 5ms/step - loss: 0.0288 - val_loss: 0.0292
# Epoch 14/100
# 263/263 [==============================] - 1s 5ms/step - loss: 0.0285 - val_loss: 0.0298
# Epoch 15/100
# 263/263 [==============================] - 1s 6ms/step - loss: 0.0282 - val_loss: 0.0304
# Epoch 16/100
# 263/263 [==============================] - 1s 5ms/step - loss: 0.0283 - val_loss: 0.0300
# Epoch 17/100
# 263/263 [==============================] - 1s 6ms/step - loss: 0.0276 - val_loss: 0.0292
# Epoch 18/100
# 263/263 [==============================] - 1s 5ms/step - loss: 0.0273 - val_loss: 0.0286
# Epoch 19/100
# 263/263 [==============================] - 1s 5ms/step - loss: 0.0273 - val_loss: 0.0304
# Epoch 20/100
# 263/263 [==============================] - 1s 5ms/step - loss: 0.0269 - val_loss: 0.0288
# Epoch 21/100
# 263/263 [==============================] - 1s 5ms/step - loss: 0.0263 - val_loss: 0.0278
# Epoch 22/100
# 263/263 [==============================] - 1s 5ms/step - loss: 0.0258 - val_loss: 0.0282
# Epoch 23/100
# 263/263 [==============================] - 1s 5ms/step - loss: 0.0255 - val_loss: 0.0269
# Epoch 24/100
# 263/263 [==============================] - 1s 5ms/step - loss: 0.0252 - val_loss: 0.0264
# Epoch 25/100
# 263/263 [==============================] - 1s 5ms/step - loss: 0.0253 - val_loss: 0.0267
# Epoch 26/100
# 263/263 [==============================] - 1s 5ms/step - loss: 0.
100
# 263/263 [==============================] - 1s 5ms/step - loss: 0.0343 - val_loss: 0.0509
# Epoch 9/100
# 263/263 [==============================] - 1s 6ms/step - loss: 0.0340 - val_loss: 0.0513
# Epoch 10/100
# 263/263 [==============================] - 1s 5ms/step - loss: 0.0332 - val_loss: 0.0523
# Epoch 11/100
# 263/263 [==============================] - 1s 6ms/step - loss: 0.0328 - val_loss: 0.0485
# Epoch 12/100
# 263/263 [==============================] - 1s 5ms/step - loss: 0.0318 - val_loss: 0.0459
# Epoch 13/100
# 263/263 [==============================] - 1s 5ms/step - loss: 0.0312 - val_loss: 0.0438
# Epoch 14/100
# 263/263 [==============================] - 1s 6ms/step - loss: 0.0305 - val_loss: 0.0414
# Epoch 15/100
# 263/263 [==============================] - 1s 5ms/step - loss: 0.0301 - val_loss: 0.0373
# Epoch 16/100
# 263/263 [==============================] - 1s 5ms/step - loss: 0.0296 - val_loss: 0.0373
# Epoch 17/100
# 263/263 [==============================] - 1s 5ms/step - loss: 0.0295 - val_loss: 0.0353
# Epoch 18/100
# 263/263 [==============================] - 1s 5ms/step - loss: 0.0293 - val_loss: 0.0355
# Epoch 19/100
# 263/263 [==============================] - 1s 5ms/step - loss: 0.0291 - val_loss: 0.0345
# Epoch 20/100
# 263/263 [==============================] - 1s 5ms/step - loss: 0.0287 - val_loss: 0.0342
# Epoch 21/100
# 263/263 [==============================] - 1s 5ms/step - loss: 0.0292 - val_loss: 0.0349
# Epoch 22/100
# 263/263 [==============================] - 1s 5ms/step - loss: 0.0292 - val_loss: 0.0348
# Epoch 23/100
# 263/263 [==============================] - 1s 5ms/step - loss: 0.0288 - val_loss: 0.0353
# Epoch 24/100
# 263/263 [==============================] - 1s 5ms/step - loss: 0.0287 - val_loss: 0.0365
# Epoch 25/100
# 263/263 [==============================] - 1s 5ms/step - loss: 0.0283 - val_loss: 0.0350
# Epoch 26/100
# 263/263 [==============================] - 1s 5ms/step - loss: 0.0283 - val_loss: 0.0376
# Epoch 27/100
# 263/263 [==============================] - 1s 5ms/step - loss: 0.0283 - val_loss: 0.0368
# Epoch 28/100
# 263/263 [==============================] - 1s 6ms/step - loss: 0.0277 - val_loss: 0.0396
# Epoch 29/100
# 263/263 [==============================] - 1s 6ms/step - loss: 0.0280 - val_loss: 0.0384
# Epoch 30/100
# 263/263 [==============================] - 1s 5ms/step - loss: 0.0274 - val_loss: 0.0372
# Epoch 00030: early stopping
# Model saved to disk
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f2014403d30> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
# loop throught the Columbia dataset and save accuracies to file
for i in range(1,28):
    filename = '/Residential_'+str(i)+'.csv'
    print('Loading data '+filename)
    print('\n')
    deep_learner.data_path = '../data/Columbia_clean'+filename
    deep_learner.data = pd.read_csv(deep_learner.data_path, index_col=0)
    deep_learner.data = deep_learner.preprocess(deep_learner.data)
    deep_learner.model_save = 'model_Columbia_B'+str(i)
    # Fitting the model
    model = deep_learner.LSTModel()
    
    original_stdout = sys.stdout # Save a reference to the original standard output
    with open('results_Columbia_logdata.txt', 'a') as f:
        sys.stdout = f # Change the standard output to the file we created.
        print('Building B'+str(i)+':')
        deep_learner.results()        
        sys.stdout = original_stdout # Reset the standard output to its origin
# Out:
# Loading data /Residential_1.csv
#
#
# Epoch 1/100
# 225/225 [==============================] - 1s 5ms/step - loss: 0.0909
# Epoch 2/100
# 225/225 [==============================] - 1s 5ms/step - loss: 0.0671
# Epoch 3/100
# 225/225 [==============================] - 1s 4ms/step - loss: 0.0658
# Epoch 4/100
# 225/225 [==============================] - 1s 4ms/step - loss: 0.0650
# Epoch 5/100
# 225/225 [==============================] - 1s 5ms/step - loss: 0.0648
# Epoch 6/100
# 225/225 [==============================] - 1s 5ms/step - loss: 0.0643
# Epoch 7/100
# 225/225 [==============================] - 1s 5ms/step - loss: 0.0638
# Epoch 8/100
# 225/225 [==============================] - 1s 5ms/step - loss: 0.0635
# Epoch 9/100
# 225/225 [==============================] - 1s 5ms/step - loss: 0.0632
# Epoch 10/100
# 225/225 [==============================] - 1s 5ms/step - loss: 0.0627
# Epoch 11/100
# 225/225 [==============================] - 1s 5ms/step - loss: 0.0618
# Epoch 12/100
# 225/225 [==============================] - 1s 5ms/step - loss: 0.0615
# Epoch 13/100
# 225/225 [==============================] - 1s 5ms/step - loss: 0.0612
# Epoch 14/100
# 225/225 [==============================] - 1s 5ms/step - loss: 0.0610
# Epoch 15/100
# 225/225 [==============================] - 1s 5ms/step - loss: 0.0609
# Epoch 16/100
# 225/225 [==============================] - 1s 5ms/step - loss: 0.0605
# Epoch 17/100
# 225/225 [==============================] - 1s 5ms/step - loss: 0.0606
# Epoch 18/100
# 225/225 [==============================] - 1s 5ms/step - loss: 0.0604
# Epoch 19/100
# 225/225 [==============================] - 1s 5ms/step - loss: 0.0604
# Epoch 20/100
# 225/225 [==============================] - 1s 5ms/step - loss: 0.0601
# Epoch 21/100
# 225/225 [==============================] - 1s 5ms/step - loss: 0.0600
# Epoch 22/100
# 225/225 [==============================] - 1s 5ms/step - loss: 0.0600
# Epoch 23/100
# 225/225 [==============================] - 1s 5ms/step - loss: 0.0600
# Epoch 24/100
# 225/225 [==============================] - 1s 5ms/step - loss: 0.0597
# Epoch 25/100
# 225/225 [==============================] - 1s 5ms/step - loss: 0.0597
# Epoch 26/100
# 225/225 [==============================] - 1s 5ms/step - loss: 0.0597
# Epoch 27/100
# 225/225 [==============================] - 1s 5ms/step - loss: 0.0596
# Epoch 28/100
# 225/225 [==============================] - 1s 5ms/step - loss: 0.0595
# Epoch 29/100
# 225/225 [==============================] - 1s 5ms/step - loss: 0.0596
# Epoch 30/100
# 225/225 [==============================] - 1s 5ms/step - loss: 0.0594
# Epoch 31/100
# 225/225 [==============================] - 1s 5ms/step - loss: 0.0594
# Epoch 32/100
# 225/225 [==============================] - 1s 5ms/step - loss: 0.0594
# Epoch 33/100
# 225/225 [==============================] - 1s 5ms/step - loss: 0.0592
# Epoch 34/100
# 225/225 [==============================] - 1s 5ms/step - loss: 0.0592
# Epoch 35/100
# 225/225 [==============================] - 1s 5ms/step - loss: 0.0591
# Epoch 36/100
# 225/225 [==============================] - 1s 5ms/step - loss: 0.0591
# Epoch 37/100
# 225/225 [==============================] - 1s 5ms/step - loss: 0.0590
# Epoch 38/100
# 225/225 [==============================] - 1s 5ms/step - loss: 0.0589
# Epoch 39/100
# 225/225 [==============================] - 1s 5ms/step - loss: 0.0587
# Epoch 40/100
# 225/225 [==============================] - 1s 5ms/step - loss: 0.0589
# Epoch 41/100
# 225/225 [==============================] - 1s 5ms/step - loss: 0.0586
# Epoch 42/100
# 225/225 [==============================] - 1s 5ms/step - loss: 0.0587
# Epoch 43/100
# 225/225 [==============================] - 1s 5ms/step - loss: 0.0586
# Epoch 44/100
# 225/225 [==============================] - 1s 5ms/step - loss: 0.0585
# Epoch 45/100
# 225/225 [==============================] - 1s 5ms/step - loss: 0.0586
# Epoch 46/100
# 225/225 [==============================] - 1s 5ms/step - loss: 0.0583
# Epoch 47/100
# 225/225 [==============================] - 1s 5ms/step - loss: 0.0582
# Epoch 48/100
# 225/225 [==============================] - 1s 5ms/step - loss: 0.0582
# Epoch 49/100
# 225/225 [==============================] - 1s 5ms/step - loss: 0.0582
# Epoch 50/100
# 225/225 [==============================] - 1s 5ms/step - loss: 0.0581
# Epoch 51/100
# 225/225 [==============================] - 1s 5ms/step - loss: 0.0581
# Epoch 52/100
# 225/225 [==============================] - 1s 5ms/step - loss: 0.0580
# Epoch 53/100
# 225/225 [==============================] - 1s 5ms/step - loss: 0.0582
# Epoch 54/100
# 225/225 [==============================] - 1s 5ms/step - loss: 0.0579
# Epoch 55/100
# 225/225 [==============================] - 1s 5ms/step - loss: 0.0579
# Epoch 56/100
# 225/225 [==============================] - 1s 5ms/step - loss: 0.0580
# Epoch 57/100
# 225/225 [==============================] - 1s 5ms/step - loss: 0.0579
# Epoch 58/100
# 225/225 [==============================] - 1s 5ms/step - loss: 0.0579
# Epoch 59/100
# 225/225 [==============================] - 1s 5ms/step - loss: 0.0579
# Epoch 60/100
# 225/225 [==============================] - 1s 5ms/step - loss: 0.0579
# Epoch 61/100
# 225/225 [==============================] - 1s 5ms/step - loss: 0.0578
# Epoch 62/100
# 225/225 [==============================] - 1s 5ms/step - loss: 0.0578
# Epoch 63/100
# 225/225 [==============================] - 1s 5ms/step - loss: 0.0579
# Epoch 64/100
# 225/225 [==============================] - 1s 5ms/step - loss: 0.0576
# Epoch 65/100
# 225/225 [==============================] - 1s 5ms/step - loss: 0.0577
# Epoch 66/100
# 225/225 [==============================] - 1s 5ms/step - loss: 0.0578
# Epoch 67/100
# 225/225 [==============================] - 1s 5ms/step - loss: 0.0578
# Epoch 68/100
# 225/225 [==============================] - 1s 5ms/step - loss: 0.0578
# Epoch 69/100
# 225/225 [==============================] - 1s 5ms/step - loss: 0.0578
# Epoch 70/100
# 225/225 [==============================] - 1s 5ms/step - loss: 0.0577
# Epoch 71/100
# 225/225 [==============================] - 1s 5ms/step - loss: 0.0578
# Epoch 72/100
# 225/225 [==============================] - 1s 5ms/step - loss: 0.0579
# Epoch 73/100
# 225/225 [==============================] - 1s 5ms/step - loss: 0.0577
# Epoch 74/100
# 225/225 [==============================] - 1s 5ms/step - loss: 0.0578
# Epoch 75/100
# 225/225 [==============================] - 1s 5ms/step - loss: 0.0579
# Epoch 76/100
# 225/225 [==============================] - 1s 5ms/step - loss: 0.0576
# Epoch 77/100
# 225/225 [==============================] - 1s 5ms/step - loss: 0.0577
# Epoch 78/100
# 225/225 [==============================] - 1s 5ms/step - loss: 0.0577
# Epoch 79/100
# 225/225 [==============================] - 1s 5ms/step - loss: 0.0576
# Epoch 80/100
# 225/225 [==============================] - 1s 5ms/step - loss: 0.0577
# Epoch 81/100
# 225/225 [==============================] - 1s 5ms/step - loss: 0.0578
# Epoch 82/100
# 225/225 [==============================] - 1s 5ms/step - loss: 0.0578
# Epoch 83/100
# 225/225 [==============================] - 1s 5ms/step - loss: 0.0578
# Epoch 84/100
# 225/225 [==============================] - 1s 5ms/step - loss: 0.0576
# Epoch 85/100
# 225/225 [==============================] - 1s 5ms/step - loss: 0.0577
# Epoch 86/100
# 225/225 [==============================] - 1s 5ms/step - loss: 0.0577
# Epoch 87/100
# 225/225 [==============================] - 1s 5ms/step - loss: 0.0577
# Epoch 88/100
# 225/225 [==============================] - 1s 5ms/step - loss: 0.0578
# Epoch 89/100
# 225/225 [==============================] - 1s 5ms/step - loss: 0.0578
# Epoch 90/100
# 225/225 [==============================] - 1s 5ms/step - loss: 0.0576
# Epoch 91/100
# 225/225 [==============================] - 1s 5ms/step - loss: 0.0577
# Epoch 92/100
# 225/225 [==============================] - 1s 5ms/step - loss: 0.0577
# Epoch 93/100
# 225/225 [==============================] - 1s 5ms/step - loss: 0.0577
# Epoch 94/100
# 225/225 [==============================] - 1s 5ms/step - loss: 0.0577
# Epoch 95/100
# 225/225 [==============================] - 1s 5ms/step - loss: 0.0578
# Epoch 96/100
# 225/225 [==============================] - 1s 5ms/step - loss: 0.0577
# Epoch 97/100
# 225/225 [==============================] - 1s 5ms/step - loss: 0.0579
# Epoch 98/100
# 225/225 [==============================] - 1s 5ms/step - loss: 0.0577
# Epoch 99/100
# 225/225 [==============================] - 1s 5ms/step - loss: 0.0577
# Epoch 100/100
# 225/225 [==============================] - 1s 5ms/step - loss: 0.0577
# Model saved to disk
# Loading data /Residential_2.csv
#
#
# Epoch 1/100
# 233/233 [==============================] - 1s 5ms/step - loss: 0.0657
# Epoch 2/100
# 233/233 [==============================] - 1s 5ms/step - loss: 0.0613
# Epoch 3/100
# 233/233 [==============================] - 1s 5ms/step - loss: 0.0601
# Epoch 4/100
# 233/233 [==============================] - 1s 5ms/step - loss: 0.0590
# Epoch 5/100
# 233/233 [==============================] - 1s 5ms/step - loss: 0.0579
# Epoch 6/100
# 233/233 [==============================] - 1s 5ms/step - loss: 0.0569
# Epoch 7/100
# 233/233 [==============================] - 1s 5ms/step - loss: 0.0562
# Epoch 8/100
# 233/233 [==============================] - 1s 5ms/step - loss: 0.0556
# Epoch 9/100
# 233/233 [==============================] - 1s 5ms/step - loss: 0.0552
# Epoch 10/100
# 233/233 [==============================] - 1s 5ms/step - loss: 0.0549
# Epoch 11/100
# 233/233 [==============================] - 1s 5ms/step - loss: 0.0545
# Epoch 12/100
# 233/233 [==============================] - 1s 5ms/step - loss: 0.0543
# Epoch 13/100
# 233/233 [==============================] - 1s 5ms/step - loss: 0.0542
# Epoch 14/100
# 233/233 [==============================] - 1s 5ms/step - loss: 0.0539
# Epoch 15/100
# 233/233 [==============================] - 1s 5ms/step - loss: 0.0537
# Epoch 16/100
# 233/233 [==============================] - 1s 5ms/step - loss: 0.0536
# Epoch 17/100
# 233/233 [==============================] - 1s 5ms/step - loss: 0.0534
# Epoch 18/100
# 233/233 [==============================] - 1s 5ms/step - loss: 0.0532
# Epoch 19/100
# 233/233 [==============================] - 1s 5ms/step - loss: 0.0530
# Epoch 20/100
# 233/233 [==============================] - 1s 5ms/step - loss: 0.0530
# Epoch 21/100
# 233/233 [==============================] - 1s 5ms/step - loss: 0.0529
# Epoch 22/100
# 233/233 [==============================] - 1s 5ms/step - loss: 0.0529
# Epoch 23/100
# 233/233 [==============================] - 1s 5ms/step - loss: 0.0527
# Epoch 24/100
# 233/233 [==============================] - 1s 5ms/step - loss: 0.0526
# Epoch 25/100
# 233/233 [==============================] - 1s 5ms/step - loss: 0.0528
# Epoch 26/100
# 233/233 [==============================] - 1s 5ms/step - loss: 0.0527
# Epoch 27/100
# 233/233 [==============================] - 1s 5ms/step - loss: 0.0526
# Epoch 28/100
# 233/233 [==============================] - 1s 5ms/step - loss: 0.0525
# Epoch 29/100
# 233/233 [==============================] - 1s 5ms/step - loss: 0.0525
# Epoch 30/100
# 233/233 [==============================] - 1s 5ms/step - loss: 0.0523
# Epoch 31/100
# 233/233 [==============================] - 1s 5ms/step - loss: 0.0522
# Epoch 32/100
# 233/233 [==============================] - 1s 5ms/step - loss: 0.0522
# Epoch 33/100
# 233/233 [==============================] - 1s 5ms/step - loss: 0.0523
# Epoch 34/100
# 233/233 [==============================] - 1s 5ms/step - loss: 0.0522
# Epoch 35/100
# 233/233 [==============================] - 1s 5ms/step - loss: 0.0522
# Epoch 36/100
# 233/233 [==============================] - 1s 5ms/step - loss: 0.0521
# Epoch 37/100
# 233/233 [==============================] - 1s 5ms/step - loss: 0.0520
# Epoch 38/100
# 233/233 [==============================] - 1s 5ms/step - loss: 0.0519
# Epoch 39/100
# 233/233 [==============================] - 1s 5ms/step - loss: 0.0520
# Epoch 40/100
# 233/233 [==============================] - 1s 5ms/step - loss: 0.0520
# Epoch 41/100
# 233/233 [==============================] - 1s 5ms/step - loss: 0.0520
# Epoch 42/100
# 233/233 [==============================] - 1s 5ms/step - loss: 0.0519
# Epoch 43/100
# 233/233 [==============================] - 1s 5ms/step - loss: 0.0519
# Epoch 44/100
# 233/233 [==============================] - 1s 5ms/step - loss: 0.0518
# Epoch 45/100
# 233/233 [==============================] - 1s 5ms/step - loss: 0.0519
# Epoch 46/100
# 233/233 [==============================] - 1s 5ms/step - loss: 0.0518
# Epoch 47/100
# 233/233 [==============================] - 1s 5ms/step - loss: 0.0516
# Epoch 48/100
# 233/233 [==============================] - 1s 5ms/step - loss: 0.0518
# Epoch 49/100
# 233/233 [==============================] - 1s 5ms/step - loss: 0.0519
# Epoch 50/100
# 233/233 [==============================] - 1s 5ms/step - loss: 0.0517
# Epoch 51/100
# 233/233 [==============================] - 1s 5ms/step - loss: 0.0517
# Epoch 52/100
# 233/233 [==============================] - 1s 5ms/step - loss: 0.0517
# Epoch 53/100
# 233/233 [==============================] - 1s 5ms/step - loss: 0.0515
# Epoch 54/100
# 233/233 [==============================] - 1s 5ms/step - loss: 0.0516
# Epoch 55/100
# 233/233 [==============================] - 1s 5ms/step - loss: 0.0515
# Epoch 56/100
# 233/233 [==============================] - 1s 5ms/step - loss: 0.0516
# Epoch 57/100
# 233/233 [==============================] - 1s 5ms/step - loss: 0.0514
# Epoch 58/100
# 233/233 [==============================] - 1s 5ms/step - loss: 0.0515
# Epoch 59/100
# 233/233 [==============================] - 1s 5ms/step - loss: 0.0514
# Epoch 60/100
# 233/233 [==============================] - 1s 5ms/step - loss: 0.0514
# Epoch 61/100
# 233/233 [==============================] - 1s 5ms/step - loss: 0.0514
# Epoch 62/100
# 233/233 [==============================] - 1s 5ms/step - loss: 0.0513
# Epoch 63/100
# 233/233 [==============================] - 1s 5ms/step - loss: 0.0513
# Epoch 64/100
# 233/233 [==============================] - 1s 5ms/step - loss: 0.0513
# Epoch 65/100
# 233/233 [==============================] - 1s 5ms/step - loss: 0.0513
# Epoch 66/100
# 233/233 [==============================] - 1s 5ms/step - loss: 0.0513
# Epoch 67/100
# 233/233 [==============================] - 1s 5ms/step - loss: 0.0512
# Epoch 68/100
# 233/233 [==============================] - 1s 5ms/step - loss: 0.0513
# Epoch 69/100
# 233/233 [==============================] - 1s 5ms/step - loss: 0.0512
# Epoch 70/100
# 233/233 [==============================] - 1s 5ms/step - loss: 0.0512
# Epoch 71/100
# 233/233 [==============================] - 1s 5ms/step - loss: 0.0511
# Epoch 72/100
# 233/233 [==============================] - 1s 5ms/step - loss: 0.0511
# Epoch 73/100
# 233/233 [==============================] - 1s 5ms/step - loss: 0.0511
# Epoch 74/100
# 233/233 [==============================] - 1s 5ms/step - loss: 0.0511
# Epoch 75/100
# 233/233 [==============================] - 1s 5ms/step - loss: 0.0511
# Epoch 76/100
# 233/233 [==============================] - 1s 5ms/step - loss: 0.0510
# Epoch 77/100
# 233/233 [==============================] - 1s 5ms/step - loss: 0.0510
# Epoch 78/100
# 233/233 [==============================] - 1s 5ms/step - loss: 0.0510
# Epoch 79/100
# 233/233 [==============================] - 1s 5ms/step - loss: 0.0510
# Epoch 80/100
# 233/233 [==============================] - 1s 5ms/step - loss: 0.0508
# Epoch 81/100
# 233/233 [==============================] - 1s 5ms/step - loss: 0.0511
# Epoch 82/100
# 233/233 [==============================] - 1s 5ms/step - loss: 0.0510
# Epoch 83/100
# 233/233 [==============================] - 1s 5ms/step - loss: 0.0511
# Epoch 84/100
# 233/233 [==============================] - 1s 5ms/step - loss: 0.0509
# Epoch 85/100
# 233/233 [==============================] - 1s 5ms/step - loss: 0.0509
# Epoch 86/100
# 233/233 [==============================] - 1s 5ms/step - loss: 0.0510
# Epoch 87/100
# 233/233 [==============================] - 1s 5ms/step - loss: 0.0508
# Epoch 88/100
# 233/233 [==============================] - 1s 5ms/step - loss: 0.0509
# Epoch 89/100
# 233/233 [==============================] - 1s 5ms/step - loss: 0.0508
# Epoch 90/100
# 233/233 [==============================] - 1s 5ms/step - loss: 0.0508
# Epoch 91/100
# 233/233 [==============================] - 1s 5ms/step - loss: 0.0510
# Epoch 92/100
# 233/233 [==============================] - 1s 5ms/step - loss: 0.0508
# Epoch 93/100
# 233/233 [==============================] - 1s 5ms/step - loss: 0.0509
# Epoch 94/100
# 233/233 [==============================] - 1s 5ms/step - loss: 0.0508
# Epoch 95/100
# 233/233 [==============================] - 1s 5ms/step - loss: 0.0508
# Epoch 96/100
# 233/233 [==============================] - 1s 5ms/step - loss: 0.0509
# Epoch 97/100
# 233/233 [==============================] - 1s 5ms/step - loss: 0.0508
# Epoch 98/100
# 233/233 [==============================] - 1s 5ms/step - loss: 0.0508
# Epoch 99/100
# 233/233 [==============================] - 1s 5ms/step - loss: 0.0508
# Epoch 100/100
# 233/233 [==============================] - 1s 5ms/step - loss: 0.0507
# Model saved to disk
# Loading data /Residential_3.csv
#
#
# Epoch 1/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.1250
# Epoch 2/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0919
# Epoch 3/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0889
# Epoch 4/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0881
# Epoch 5/100
# 203/203 [==============================] - 1s 4ms/step - loss: 0.0873
# Epoch 6/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0860
# Epoch 7/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0849
# Epoch 8/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0839
# Epoch 9/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0826
# Epoch 10/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0818
# Epoch 11/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0813
# Epoch 12/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0806
# Epoch 13/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0800
# Epoch 14/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0797
# Epoch 15/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0794
# Epoch 16/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0790
# Epoch 17/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0789
# Epoch 18/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0785
# Epoch 19/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0785
# Epoch 20/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0781
# Epoch 21/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0780
# Epoch 22/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0777
# Epoch 23/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0776
# Epoch 24/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0775
# Epoch 25/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0775
# Epoch 26/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0773
# Epoch 27/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0772
# Epoch 28/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0774
# Epoch 29/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0772
# Epoch 30/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0773
# Epoch 31/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0770
# Epoch 32/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0770
# Epoch 33/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0769
# Epoch 34/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0770
# Epoch 35/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0770
# Epoch 36/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0770
# Epoch 37/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0768
# Epoch 38/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0768
# Epoch 39/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0765
# Epoch 40/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0766
# Epoch 41/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0765
# Epoch 42/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0764
# Epoch 43/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0762
# Epoch 44/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0764
# Epoch 45/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0762
# Epoch 46/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0762
# Epoch 47/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0761
# Epoch 48/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0762
# Epoch 49/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0760
# Epoch 50/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0760
# Epoch 51/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0760
# Epoch 52/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0757
# Epoch 53/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0758
# Epoch 54/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0758
# Epoch 55/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0757
# Epoch 56/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0759
# Epoch 57/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0757
# Epoch 58/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0756
# Epoch 59/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0756
# Epoch 60/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0757
# Epoch 61/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0756
# Epoch 62/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0753
# Epoch 63/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0755
# Epoch 64/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0754
# Epoch 65/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0754
# Epoch 66/100
# 203/203 [==============================] - 1s 4ms/step - loss: 0.0754
# Epoch 67/100
# 203/203 [==============================] - 1s 4ms/step - loss: 0.0756
# Epoch 68/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0754
# Epoch 69/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0753
# Epoch 70/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0752
# Epoch 71/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0754
# Epoch 72/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0753
# Epoch 73/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0753
# Epoch 74/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0752
# Epoch 75/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0753
# Epoch 76/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0754
# Epoch 77/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0753
# Epoch 78/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0753
# Epoch 79/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0752
# Epoch 80/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0752
# Epoch 81/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0752
# Epoch 82/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0751
# Epoch 83/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0754
# Epoch 84/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0752
# Epoch 85/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0751
# Epoch 86/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0751
# Epoch 87/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0751
# Epoch 88/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0753
# Epoch 89/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0753
# Epoch 90/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0751
# Epoch 91/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0752
# Epoch 92/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0752
# Epoch 93/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0750
# Epoch 94/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0753
# Epoch 95/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0751
# Epoch 96/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0752
# Epoch 97/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0750
# Epoch 98/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0750
# Epoch 99/100
# 203/203 [==============================] - 1s 4ms/step - loss: 0.0749
# Epoch 100/100
# 203/203 [==============================] - 1s 5ms/step - loss: 0.0750
# Model saved to disk
# Loading data /Residential_4.csv
#
#
# Epoch 1/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.1332
# Epoch 2/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.1123
# Epoch 3/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.1095
# Epoch 4/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.1046
# Epoch 5/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0995
# Epoch 6/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0958
# Epoch 7/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0932
# Epoch 8/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0919
# Epoch 9/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0911
# Epoch 10/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0903
# Epoch 11/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0901
# Epoch 12/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0895
# Epoch 13/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0892
# Epoch 14/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0891
# Epoch 15/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0888
# Epoch 16/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0887
# Epoch 17/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0884
# Epoch 18/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0882
# Epoch 19/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0879
# Epoch 20/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0879
# Epoch 21/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0881
# Epoch 22/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0877
# Epoch 23/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0873
# Epoch 24/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0874
# Epoch 25/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0873
# Epoch 26/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0871
# Epoch 27/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0870
# Epoch 28/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0870
# Epoch 29/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0869
# Epoch 30/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0868
# Epoch 31/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0867
# Epoch 32/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0868
# Epoch 33/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0865
# Epoch 34/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0866
# Epoch 35/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0864
# Epoch 36/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0863
# Epoch 37/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0865
# Epoch 38/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0864
# Epoch 39/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0863
# Epoch 40/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0862
# Epoch 41/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0861
# Epoch 42/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0859
# Epoch 43/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0859
# Epoch 44/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0861
# Epoch 45/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0861
# Epoch 46/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0858
# Epoch 47/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0861
# Epoch 48/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0856
# Epoch 49/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0858
# Epoch 50/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0857
# Epoch 51/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0858
# Epoch 52/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0853
# Epoch 53/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0855
# Epoch 54/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0855
# Epoch 55/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0855
# Epoch 56/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0853
# Epoch 57/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0854
# Epoch 58/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0854
# Epoch 59/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0850
# Epoch 60/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0852
# Epoch 61/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0853
# Epoch 62/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0852
# Epoch 63/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0851
# Epoch 64/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0851
# Epoch 65/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0851
# Epoch 66/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0850
# Epoch 67/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0850
# Epoch 68/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0852
# Epoch 69/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0850
# Epoch 70/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0848
# Epoch 71/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0848
# Epoch 72/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0847
# Epoch 73/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0849
# Epoch 74/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0848
# Epoch 75/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0848
# Epoch 76/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0848
# Epoch 77/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0846
# Epoch 78/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0845
# Epoch 79/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0846
# Epoch 80/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0844
# Epoch 81/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0843
# Epoch 82/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0845
# Epoch 83/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0845
# Epoch 84/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0841
# Epoch 85/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0841
# Epoch 86/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0843
# Epoch 87/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0843
# Epoch 88/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0841
# Epoch 89/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0844
# Epoch 90/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0843
# Epoch 91/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0841
# Epoch 92/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0840
# Epoch 93/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0841
# Epoch 94/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0840
# Epoch 95/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0839
# Epoch 96/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0839
# Epoch 97/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0840
# Epoch 98/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0840
# Epoch 99/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0836
# Epoch 100/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0838
# Model saved to disk
# Loading data /Residential_5.csv
#
#
# Epoch 1/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.1149
# Epoch 2/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0975
# Epoch 3/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0975
# Epoch 4/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0964
# Epoch 5/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0960
# Epoch 6/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0942
# Epoch 7/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0932
# Epoch 8/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0918
# Epoch 9/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0910
# Epoch 10/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0901
# Epoch 11/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0892
# Epoch 12/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0887
# Epoch 13/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0882
# Epoch 14/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0881
# Epoch 15/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0879
# Epoch 16/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0875
# Epoch 17/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0877
# Epoch 18/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0875
# Epoch 19/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0873
# Epoch 20/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0871
# Epoch 21/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0871
# Epoch 22/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0870
# Epoch 23/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0868
# Epoch 24/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0866
# Epoch 25/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0866
# Epoch 26/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0863
# Epoch 27/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0861
# Epoch 28/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0860
# Epoch 29/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0859
# Epoch 30/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0859
# Epoch 31/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0856
# Epoch 32/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0857
# Epoch 33/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0856
# Epoch 34/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0853
# Epoch 35/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0853
# Epoch 36/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0854
# Epoch 37/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0850
# Epoch 38/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0849
# Epoch 39/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0848
# Epoch 40/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0849
# Epoch 41/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0848
# Epoch 42/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0848
# Epoch 43/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0845
# Epoch 44/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0846
# Epoch 45/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0843
# Epoch 46/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0843
# Epoch 47/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0841
# Epoch 48/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0841
# Epoch 49/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0842
# Epoch 50/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0842
# Epoch 51/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0838
# Epoch 52/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0841
# Epoch 53/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0837
# Epoch 54/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0836
# Epoch 55/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0836
# Epoch 56/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0836
# Epoch 57/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0834
# Epoch 58/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0834
# Epoch 59/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0836
# Epoch 60/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0831
# Epoch 61/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0835
# Epoch 62/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0832
# Epoch 63/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0831
# Epoch 64/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0830
# Epoch 65/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0831
# Epoch 66/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0830
# Epoch 67/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0830
# Epoch 68/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0830
# Epoch 69/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0826
# Epoch 70/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0829
# Epoch 71/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0829
# Epoch 72/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0831
# Epoch 73/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0829
# Epoch 74/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0827
# Epoch 75/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0826
# Epoch 76/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0825
# Epoch 77/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0828
# Epoch 78/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0827
# Epoch 79/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0826
# Epoch 80/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0823
# Epoch 81/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0826
# Epoch 82/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0824
# Epoch 83/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0824
# Epoch 84/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0824
# Epoch 85/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0823
# Epoch 86/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0823
# Epoch 87/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0824
# Epoch 88/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0824
# Epoch 89/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0821
# Epoch 90/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0822
# Epoch 91/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0822
# Epoch 92/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0822
# Epoch 93/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0823
# Epoch 94/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0821
# Epoch 95/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0821
# Epoch 96/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0820
# Epoch 97/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0819
# Epoch 98/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0822
# Epoch 99/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0819
# Epoch 100/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0819
# Model saved to disk
# Loading data /Residential_6.csv
#
#
# Epoch 1/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0868
# Epoch 2/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0698
# Epoch 3/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0691
# Epoch 4/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0687
# Epoch 5/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0680
# Epoch 6/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0667
# Epoch 7/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0649
# Epoch 8/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0639
# Epoch 9/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0635
# Epoch 10/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0634
# Epoch 11/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0631
# Epoch 12/100
# 202/202 [==============================] - 1s 4ms/step - loss: 0.0631
# Epoch 13/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0627
# Epoch 14/100
# 202/202 [==============================] - 1s 4ms/step - loss: 0.0627
# Epoch 15/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0624
# Epoch 16/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0623
# Epoch 17/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0621
# Epoch 18/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0618
# Epoch 19/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0615
# Epoch 20/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0615
# Epoch 21/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0613
# Epoch 22/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0612
# Epoch 23/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0611
# Epoch 24/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0610
# Epoch 25/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0608
# Epoch 26/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0607
# Epoch 27/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0605
# Epoch 28/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0605
# Epoch 29/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0603
# Epoch 30/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0603
# Epoch 31/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0601
# Epoch 32/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0600
# Epoch 33/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0598
# Epoch 34/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0600
# Epoch 35/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0599
# Epoch 36/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0597
# Epoch 37/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0596
# Epoch 38/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0595
# Epoch 39/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0595
# Epoch 40/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0594
# Epoch 41/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0594
# Epoch 42/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0594
# Epoch 43/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0594
# Epoch 44/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0592
# Epoch 45/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0593
# Epoch 46/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0592
# Epoch 47/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0592
# Epoch 48/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0591
# Epoch 49/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0592
# Epoch 50/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.0589
# Epoch 51/100
# 202/202 [==============================] - 1s 5ms/step - loss: 0.
100
# 310/310 [==============================] - 1s 5ms/step - loss: 0.0221
# Epoch 34/100
# 310/310 [==============================] - 1s 5ms/step - loss: 0.0217
# Epoch 35/100
# 310/310 [==============================] - 2s 5ms/step - loss: 0.0214
# Epoch 36/100
# 310/310 [==============================] - 2s 5ms/step - loss: 0.0212
# Epoch 37/100
# 310/310 [==============================] - 2s 5ms/step - loss: 0.0209
# Epoch 38/100
# 310/310 [==============================] - 1s 5ms/step - loss: 0.0209
# Epoch 39/100
# 310/310 [==============================] - 1s 5ms/step - loss: 0.0208
# Epoch 40/100
# 310/310 [==============================] - 2s 5ms/step - loss: 0.0207
# Epoch 41/100
# 310/310 [==============================] - 2s 5ms/step - loss: 0.0204
# Epoch 42/100
# 310/310 [==============================] - 1s 5ms/step - loss: 0.0201
# Epoch 43/100
# 310/310 [==============================] - 1s 5ms/step - loss: 0.0200
# Epoch 44/100
# 310/310 [==============================] - 2s 5ms/step - loss: 0.0199
# Epoch 45/100
# 310/310 [==============================] - 1s 5ms/step - loss: 0.0198
# Epoch 46/100
# 310/310 [==============================] - 2s 5ms/step - loss: 0.0197
# Epoch 47/100
# 310/310 [==============================] - 1s 5ms/step - loss: 0.0194
# Epoch 48/100
# 310/310 [==============================] - 2s 5ms/step - loss: 0.0193
# Epoch 49/100
# 310/310 [==============================] - 2s 5ms/step - loss: 0.0199
# Epoch 50/100
# 310/310 [==============================] - 1s 5ms/step - loss: 0.0193
# Epoch 51/100
# 310/310 [==============================] - 2s 5ms/step - loss: 0.0193
# Epoch 52/100
# 310/310 [==============================] - 2s 5ms/step - loss: 0.0191
# Epoch 53/100
# 310/310 [==============================] - 1s 5ms/step - loss: 0.0196
# Epoch 54/100
# 310/310 [==============================] - 1s 5ms/step - loss: 0.0197
# Epoch 55/100
# 310/310 [==============================] - 1s 5ms/step - loss: 0.0191
# Epoch 56/100
# 310/310 [==============================] - 1s 5ms/step - loss: 0.0191
# Epoch 57/100
# 310/310 [==============================] - 2s 5ms/step - loss: 0.0199
# Epoch 58/100
# 310/310 [==============================] - 2s 5ms/step - loss: 0.0202
# Epoch 59/100
# 310/310 [==============================] - 2s 5ms/step - loss: 0.0201
# Epoch 60/100
# 310/310 [==============================] - 2s 5ms/step - loss: 0.0204
# Epoch 61/100
# 310/310 [==============================] - 2s 5ms/step - loss: 0.0202
# Epoch 62/100
# 310/310 [==============================] - 1s 5ms/step - loss: 0.0201
# Epoch 63/100
# 310/310 [==============================] - 1s 4ms/step - loss: 0.0194
# Epoch 64/100
# 310/310 [==============================] - 1s 5ms/step - loss: 0.0193
# Epoch 65/100
# 310/310 [==============================] - 1s 5ms/step - loss: 0.0194
# Epoch 66/100
# 310/310 [==============================] - 1s 5ms/step - loss: 0.0189
# Epoch 67/100
# 310/310 [==============================] - 1s 5ms/step - loss: 0.0187
# Epoch 68/100
# 310/310 [==============================] - 1s 5ms/step - loss: 0.0185
# Epoch 69/100
# 310/310 [==============================] - 1s 5ms/step - loss: 0.0192
# Epoch 70/100
# 310/310 [==============================] - 1s 5ms/step - loss: 0.0192
# Epoch 71/100
# 310/310 [==============================] - 2s 5ms/step - loss: 0.0187
# Epoch 72/100
# 310/310 [==============================] - 1s 5ms/step - loss: 0.0190
# Epoch 73/100
# 310/310 [==============================] - 2s 5ms/step - loss: 0.0186
# Epoch 74/100
# 310/310 [==============================] - 2s 5ms/step - loss: 0.0189
# Epoch 75/100
# 310/310 [==============================] - 2s 5ms/step - loss: 0.0184
# Epoch 76/100
# 310/310 [==============================] - 2s 5ms/step - loss: 0.0187
# Epoch 77/100
# 310/310 [==============================] - 2s 5ms/step - loss: 0.0191
# Epoch 78/100
# 310/310 [==============================] - 1s 5ms/step - loss: 0.0187
# Epoch 79/100
# 310/310 [==============================] - 2s 5ms/step - loss: 0.0182
# Epoch 80/100
# 310/310 [==============================] - 2s 5ms/step - loss: 0.0190
# Epoch 81/100
# 310/310 [==============================] - 2s 5ms/step - loss: 0.0183
# Epoch 82/100
# 310/310 [==============================] - 1s 5ms/step - loss: 0.0180
# Epoch 83/100
# 310/310 [==============================] - 2s 5ms/step - loss: 0.0182
# Epoch 84/100
# 310/310 [==============================] - 1s 5ms/step - loss: 0.0181
# Epoch 85/100
# 310/310 [==============================] - 1s 5ms/step - loss: 0.0181
# Epoch 86/100
# 310/310 [==============================] - 2s 5ms/step - loss: 0.0178
# Epoch 87/100
# 310/310 [==============================] - 1s 5ms/step - loss: 0.0184
# Epoch 88/100
# 310/310 [==============================] - 1s 5ms/step - loss: 0.0190
# Epoch 89/100
# 310/310 [==============================] - 1s 5ms/step - loss: 0.0188
# Epoch 90/100
# 310/310 [==============================] - 1s 5ms/step - loss: 0.0182
# Epoch 91/100
# 310/310 [==============================] - 1s 5ms/step - loss: 0.0182
# Epoch 92/100
# 310/310 [==============================] - 1s 5ms/step - loss: 0.0186
# Epoch 93/100
# 310/310 [==============================] - 2s 5ms/step - loss: 0.0191
# Epoch 94/100
# 310/310 [==============================] - 1s 5ms/step - loss: 0.0197
# Epoch 95/100
# 310/310 [==============================] - 1s 5ms/step - loss: 0.0189
# Epoch 96/100
# 310/310 [==============================] - 1s 5ms/step - loss: 0.0181
# Epoch 97/100
# 310/310 [==============================] - 1s 5ms/step - loss: 0.0184
# Epoch 98/100
# 310/310 [==============================] - 1s 5ms/step - loss: 0.0192
# Epoch 99/100
# 310/310 [==============================] - 2s 5ms/step - loss: 0.0198
# Epoch 100/100
# 310/310 [==============================] - 1s 5ms/step - loss: 0.0198
# Model saved to disk

# %%
deep_learner.plot_test()
# Out:
# RMSE: 0.937987 [kWh]
# MAPE: 3.954067 %

# %%
# upload the data to predict ahead
filename = 'Consumption_15min.csv'
data27 = pd.read_csv(filename, index_col=0)
# slice some part for an input for the multiple step ahead forecast to continue on
data27 = data27[-672:]
data27
# Out:
#                      Valeur
# Datetime
# 2019-12-25 00:00:00    3.78
# 2019-12-25 00:15:00    3.99
# 2019-12-25 00:30:00    3.78
# 2019-12-25 00:45:00    3.99
# 2019-12-25 01:00:00    4.20
# ...                     ...
# 2019-12-31 22:45:00    3.78
# 2019-12-31 23:00:00    3.99
# 2019-12-31 23:15:00    3.78
# 2019-12-31 23:30:00    3.78
# 2019-12-31 23:45:00    3.78
#
# [672 rows x 1 columns]

# %%
# predict n steps ahead and plot
deep_learner.evaluate_n_ahead(data27, 288)
# Out:
# Loaded model from disk
#                             0
# 2020-01-04 06:00:00  4.846350
# 2020-01-04 06:15:00  4.851257
# 2020-01-04 06:30:00  4.853628
# 2020-01-04 06:45:00  4.848693
# 2020-01-04 07:00:00  4.781270
# ...                       ...
# 2020-01-07 04:45:00  5.239805
# 2020-01-07 05:00:00  5.235705
# 2020-01-07 05:15:00  5.226084
# 2020-01-07 05:30:00  5.228979
# 2020-01-07 05:45:00  5.208601
#
# [288 rows x 1 columns]
